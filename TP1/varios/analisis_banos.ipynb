# %% [markdown]
# # Analisis del campo 'banos'

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import common.common_pandas_lib as common

# %% [markdown]
# ## Configuraciones

# %% [markdown]
# ### Configuraciones librerias y plots

# %%
COLORES_BARRAS = 'colorblind'
# %matplotlib inline

plt.style.use('default') # haciendo los graficos un poco mas bonitos en matplotlib
plt.rcParams['figure.figsize'] = (18, 8)

sns.set(style="whitegrid", font_scale = 2) # seteando tipo de grid en seaborn
                                           # seteando tamanio de ticks label
sns.set_palette(COLORES_BARRAS)
    
pd.options.display.float_format = '{:20,.2f}'.format # suprimimos la notacion cientifica en los outputs

# %% [markdown]
# ## Carga optimizada del set de datos

# %%
zona_prop = common.cargar_train_optimizado('train.csv')

# %% [markdown]
# ## Banos

# %% [markdown]
# ### ¿Que es banos?

# %%
zona_prop['banos'].unique()
# Out:
# array([ 2.,  1.,  3., nan,  4.])

# %%
zona_prop['banos'].dtype
# Out:
# dtype('float16')

# %% [markdown]
# ### ¿Cuantos datos tiene el campo bano limpio?

# %%
cant_banos_nan = zona_prop['banos'].isnull().sum()
cant_banos_nan
# Out:
# 26221

# %% [markdown]
# ### ¿Cuantos datos perdemos si descartamos todos los banos nan?

# %%
cant_banos_nan / zona_prop.shape[0]
# Out:
# 0.10925416666666667

# %% [markdown]
# Perdemos aprox. el 11 % de los datos del set.

# %%
zona_banos = zona_prop.copy()
zona_banos = zona_banos.dropna(subset = ['banos'])
zona_banos['banos'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Ahora podemos convertir la columna de baños a int, pues los valores decimales no nos importan

# %%
zona_banos['banos'] = zona_banos['banos'].astype(np.int8) 
zona_banos['banos'].dtype
# Out:
# dtype('int8')

# %% [markdown]
# ### ¿Cual es la distribucion de propiedades segun la cantidad de baños?

# %%
banos_agrupados_cantidad = zona_banos.groupby(['banos']).agg({'banos' : ['count']})
banos_agrupados_cantidad.columns = banos_agrupados_cantidad.columns.get_level_values(0) \
                                    + '_' + \
                                    banos_agrupados_cantidad.columns.get_level_values(1)
banos_agrupados_cantidad.reset_index(inplace = True)
banos_agrupados_cantidad
# Out:
#    banos  banos_count
# 0      1        58173
# 1      2        87683
# 2      3        49365
# 3      4        18558

# %%
plot_banos_cantidad = sns.barplot(
                        x  = 'banos',
                        y = 'banos_count',
                        data = banos_agrupados_cantidad
                    )
common.setear_titulos_plot(
    plot_banos_cantidad,
    'Barplot : \nCantidad de propiedades, en Mexico, \nsegun la cantidad de baños',
    'Cantidad de baños',
    'Cantidad de propiedades'
)


plt.show()

# %% [markdown]
# Vemos que la mayor parte de las propiedades tiene solo 2 baños

# %% [markdown]
# ## Banos - Antiguedad

# %% [markdown]
# ### ¿Que es antiguedad?

# %%
zona_banos['antiguedad'].unique()
# Out:
# array([nan, 10.,  5.,  1.,  2.,  0.,  4.,  8.,  3., 18., 20., 16.,  6.,
#        50., 30., 26., 25., 28., 15., 12., 48., 22., 11., 60., 17., 33.,
#        35., 14., 40.,  7.,  9., 27., 24., 19., 34., 13., 37., 36., 31.,
#        21., 23., 45., 32., 51., 29., 42., 43., 70., 44., 65., 46., 39.,
#        38., 47., 63., 55., 52., 41., 80., 59., 67., 54., 49., 58., 75.,
#        53., 79., 69., 56., 61., 57., 66., 64., 74., 62., 68.])

# %%
zona_banos['antiguedad'].dtype
# Out:
# dtype('float16')

# %% [markdown]
# ### ¿Cuantas antiguedad son NaN?

# %%
cant_antiguedad_nan = zona_banos['antiguedad'].isnull().sum()
cant_antiguedad_nan
# Out:
# 33528

# %% [markdown]
# ### ¿Cuantos datos perdemos si descartamas antiguedad NaN tambien?

# %%
(cant_banos_nan + cant_antiguedad_nan) / zona_prop.shape[0]
# Out:
# 0.24895416666666667

# %% [markdown]
# Perdemos aprox. el 25 % de los datos totales.

# %%
zona_banos_antiguedad = zona_banos.dropna(subset = ['antiguedad'])
zona_banos_antiguedad['antiguedad'].isnull().sum()
# Out:
# 0

# %%
zona_banos_antiguedad = zona_banos_antiguedad.copy()
zona_banos_antiguedad['antiguedad'] = zona_banos_antiguedad['antiguedad'].astype(np.int16) 
# Para evitar overflows en el tipo al realizar operaciones, usamos un tipo 
# con mas bits de los necesarios, pero el minimo de ellos
zona_banos_antiguedad['antiguedad'].dtype
# Out:
# dtype('int16')

# %% [markdown]
# ### ¿Cual es el porcentaje de propiedades, en Mexico, segun la cantidad de baños y su antiguedad?

# %%
banos_agrupados_antiguedad_porcentaje = common.agrupar_calcular_porcentajes_desagrupar(zona_banos_antiguedad, 'banos', 'antiguedad')
banos_agrupados_antiguedad_porcentaje.columns = ['banos', 'antiguedad', 'porcentaje_propiedades']
banos_antiguedad_porcentaje_pivot = banos_agrupados_antiguedad_porcentaje.pivot_table(index = 'antiguedad', columns = 'banos', values = 'porcentaje_propiedades')
banos_antiguedad_porcentaje_pivot.fillna(0, inplace = True)
banos_antiguedad_porcentaje_pivot
# Out:
# banos                         1                    2                    3  \
# antiguedad
# 0                         15.76                26.81                27.82
# 1                          4.23                 6.91                 7.11
# 2                          1.82                 3.01                 2.86
# 3                          2.33                 3.25                 3.15
# 4                          3.79                 4.39                 4.18
# 5                         21.12                17.11                14.95
# 6                          1.68                 1.64                 1.65
# 7                          1.22                 1.06                 1.02
# 8                          1.47                 1.24                 1.20
# 9                          0.68                 0.51                 0.51
# 10                        19.96                13.41                12.78
# 11                         0.89                 0.63                 0.73
# 12                         0.94                 0.67                 0.75
# 13                         0.35                 0.25                 0.32
# 14                         0.35                 0.28                 0.33
# 15                         2.75                 1.77                 1.84
# 16                         0.36                 0.33                 0.38
# 17                         0.30                 0.25                 0.28
# 18                         0.51                 0.45                 0.48
# 19                         0.12                 0.17                 0.20
# 20                        11.87                 9.35                 9.96
# 21                         0.32                 0.35                 0.43
# 22                         0.23                 0.22                 0.26
# 23                         0.18                 0.13                 0.18
# 24                         0.17                 0.13                 0.12
# 25                         1.36                 1.04                 1.31
# 26                         0.21                 0.17                 0.21
# 27                         0.15                 0.12                 0.21
# 28                         0.19                 0.22                 0.23
# 29                         0.13                 0.09                 0.08
# ...                         ...                  ...                  ...
# 45                         0.19                 0.16                 0.14
# 46                         0.03                 0.01                 0.01
# 47                         0.02                 0.02                 0.02
# 48                         0.03                 0.01                 0.01
# 49                         0.01                 0.01                 0.00
# 50                         0.69                 0.50                 0.49
# 51                         0.02                 0.03                 0.02
# 52                         0.02                 0.00                 0.00
# 53                         0.01                 0.01                 0.01
# 54                         0.01                 0.00                 0.00
# 55                         0.02                 0.02                 0.02
# 56                         0.00                 0.00                 0.00
# 57                         0.00                 0.00                 0.00
# 58                         0.00                 0.01                 0.00
# 59                         0.00                 0.00                 0.00
# 60                         0.10                 0.07                 0.06
# 61                         0.00                 0.00                 0.00
# 62                         0.00                 0.00                 0.00
# 63                         0.00                 0.00                 0.00
# 64                         0.00                 0.00                 0.00
# 65                         0.01                 0.00                 0.01
# 66                         0.00                 0.00                 0.00
# 67                         0.00                 0.00                 0.00
# 68                         0.00                 0.00                 0.00
# 69                         0.00                 0.00                 0.00
# 70                         0.02                 0.01                 0.01
# 74                         0.00                 0.00                 0.00
# 75                         0.01                 0.00                 0.00
# 79                         0.00                 0.00                 0.00
# 80                         0.01                 0.01                 0.00
#
# banos                         4
# antiguedad
# 0                         30.61
# 1                          7.83
# 2                          2.86
# 3                          3.07
# 4                          4.17
# 5                         13.64
# 6                          1.62
# 7                          0.91
# 8                          1.05
# 9                          0.61
# 10                        11.48
# 11                         0.69
# 12                         0.87
# 13                         0.23
# 14                         0.40
# 15                         1.82
# 16                         0.49
# 17                         0.30
# 18                         0.47
# 19                         0.21
# 20                         9.20
# 21                         0.57
# 22                         0.29
# 23                         0.16
# 24                         0.16
# 25                         0.96
# 26                         0.21
# 27                         0.26
# 28                         0.16
# 29                         0.07
# ...                         ...
# 45                         0.16
# 46                         0.01
# 47                         0.03
# 48                         0.02
# 49                         0.00
# 50                         0.65
# 51                         0.02
# 52                         0.00
# 53                         0.00
# 54                         0.00
# 55                         0.02
# 56                         0.00
# 57                         0.01
# 58                         0.01
# 59                         0.01
# 60                         0.05
# 61                         0.00
# 62                         0.01
# 63                         0.00
# 64                         0.00
# 65                         0.01
# 66                         0.00
# 67                         0.00
# 68                         0.00
# 69                         0.01
# 70                         0.01
# 74                         0.00
# 75                         0.01
# 79                         0.00
# 80                         0.03
#
# [75 rows x 4 columns]

# %%
plot_heatmap_banos_antiguedad_porcentaje = sns.heatmap(
                                                banos_antiguedad_porcentaje_pivot,
                                                cmap = 'Blues',
                                                cbar_kws={'label': 'Porcentaje de propiedades [%]'}
                                            )
common.setear_titulos_plot(
    plot_heatmap_banos_antiguedad_porcentaje,
    'Heatmap : \nPorcentaje de propiedades, en Mexico, \nsegun la cantidad de baños y su antigüedad',
    'Cantidad de baños',
    'Antiguedad [años]'
)

plt.show()

# %% [markdown]
# #### ¿Cuales son la antiguedad de propiedades, en Mexico, que abarcan un porcentaje mayor a 10%, segun la cantidad de baños ?

# %%
banos_antiguedad_porcentaje = banos_antiguedad_porcentaje_pivot.unstack().to_frame().reset_index()
banos_antiguedad_porcentaje.columns = ['banos', 'antiguedad', 'porcentaje_propiedades']
banos_antiguedad_porcentaje_mayor_10 = banos_antiguedad_porcentaje.loc[banos_antiguedad_porcentaje['porcentaje_propiedades'] > 10]
banos_antiguedad_porcentaje_mayor_10_pivot = banos_antiguedad_porcentaje_mayor_10.pivot_table(index = 'antiguedad', columns = 'banos', values = 'porcentaje_propiedades')
banos_antiguedad_porcentaje_mayor_10_pivot.fillna(0, inplace = True)
banos_antiguedad_porcentaje_mayor_10_pivot
# Out:
# banos                         1                    2                    3  \
# antiguedad
# 0                         15.76                26.81                27.82
# 5                         21.12                17.11                14.95
# 10                        19.96                13.41                12.78
# 20                        11.87                 0.00                 0.00
#
# banos                         4
# antiguedad
# 0                         30.61
# 5                         13.64
# 10                        11.48
# 20                         0.00

# %%
plot_heatmap_banos_antiguedad_porcentaje_mayor_10 = sns.heatmap(
                                                        banos_antiguedad_porcentaje_mayor_10_pivot,
                                                        cmap = 'Blues',
                                                        cbar_kws={'label': 'Porcentaje de propiedades [%]'}
                                                    )
common.setear_titulos_plot(
    plot_heatmap_banos_antiguedad_porcentaje_mayor_10,
    'Heatmap : \nPorcentajes de propiedades mayores al 10%, en Mexico, \nsegun la cantidad de baños y su antigüedad ',
    'Cantidad de baños',
    'Antigüedad'
)

plt.show()

# %% [markdown]
# ## Banos - Metroscubiertos

# %% [markdown]
# ### ¿Que es metros cubiertos?

# %%
zona_banos['metroscubiertos'].unique()
# Out:
# array([ 80., 268., 144.,  63.,  95.,  75., 140., 293.,  58., 100., 256.,
#        170., 250., 180., 210., 133., 181., 179., 280., 258., 150.,  40.,
#         nan,  88., 143., 292., 346., 300., 303., 146.,  78.,  84.,  90.,
#        262., 156., 160.,  68.,  98.,  47.,  57., 285.,  79., 175., 340.,
#         61., 167., 220., 405.,  46., 350., 355.,  71.,  76., 122., 108.,
#        247.,  89., 228., 396., 264., 367., 164., 130.,  39., 161., 216.,
#         83., 385., 196., 120., 171., 141., 106., 254.,  86.,  55., 135.,
#        277., 110., 115., 177.,  70., 430., 189., 111.,  51., 155.,  65.,
#        225., 265.,  60., 102.,  49., 138., 270., 278., 131., 208., 245.,
#        269., 154., 125., 295., 211., 188., 230.,  66., 310., 113., 330.,
#        226., 233.,  96.,  59.,  54., 152., 360., 195., 173., 234.,  53.,
#        201., 193., 117., 351., 145.,  72., 260., 139.,  62., 198., 127.,
#        206.,  77., 322., 417., 192.,  64.,  97., 382., 222.,  94., 137.,
#        183., 246., 199., 153., 128., 147., 271., 105.,  85., 403., 101.,
#         87., 107., 136., 165., 342.,  99., 200., 263., 185., 205.,  30.,
#        240., 387., 218., 307.,  67.,  42., 116., 244.,  50., 217., 112.,
#        215., 309., 400., 252., 239.,  20., 420., 372., 166., 344., 121.,
#        151., 178., 159., 126., 413., 317., 335., 224., 186., 162., 272.,
#        202., 384.,  91., 158., 157., 142., 212., 306., 436., 148.,  36.,
#         92., 103., 320., 297., 276., 187., 426., 227.,  93., 377., 284.,
#         73.,  48., 132., 119., 304.,  74.,  56.,  45., 169., 380., 424.,
#         69., 334., 261., 273., 315., 231., 305., 312., 390., 371., 184.,
#        249., 410.,  52., 163., 243., 282., 255.,  82., 388., 298., 257.,
#        172., 235., 134., 182.,  81.,  41., 333., 123., 373., 316., 197.,
#        114., 232., 118., 418., 109., 290., 291., 391., 168., 104., 325.,
#        241., 174., 190., 314., 129., 176., 370., 348., 274., 253., 289.,
#        349., 327., 204., 313., 286., 363., 328., 319.,  38., 248., 203.,
#        365., 407.,  32., 242., 287., 281., 124., 283., 389., 404.,  44.,
#        207., 275., 337., 311., 308., 394., 331., 326., 432., 237., 329.,
#        374., 149., 302., 362., 213., 236., 296., 229., 214., 378.,  31.,
#         43., 356., 383., 324., 343., 194., 375., 191., 431., 406., 437.,
#        386., 221., 428., 259., 238., 419., 301., 438., 299., 352., 251.,
#        408., 338., 402., 209., 321., 368., 267., 392.,  35., 354., 223.,
#        401., 435., 266., 294., 429., 336.,  34., 332., 369., 425., 414.,
#        347., 353.,  29., 345.,  23., 364., 422., 421., 409., 416., 423.,
#        381., 339., 279., 427., 366., 393., 288., 376., 412., 318., 341.,
#        397.,  25.,  33., 411., 323., 415., 398.,  37., 395., 357., 358.,
#        379., 359., 361.,  24., 219., 399., 433.,  15.,  18., 439., 434.,
#         27.,  22.,  16.,  26.,  21.,  17.,  19.,  28.])

# %% [markdown]
# ### ¿Cuantos metroscubiertos del set restante estan limpios?

# %%
cant_banos_no_nan_metroscubiertos_nan = zona_banos['metroscubiertos'].isnull().sum()
cant_banos_no_nan_metroscubiertos_nan
# Out:
# 6604

# %% [markdown]
# ### ¿Cuantos datos perdemos si descartamos metroscubiertos NaN?

# %%
(cant_banos_nan + cant_banos_no_nan_metroscubiertos_nan) / zona_prop.shape[0]
# Out:
# 0.13677083333333334

# %% [markdown]
# Perdemos aprox. el 14 % de los datos del set.

# %%
zona_banos_metroscubiertos = zona_banos.dropna(subset = ['metroscubiertos'])
zona_banos_metroscubiertos['metroscubiertos'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### ¿Cual es la distribuciones de metros cubiertos de las propiedades, en Mexico, segun la cantidad de banos?

# %%
banos_agrupados_metroscubiertos_estadisticas = common.agrupar_calcular_estadisticas_desagrupar(zona_banos, 'banos', 'metroscubiertos')
banos_agrupados_metroscubiertos_estadisticas
# Out:
#    banos  metroscubiertos_cuantil_1  metroscubiertos_median  \
# 0      1                      60.00                   73.00
# 1      2                     106.00                  145.00
# 2      3                     180.00                  232.00
# 3      4                     237.00                  295.00
#
#    metroscubiertos_cuantil_3
# 0                      99.00
# 1                     198.00
# 2                     300.00
# 3                     350.00

# %%
plot_boxplot_banos_metroscubiertos = sns.boxplot(
                                            x = 'banos',
                                            y = 'metroscubiertos',
                                            data = zona_banos_metroscubiertos
                                        )

# Titulos
common.setear_titulos_plot(
    plot_boxplot_banos_metroscubiertos,
    'Boxplot : \nDistribucion de metros cubiertos para propiedades, \nen Mexico, segun la cantidad de baños',
    'Cantidad de baños',
    'Metros cubiertos [m]'
)

# Agrego cuantiles y medianas
common.agregar_serie_plot(
    plot_boxplot_banos_metroscubiertos,
    banos_agrupados_metroscubiertos_estadisticas['metroscubiertos_cuantil_1'],
    banos_agrupados_metroscubiertos_estadisticas['metroscubiertos_cuantil_1'],
    'w',
    -0.25, 3
)

common.agregar_serie_plot(
    plot_boxplot_banos_metroscubiertos,
    banos_agrupados_metroscubiertos_estadisticas['metroscubiertos_median'],
    banos_agrupados_metroscubiertos_estadisticas['metroscubiertos_median'],
    'w',
    0, 3
)

common.agregar_serie_plot(
    plot_boxplot_banos_metroscubiertos,
    banos_agrupados_metroscubiertos_estadisticas['metroscubiertos_cuantil_3'],
    banos_agrupados_metroscubiertos_estadisticas['metroscubiertos_cuantil_3'],
    'k',
    0.25, 3
)

plt.show()

# %% [markdown]
# Vemos que la cantidad de metros cubiertos para propiedades de un solo baño varia poco.
# Por otro lado propieadades con 3 o 4 baños tienen mas variacion mayor en los metros cubiertos.

# %% [markdown]
# ## Banos - Metrostotales

# %% [markdown]
# ### ¿Que ese metrostotales?

# %%
zona_banos['metrostotales'].unique()
# Out:
# array([ 80., 180., 166.,  67.,  95.,  90., 160., 293.,  nan, 141., 231.,
#        250., 275., 184., 150., 224., 260.,  98.,  66., 306., 196., 355.,
#        300., 350., 216., 145., 200., 100., 170.,  84., 110.,  70., 140.,
#        128., 233.,  68.,  47., 190.,  61., 167., 132.,  64., 385., 340.,
#        215., 330., 122., 204., 120., 135., 210., 183., 325., 163.,  39.,
#        191.,  83., 408., 121., 400., 144.,  75.,  96., 178.,  86.,  60.,
#         85., 220.,  50., 153., 189., 421., 125., 151., 105., 155., 257.,
#        256., 168., 268., 349., 126.,  49., 112., 273., 130., 198., 131.,
#        115., 248.,  88., 246., 113., 304., 394., 154.,  59.,  63., 208.,
#         58., 244., 117., 127.,  53., 226., 108., 146., 309., 415.,  72.,
#        240.,  55., 420., 107.,  71., 367., 197., 138., 230., 142.,  97.,
#         89., 320., 162., 290., 137., 251., 119., 123., 136., 271., 158.,
#         74., 109., 390.,  65.,  30., 302., 218., 214., 313., 102.,  99.,
#        104.,  62., 249., 243., 165., 169., 195., 192., 205., 310., 159.,
#        101., 366.,  56., 238., 245., 277., 225., 407., 164., 266., 351.,
#        111., 185., 280., 152., 157., 161., 212., 336.,  73., 211., 360.,
#         91., 103., 177., 187., 176., 396., 261., 368., 341., 227., 437.,
#        229.,  93., 264., 106.,  92., 234., 156.,  87.,  94.,  78.,  48.,
#        148., 149., 288., 217., 424., 147., 114., 133., 265., 182., 236.,
#        363., 365., 282.,  36., 206.,  82.,  52., 422., 239., 254., 339.,
#        392., 384., 143.,  41., 301., 311., 134., 439.,  77., 380., 235.,
#         45., 344., 345.,  46., 242., 175., 318., 376., 116., 199., 188.,
#        398., 241., 209., 174., 314., 172., 371., 357., 223., 308., 124.,
#        427., 274., 181., 433., 324., 334., 255., 348., 213., 281., 303.,
#        263., 286., 379., 171., 356., 283., 272., 194., 352., 312., 372.,
#         51.,  54., 270., 410., 202., 276., 307., 354., 331., 326., 258.,
#        269., 362., 289., 299., 252., 297., 193., 315., 237., 285., 378.,
#        328., 259.,  81., 373., 129., 118., 403., 253., 409., 186., 287.,
#        203.,  40., 430., 405., 173., 222., 418., 228., 247., 359., 397.,
#        364., 428., 435., 323., 375.,  69., 201., 333.,  42., 431., 417.,
#        179., 322., 298., 370., 139., 335.,  76., 219., 279., 387., 319.,
#        346., 291.,  57., 207., 332.,  79., 395., 232.,  44., 353., 413.,
#        389., 305., 278., 262., 296., 338., 316., 358., 295., 267., 416.,
#         43.,  35., 425.,  24., 292.,  22., 391., 327., 404., 294., 347.,
#         34., 386., 426., 382., 383.,  33., 361., 221., 377.,  32., 329.,
#        284., 374., 412., 342.,  25., 432., 381.,  28., 337., 419., 369.,
#        438., 388.,  26., 402., 423., 434.,  20.,  37., 321., 317.,  31.,
#         16., 399., 406.,  17., 393., 401., 411.,  15., 429.,  21., 343.,
#        436.,  38.,  27., 414.,  19.,  29.,  23.,  18.])

# %%
zona_banos['metrostotales'].dtype
# Out:
# dtype('float16')

# %% [markdown]
# ### ¿Cuantos metrostotales son NaN?

# %%
cant_metrostotales_nan = zona_banos['metrostotales'].isnull().sum()
cant_metrostotales_nan
# Out:
# 46376

# %% [markdown]
# ### ¿Cuantos datos perdemos si descartamos tambien metrostotales NaN?

# %%
(cant_banos_nan + cant_metrostotales_nan) / zona_prop.shape[0]
# Out:
# 0.3024875

# %% [markdown]
# Perdemos aprox. el 30 % de los datos.

# %%
zona_banos_metrostotales = zona_banos.copy()
zona_banos_metrostotales = zona_banos_metrostotales.dropna(subset = ['metrostotales'])
zona_banos_metrostotales['metrostotales'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### ¿Cual es la distribucion de metros totales de las propiedades, en Mexico, segun la cantidad de baños?

# %%
banos_agrupados_metrostotales_estadisticas = common.agrupar_calcular_estadisticas_desagrupar(zona_banos, 'banos', 'metrostotales')
banos_agrupados_metrostotales_estadisticas
# Out:
#    banos  metrostotales_cuantil_1  metrostotales_median  \
# 0      1                    66.00                 90.00
# 1      2                   106.00                142.00
# 2      3                   152.00                203.00
# 3      4                   190.00                250.00
#
#    metrostotales_cuantil_3
# 0                   124.00
# 1                   200.00
# 2                   284.00
# 3                   320.00

# %%
plot_boxplot_banos_metrostotales = sns.boxplot(
                                        x = 'banos',
                                        y = 'metrostotales',
                                        data = zona_banos_metrostotales
                                    )
# Titulos
common.setear_titulos_plot(
    plot_boxplot_banos_metrostotales,
    'Boxplot : \nDistribucion de los metros totales de las propiedades, \nen Mexico, segun la cantidad de baños',
    'Cantidad de baños',
    'Metros totales [m]'
)

# Agrego cuantiles y medianas
common.agregar_serie_plot(
    plot_boxplot_banos_metrostotales,
    banos_agrupados_metrostotales_estadisticas['metrostotales_cuantil_1'],
    banos_agrupados_metrostotales_estadisticas['metrostotales_cuantil_1'],
    'w',
    -0.25, 3
)

common.agregar_serie_plot(
    plot_boxplot_banos_metrostotales,
    banos_agrupados_metrostotales_estadisticas['metrostotales_median'],
    banos_agrupados_metrostotales_estadisticas['metrostotales_median'],
    'w',
    0, 3
)

common.agregar_serie_plot(
    plot_boxplot_banos_metrostotales,
    banos_agrupados_metrostotales_estadisticas['metrostotales_cuantil_3'],
    banos_agrupados_metrostotales_estadisticas['metrostotales_cuantil_3'],
    'k',
    0.25, 3
)

plt.show()

# %% [markdown]
# Al igual que en el boxplot banos-metroscubiertos, las propiedades con 1 baño varian poco en metros totales ocupados.
# De la misma, manera, a medida que aumento la cantidad de baños, tambien aumenta la "varianza" de metrostotales de la estas propiedades.

# %% [markdown]
# ## Baños - Fecha

# %% [markdown]
# TODO : Podriamos hacer un grafico para ver la evolucion de los precios con respecto al avance de los meses en un año.

# %% [markdown]
# ### ¿Que es fecha?

# %%
zona_banos['fecha'].unique()
# Out:
# array(['2015-08-23T00:00:00.000000000', '2013-06-28T00:00:00.000000000',
#        '2015-10-17T00:00:00.000000000', ...,
#        '2012-12-30T00:00:00.000000000', '2014-08-31T18:12:16.000000000',
#        '2014-09-30T18:12:16.000000000'], dtype='datetime64[ns]')

# %%
zona_banos['fecha'].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# ### ¿Cuantas fecha son NaN?

# %%
zona_banos['fecha'].isnull().sum()
# Out:
# 0

# %% [markdown]
# No perdemos mas datos.

# %%
zona_banos['anio'] = zona_banos['fecha'].dt.year
zona_banos
# Out:
#             id                                             titulo  \
# 0       254099                                  depto. tipo a-402
# 1        53461                     condominio horizontal en venta
# 2       247984              casa en venta urbi 3 recamaras tonala
# 3       209067  casa sola en toluca zinacantepec con credito i...
# 4       185997                                     paseos del sol
# 5       126147                     departamento en venta taxqueña
# 6       139233                 de oportunidad casa en san lorenzo
# 7         5013  casa emilia en venta en selvamar playa del carmen
# 8        44962  pre- venta preciosos depas 2 recamaras con sub...
# 10       51180                                      mi 2° credito
# 11      103293  departamento en venta, san pedro garza garcia,...
# 12       47890             hermosa casa en zibata queretaro 170m²
# 14      181436                        casa en venta en valle real
# 15      201923               casa en venta lomas verdes naucalpan
# 16      283945               preciosa casa en cumbres del lago \t
# 19       87655                                                NaN
# 21      224513                         casa en venta en querétaro
# 22      129818  comoda casa con recamara en planta baja y ampl...
# 23      146699  casa en condominio en venta, benito juarez, ca...
# 24      235958  casa en venta - colinas del cimatario, queréta...
# 25       97918                           casa venta santa cecilia
# 26       70294  casa en venta de un nivel , frac. misiones de ...
# 27      177031                                                NaN
# 30      257302                                                NaN
# 31      118889  vendo hermosa casa en fraccionamiento lomas de...
# 32      261416           casa en venta en montebello, merida - pf
# 33      162157                                      universitaria
# 34      173573                casa en venta lomas de la herradura
# 36      261703  hermosa casa en desarrollo en juriquilla (quer...
# 37        1127  casa en venta en tampico zona centro calle dr....
# ...        ...                                                ...
# 239969   65725                       casa en venta en toluca 2000
# 239970  123855  residencia en las cañadas, gran oportunidad pa...
# 239971    2747  departamento exclusivo para tu familia, vive b...
# 239972  130523           casa para remodelar, excelente ubicación
# 239973  149503           departamento en venta en villa de cortes
# 239974  156730  casa en venta, cuautitlán izcalli, estado de m...
# 239975  258795  casa en uno de los desarrollos con mayor plusv...
# 239976  184779                        casa en venta en campanario
# 239977  214176                                       casa tecamac
# 239978  235796    linda casa en venta,cerca del lago de guadalupe
# 239979  103355         se vende casa en delegacion miguel hidalgo
# 239980  267455              departamentos en renta torres palmira
# 239981  199041         casa en venta en residencial agua caliente
# 239982  252709  casa de 2 recamaras en residencial del bosque ...
# 239983  194027                   casa en venta en san luis potosí
# 239984  262913        en venta mitras centro monterrey nuevo leon
# 239985   64820  casa en venta fuentes de satelite, atizapan, e...
# 239986   41090  excelete torre de departamentos en lomas 4ta s...
# 239987  278167                                                NaN
# 239989  175203               casa venta renta en rinconada jurica
# 239990   87498                  casa en venta: bosques del contry
# 239991  137337                    departamento residencial coyuya
# 239992   54886                                      casa en venta
# 239993  207892                               bugambilias (ciudad)
# 239994  110268               hermosa casa en villa de los belenes
# 239995  119879  bonita casas de 2 recamaras a 10 minutos del c...
# 239996  259178  casa en condominio a 10 min. del centro de toluca
# 239997  131932                                   nicolas san juan
# 239998  146867                      casa sola. javier rojo gomez.
# 239999  121958  departamento en bosques de las lomas  / av. st...
#
#                                               descripcion     tipodepropiedad  \
# 0       depto. interior de 80.15m2, consta de sala com...         Apartamento
# 1       <p>entre sonora y guerrero, atr&aacute;s del h...  Casa en condominio
# 2       descripcion \nla mejor ubicacion residencial e...                Casa
# 3       casa en privada con caseta de vigilancia casas...                Casa
# 4       bonito departamento en excelentes condiciones ...         Apartamento
# 5       amplio departamento, estancia de sala y comedo...         Apartamento
# 6       ubicada en esquina, pertenece san lorenzo agen...                Casa
# 7       casa emilia en venta playa del carmenfracciona...                Casa
# 8       <p>pre-venta de preciosos departamento ecologi...         Apartamento
# 10      <p>mi 2&deg; credito<br />para todos aquellos ...                Casa
# 11      departamento nuevo ,256 m2 de construccion,un ...         Apartamento
# 12      <p><strong>casa </strong>en venta en fracciona...                Casa
# 14      pre venta de residencia en la toscana con exce...                Casa
# 15      <p>casa en dos niveles, 3 recámaras la princip...                Casa
# 16      <p>clave: vcln2450 fecha de actualizaci&oacute...                Casa
# 19      -- rcv151104-lv-27 --    linda casa con area d...                Casa
# 21      nocnok id: mx15-bk0340. hermosa casa en conjun...  Casa en condominio
# 22      <p>comoda casa con recamara en planta baja y a...                Casa
# 23      casa en venta en cancun en residencial cumbres...  Casa en condominio
# 24      <p>propiedad en un nivel, con espacios amplios...                Casa
# 25      hermosa casa en santa cecilia en apodaca, cerc...                Casa
# 26      ¡excelente oportunidad!  \n\ncasa de un nivel ...  Casa en condominio
# 27      hermosa casa remodelada, con acabados de lujo,...  Casa en condominio
# 30      -- hav1407e-285 --    excelente departamento e...         Apartamento
# 31      <p>vendo hermosa casa en fraccionamiento lomas...                Casa
# 32      <p>planta baja:\n</p><p>sala, comedor, amplia ...                Casa
# 33      2 plantas, 4 habitaciones, 3.5 baños, sala, co...                Casa
# 34      casa iluminada, con buena distribucion, 350m2 ...                Casa
# 36      <p>bonito desarrollo dentro de cumbres del lag...  Casa en condominio
# 37      <p>excelente casa en céntrica ubicación, con p...                Casa
# ...                                                   ...                 ...
# 239969  cansado de buscar¡¡¡deseas vivir en un desarro...                Casa
# 239970  residencia en las cañadas, una gran oportunida...                Casa
# 239971  www. \n3 recamaras, 2 baños \n2 autos \nentreg...         Apartamento
# 239972  estado de conservación: para remodelar, área d...                Casa
# 239973  últimos departamentos en preventa dentro de ex...         Apartamento
# 239974  casa en venta en lago de guadalupe. excelente ...                Casa
# 239975  <p>el desarrollo cuenta con barda perimetral c...                Casa
# 239976  bonita y bien ubicada casa en venta, 3 recamar...                Casa
# 239977  hermosa casa, en excelente mantenimiento y muy...                Casa
# 239978  buen proyecto, desarrollada en tres plantas, p...                Casa
# 239979  excelente casa muy bien ubicada en zona tranqu...                Casa
# 239980  departamento en venta avenida palmira , san lu...         Apartamento
# 239981  se vende bonita casa en el fracc. residencial ...                Casa
# 239982  casa de 2 recámaras en residencial del bosque ...                Casa
# 239983  nocnok id: mx16-bo3390. sin posesión física, p...                Casa
# 239984   en excelente ubicación zona mitras centro. am...                Casa
# 239985  casa en venta fuentes de satélite, atizapán, e...  Casa en condominio
# 239986  <p>exclusiva torre de departamentos en venta e...         Apartamento
# 239987  -- rcv347n-287 --    casas nuevas estilo minim...                Casa
# 239989  terreno 404m2 \nconst. 347 m2 \n\npreciosa cas...                Casa
# 239990  <p>casa en venta, en magníficas condiciones; e...                Casa
# 239991  departamento ubicado en planta baja, con excel...         Apartamento
# 239992  bonita casa para remodelar en una calle cerrad...  Casa en condominio
# 239993  coto privado de tan solo 7 casas donde cada fa...                Casa
# 239994  <p>moderna casa 3 pisos, muro llor&oacute;n , ...                Casa
# 239995  vendo casa en bosques de ica residencial a 10 ...                Casa
# 239996  casa con un jardin amplio, un cuarto de servic...                Casa
# 239997  departamento con excelente ubicación, muy cerc...         Apartamento
# 239998  casa sola, dividida en cuatro departamentos de...                Casa
# 239999  id:19816, muy bonito e iluminado departamento,...         Apartamento
#
#                                                 direccion  \
# 0                         Avenida Division del Norte 2005
# 1                                              AV. MEXICO
# 2                                             Urbi Tonala
# 3                           IGNACIO MANUEL ALTAMIRANO 128
# 4                                         PASEOS DEL SOL
# 5                                   Condominio Tlalpan 2B
# 6                                                     NaN
# 7                                    condominio el trebol
# 8                          BUENAVISTA DEPTOS CON SUBSIDIO
# 10                                          MI 2° CREDITO
# 11                                                    NaN
# 12                               Pitahayas 2 - 58, Zibata
# 14                                                    NaN
# 15                                                    NaN
# 16         CUMBRES DEL LAGO JURIQUILLA, QUERETARO, MEXICO
# 19                                     SENDA CELESTIAL 10
# 21                                                    NaN
# 22                                                    NaN
# 23                                                    NaN
# 24                           Colinas del Cimatario   C721
# 25                                          Lopez Velarde
# 26                              MISIONES DE SAN FRANCISCO
# 27                                  PASEO DE LOS LAURELES
# 30                                            Rio Mante .
# 31                   FRACCIONAMIENTO LOMAS DE SAN ALFONSO
# 32                                                    NaN
# 33                                                    NaN
# 34                               PASEO DE LA HERRADURA 00
# 36                                                    NaN
# 37                                   Dr. Alfredo Gochicoa
# ...                                                   ...
# 239969                 Lopez portillo y Av. Las Parti S/N
# 239970                       Paseo de los fambruesos 3150
# 239971                                              TOKIO
# 239972                                  Albino Garcia 219
# 239973                                  Pérez de León  61
# 239974                                                NaN
# 239975                                                NaN
# 239976                                                NaN
# 239977                                    AV RANCHO NUEVO
# 239978                                                NaN
# 239979                                         Rio Parana
# 239980                                                NaN
# 239981                                      PRIV. VENECIA
# 239982                                                NaN
# 239983                                                NaN
# 239984                                PROGRESO, MONTERREY
# 239985    FUENTES DE SATÉLITE, ATIZAPÁN, ESTADO DE MÉXICO
# 239986                                                NaN
# 239987                                  Primero de mayo 5
# 239989                                             Jurica
# 239990                                                NaN
# 239991                                         Coyuya 200
# 239992                            Cerrada villa Picadilly
# 239993                                 Paseo de la Cañada
# 239994  MANUEL AMAYA,ENTRE SEBASTIAN ALLENDE Y AMADO A...
# 239995                                            BOSQUES
# 239996                                Filiberto Navas 325
# 239997                                   Nicolas San Juan
# 239998                              Javier Rojo Gomez 120
# 239999                                          AVE. STIM
#
#                         ciudad              provincia           antiguedad  \
# 0                Benito Juárez       Distrito Federal                  nan
# 1       La Magdalena Contreras       Distrito Federal                10.00
# 2                       Tonalá                Jalisco                 5.00
# 3                 Zinacantepec         Edo. de México                 1.00
# 4                      Zapopan                Jalisco                10.00
# 5                     Coyoacán       Distrito Federal                 5.00
# 6             Oaxaca de Juárez                 Oaxaca                  nan
# 7             Playa del Carmen           Quintana Roo                 2.00
# 8             Villa de Alvarez                 Colima                 1.00
# 10             San Luis Potosí        San luis Potosí                 0.00
# 11      San Pedro Garza García             Nuevo León                  nan
# 12                   Querétaro              Querétaro                 0.00
# 14                     Zapopan                Jalisco                  nan
# 15         Naucalpan de Juárez         Edo. de México                  nan
# 16                   Querétaro              Querétaro                 0.00
# 19                   Querétaro              Querétaro                 0.00
# 21                   Querétaro              Querétaro                  nan
# 22               Ciudad Madero             Tamaulipas                 0.00
# 23                      Cancún           Quintana Roo                 4.00
# 24                   Querétaro              Querétaro                 4.00
# 25                     Apodaca             Nuevo León                 8.00
# 26                      Puebla                 Puebla                 3.00
# 27              Miguel Hidalgo       Distrito Federal                18.00
# 30               Ciudad Madero             Tamaulipas                 0.00
# 31                      Puebla                 Puebla                 5.00
# 32                      Mérida                Yucatán                  nan
# 33             San Luis Potosí        San luis Potosí                 0.00
# 34                Huixquilucan         Edo. de México                20.00
# 36                   Querétaro              Querétaro                  nan
# 37                     Tampico             Tamaulipas                  nan
# ...                        ...                    ...                  ...
# 239969                  Toluca         Edo. de México                 1.00
# 239970                 Zapopan                Jalisco                10.00
# 239971           Benito Juárez       Distrito Federal                 4.00
# 239972              Cuauhtémoc       Distrito Federal                20.00
# 239973           Benito Juárez       Distrito Federal                 1.00
# 239974      Cuautitlán Izcalli         Edo. de México                 4.00
# 239975               Querétaro              Querétaro                  nan
# 239976               Chihuahua              Chihuahua                  nan
# 239977                 Tecámac         Edo. de México                 5.00
# 239978    Atizapán de Zaragoza         Edo. de México                  nan
# 239979          Miguel Hidalgo       Distrito Federal                10.00
# 239980         San Luis Potosí        San luis Potosí                 1.00
# 239981                 Tijuana  Baja California Norte                10.00
# 239982                 Tijuana  Baja California Norte                  nan
# 239983         San Luis Potosí        San luis Potosí                  nan
# 239984               Monterrey             Nuevo León                20.00
# 239985    Atizapán de Zaragoza         Edo. de México                10.00
# 239986         San Luis Potosí        San luis Potosí                 0.00
# 239987           Cuautlancingo                 Puebla                 0.00
# 239989               Querétaro              Querétaro                 2.00
# 239990               Guadalupe             Nuevo León                20.00
# 239991               Iztacalco       Distrito Federal                20.00
# 239992            Huixquilucan         Edo. de México                10.00
# 239993                 Zapopan                Jalisco                 1.00
# 239994                 Zapopan                Jalisco                 3.00
# 239995            Zinacantepec         Edo. de México                 0.00
# 239996                  Toluca         Edo. de México                 0.00
# 239997           Benito Juárez       Distrito Federal                20.00
# 239998              Iztapalapa       Distrito Federal                20.00
# 239999   Cuajimalpa de Morelos       Distrito Federal                 1.00
#
#                habitaciones              garages  ...                  lat  \
# 0                      2.00                 1.00  ...                  nan
# 1                      3.00                 2.00  ...                19.31
# 2                      3.00                 2.00  ...                  nan
# 3                      2.00                 1.00  ...                19.30
# 4                      2.00                 1.00  ...                  nan
# 5                      2.00                 1.00  ...                19.30
# 6                      3.00                 1.00  ...                17.14
# 7                      4.00                 2.00  ...                20.67
# 8                      2.00                 1.00  ...                  nan
# 10                     3.00                 1.00  ...                22.20
# 11                     3.00                 2.00  ...                  nan
# 12                     3.00                 2.00  ...                20.68
# 14                      nan                 2.00  ...                20.73
# 15                     3.00                 2.00  ...                19.52
# 16                     3.00                 2.00  ...                20.71
# 19                     3.00                 2.00  ...                  nan
# 21                     3.00                 2.00  ...                  nan
# 22                     4.00                  nan  ...                22.26
# 23                     3.00                 2.00  ...                21.11
# 24                     3.00                  nan  ...                20.56
# 25                     3.00                 2.00  ...                  nan
# 26                     2.00                 1.00  ...                  nan
# 27                     3.00                 3.00  ...                  nan
# 30                     2.00                 1.00  ...                  nan
# 31                     3.00                 2.00  ...                18.97
# 32                     3.00                 2.00  ...                  nan
# 33                     4.00                 3.00  ...                  nan
# 34                     4.00                  nan  ...                19.41
# 36                     3.00                 2.00  ...                  nan
# 37                     3.00                  nan  ...                22.22
# ...                     ...                  ...  ...                  ...
# 239969                 3.00                 1.00  ...                19.37
# 239970                 5.00                 3.00  ...                20.79
# 239971                 3.00                 2.00  ...                19.37
# 239972                 5.00                 2.00  ...                19.40
# 239973                 2.00                 1.00  ...                  nan
# 239974                 3.00                  nan  ...                19.63
# 239975                 3.00                 2.00  ...                20.65
# 239976                 3.00                 0.00  ...                  nan
# 239977                 1.00                 1.00  ...                  nan
# 239978                 3.00                 2.00  ...                19.60
# 239979                 3.00                 2.00  ...                19.46
# 239980                 2.00                  nan  ...                16.75
# 239981                 2.00                 1.00  ...                32.49
# 239982                 2.00                 1.00  ...                32.51
# 239983                 3.00                  nan  ...                22.16
# 239984                 2.00                 1.00  ...                25.70
# 239985                 3.00                 2.00  ...                  nan
# 239986                 3.00                 2.00  ...                  nan
# 239987                 3.00                 2.00  ...                  nan
# 239989                 3.00                 2.00  ...                20.65
# 239990                 3.00                 2.00  ...                25.66
# 239991                 2.00                 1.00  ...                19.40
# 239992                 3.00                  nan  ...                  nan
# 239993                 3.00                 2.00  ...                20.62
# 239994                 2.00                 2.00  ...                20.60
# 239995                 2.00                 2.00  ...                  nan
# 239996                 3.00                 3.00  ...                19.29
# 239997                 2.00                 1.00  ...                  nan
# 239998                 4.00                 0.00  ...                19.37
# 239999                 3.00                 2.00  ...                  nan
#
#                         lng      fecha  gimnasio  usosmultiples  piscina  \
# 0                       nan 2015-08-23     False          False    False
# 1                    -99.23 2013-06-28     False          False    False
# 2                       nan 2015-10-17     False          False    False
# 3                    -99.69 2012-03-09     False          False    False
# 4                       nan 2016-06-07     False          False    False
# 5                    -99.15 2014-03-18     False          False    False
# 6                    -96.80 2016-02-23     False          False    False
# 7                    -87.04 2016-10-20     False          False    False
# 8                       nan 2014-01-06     False          False    False
# 10                  -101.02 2013-01-03     False          False    False
# 11                      nan 2014-12-01     False          False    False
# 12                  -100.32 2013-08-12     False           True    False
# 14                  -103.43 2014-11-25     False          False    False
# 15                   -99.26 2015-01-13     False          False    False
# 16                  -100.46 2013-03-06     False          False    False
# 19                      nan 2016-01-15     False          False    False
# 21                      nan 2016-02-01     False          False    False
# 22                   -97.84 2013-12-12     False          False    False
# 23                   -86.85 2015-05-19     False          False    False
# 24                  -100.37 2013-09-26     False          False    False
# 25                      nan 2016-12-31     False          False    False
# 26                      nan 2014-07-22     False          False    False
# 27                      nan 2012-03-07     False          False    False
# 30                      nan 2016-04-08     False          False    False
# 31                   -98.24 2013-01-20     False           True    False
# 32                      nan 2014-04-05     False          False    False
# 33                      nan 2013-01-12     False          False    False
# 34                   -99.27 2016-11-19     False           True    False
# 36                      nan 2015-11-22     False          False    False
# 37                   -97.86 2016-12-25     False          False    False
# ...                     ...        ...       ...            ...      ...
# 239969               -99.58 2012-07-03     False          False    False
# 239970              -103.36 2016-12-11     False          False     True
# 239971               -99.15 2016-12-19     False          False    False
# 239972               -99.13 2016-01-19     False          False    False
# 239973                  nan 2013-02-05     False          False    False
# 239974               -99.25 2015-08-05     False          False    False
# 239975              -100.35 2014-04-03     False          False    False
# 239976                  nan 2015-02-09     False          False    False
# 239977                  nan 2015-04-12     False          False    False
# 239978               -99.25 2016-10-24     False          False    False
# 239979               -99.21 2016-03-04     False          False    False
# 239980               -93.09 2016-12-03     False          False    False
# 239981              -116.99 2012-11-20     False          False    False
# 239982              -116.84 2016-02-05     False          False    False
# 239983              -100.97 2016-02-09     False          False    False
# 239984              -100.34 2016-07-30     False          False    False
# 239985                  nan 2016-12-07     False          False    False
# 239986                  nan 2013-09-07     False          False    False
# 239987                  nan 2015-10-28     False          False    False
# 239989              -100.43 2016-09-15     False           True     True
# 239990              -100.25 2014-04-12     False          False    False
# 239991               -99.12 2015-03-14     False          False    False
# 239992                  nan 2015-11-23     False          False    False
# 239993              -103.46 2015-03-22     False          False    False
# 239994              -103.45 2013-07-31     False          False    False
# 239995                  nan 2015-02-08     False          False    False
# 239996               -99.69 2014-07-10     False          False    False
# 239997                  nan 2015-03-03     False          False    False
# 239998               -99.08 2014-12-26      True          False    False
# 239999                  nan 2015-06-19     False          False    False
#
#        escuelascercanas  centroscomercialescercanos               precio  anio
# 0                 False                       False         2,273,000.00  2015
# 1                  True                        True         3,600,000.00  2013
# 2                 False                       False         1,200,000.00  2015
# 3                  True                        True           650,000.00  2012
# 4                 False                       False         1,150,000.00  2016
# 5                 False                        True         1,100,000.00  2014
# 6                 False                       False         1,150,000.00  2016
# 7                 False                       False         4,200,000.00  2016
# 8                  True                        True           310,000.00  2014
# 10                 True                        True           488,000.00  2013
# 11                False                       False         7,200,000.00  2014
# 12                 True                        True         1,500,000.00  2013
# 14                False                       False         5,300,000.00  2014
# 15                False                       False         3,650,000.00  2015
# 16                 True                        True         2,450,000.00  2013
# 19                False                       False         1,850,000.00  2016
# 21                False                       False         2,300,000.00  2016
# 22                False                       False         1,340,000.00  2013
# 23                False                       False         3,500,000.00  2015
# 24                 True                        True         3,900,000.00  2013
# 25                 True                        True           850,000.00  2016
# 26                 True                        True           310,000.00  2014
# 27                False                       False        10,800,000.00  2012
# 30                False                       False           750,000.00  2016
# 31                 True                        True         1,450,000.00  2013
# 32                False                       False         3,300,000.00  2014
# 33                False                       False         2,600,000.00  2013
# 34                 True                        True         7,900,000.00  2016
# 36                False                       False         3,000,000.00  2015
# 37                False                       False         1,280,000.00  2016
# ...                 ...                         ...                  ...   ...
# 239969             True                        True           715,000.00  2012
# 239970            False                       False         3,350,000.00  2016
# 239971             True                        True         3,750,000.00  2016
# 239972             True                        True         2,400,000.00  2016
# 239973             True                        True         1,260,000.00  2013
# 239974            False                       False         3,300,000.00  2015
# 239975             True                       False         1,275,000.00  2014
# 239976            False                       False         2,020,000.00  2015
# 239977            False                       False           490,000.00  2015
# 239978            False                       False         1,880,000.00  2016
# 239979             True                        True         3,300,000.00  2016
# 239980            False                       False         3,386,400.00  2016
# 239981             True                        True           550,000.00  2012
# 239982            False                       False           357,000.00  2016
# 239983            False                       False           684,338.00  2016
# 239984             True                        True           505,000.00  2016
# 239985             True                        True         2,700,000.00  2016
# 239986            False                       False         2,079,000.00  2013
# 239987            False                       False           830,000.00  2015
# 239989             True                        True         3,850,000.00  2016
# 239990            False                       False         1,495,000.00  2014
# 239991             True                        True         1,450,000.00  2015
# 239992             True                        True         5,500,000.00  2015
# 239993            False                       False         1,650,000.00  2015
# 239994            False                       False         1,350,000.00  2013
# 239995            False                       False           650,000.00  2015
# 239996             True                        True         1,940,000.00  2014
# 239997            False                       False         3,400,000.00  2015
# 239998             True                        True         2,890,000.00  2014
# 239999            False                       False         3,650,000.00  2015
#
# [213779 rows x 24 columns]

# %% [markdown]
# ### ¿Como evoluciono el porcentaje de propiedades, en Mexico, segun la cantidad de baños, por año?

# %%
anio_agrupado_banos_porcentaje = common.agrupar_calcular_porcentajes_desagrupar(zona_banos,'anio', 'banos')
anio_agrupado_banos_porcentaje.columns = ['anio', 'banos', 'porcentaje_propiedades']
anio_agrupado_banos_porcentaje
# Out:
#     anio  banos  porcentaje_propiedades
# 0   2012      2                   40.65
# 1   2012      1                   31.29
# 2   2012      3                   21.02
# 3   2012      4                    7.04
# 4   2013      2                   41.33
# 5   2013      1                   30.82
# 6   2013      3                   20.86
# 7   2013      4                    6.99
# 8   2014      2                   40.67
# 9   2014      1                   27.76
# 10  2014      3                   22.97
# 11  2014      4                    8.60
# 12  2015      2                   41.76
# 13  2015      1                   25.48
# 14  2015      3                   23.78
# 15  2015      4                    8.97
# 16  2016      2                   40.75
# 17  2016      1                   25.71
# 18  2016      3                   24.02
# 19  2016      4                    9.53

# %%
plot_barplot_anio_banos_porcentaje = sns.barplot(
                                        x = 'anio',
                                        y = 'porcentaje_propiedades',
                                        hue = 'banos',
                                        data = anio_agrupado_banos_porcentaje
                                    )
common.setear_titulos_plot(
    plot_barplot_anio_banos_porcentaje,
    'Barplot : \nPorcentaje de propiedades, en Mexico, segun la \ncantidad de baños, por año de puesta en venta',
    'Año de puesta en venta',
    'Porcentaje de propiedades [%]'
)

plot_barplot_anio_banos_porcentaje.legend(
    title = 'Cantidad \nde Baños',
    loc = [0.95, 0.56]
)
plt.show()

# %%
anio_banos_porcentaje_pivot = anio_agrupado_banos_porcentaje.pivot_table(index = 'banos', columns = 'anio', values = 'porcentaje_propiedades')
anio_banos_porcentaje_pivot
# Out:
# anio                  2012                 2013                 2014  \
# banos
# 1                    31.29                30.82                27.76
# 2                    40.65                41.33                40.67
# 3                    21.02                20.86                22.97
# 4                     7.04                 6.99                 8.60
#
# anio                  2015                 2016
# banos
# 1                    25.48                25.71
# 2                    41.76                40.75
# 3                    23.78                24.02
# 4                     8.97                 9.53

# %%
plot_heatmap_banos_anio_porcentaje = sns.heatmap(
                                        anio_banos_porcentaje_pivot,
                                        cmap = 'Blues',
                                        vmin = 0,
                                        vmax = 40,
                                        cbar_kws={'label': 'Porcentaje de propiedades [%]'}
                                    )
plot_heatmap_banos_anio_porcentaje.invert_yaxis()

common.setear_titulos_plot(
    plot_heatmap_banos_anio_porcentaje,
    'Heatmap : \nPorcentaje de propiedades, en Mexico, \nsegun la cantidad de baños, por año',
    'Año de puesta en venta',
    'Cantidad de baños'
)

plt.show()

# %% [markdown]
# Otra forma de visualizar la misma informacion que en el grafico de barras.

# %% [markdown]
# #### ¿Y en forma de barras apiladas?

# %%
anio_banos_porcentaje_pivot_apilados = anio_banos_porcentaje_pivot.cumsum()
anio_banos_porcentaje_pivot_apilados
# Out:
# anio                  2012                 2013                 2014  \
# banos
# 1                    31.29                30.82                27.76
# 2                    71.94                72.15                68.43
# 3                    92.96                93.01                91.40
# 4                   100.00               100.00               100.00
#
# anio                  2015                 2016
# banos
# 1                    25.48                25.71
# 2                    67.24                66.46
# 3                    91.03                90.47
# 4                   100.00               100.00

# %%
varios_plots_anio_bano_porcentaje_apilados = common.plot_stacked_barplot(
                                                    anio_banos_porcentaje_pivot_apilados, 
                                                    'Cantidad \nde \nbaños', 1, 0.5
                                                ) 

# Titulos 
common.setear_titulos_plot(
    varios_plots_anio_bano_porcentaje_apilados[-1],
    'Stacked Barplot : \nPorcentaje de propiedades, en Mexico, segun la \ncantidad de baños y el año de puesta en venta',
    'Año de puesta en venta',
    'Porcentaje de propiedades [%]'
)

# Agregar porcentajes
common.agregar_valores_stacked_barplot(
    varios_plots_anio_bano_porcentaje_apilados,
    anio_banos_porcentaje_pivot_apilados,
    'w',
    0, -2
)

plt.show()

# %% [markdown]
# ## Banos - Gimnasio

# %% [markdown]
# ### ¿Que es gimnasio?

# %%
zona_banos['gimnasio'].unique()
# Out:
# array([False,  True])

# %%
zona_banos['gimnasio'].dtype
# Out:
# dtype('bool')

# %% [markdown]
# ### ¿Cuantos gimnasio son NaN?

# %%
zona_banos['gimnasio'].isnull().sum()
# Out:
# 0

# %% [markdown]
# No perdemos ningun otro dato.

# %% [markdown]
# ### ¿Cual es el porcentaje de propiedade, en Mexico, segun la cantidad de baños y la presencia de gimnasio?

# %%
banos_agrupados_gimnasio_porcentaje = common.agrupar_calcular_porcentajes_desagrupar(zona_banos, 'banos', 'gimnasio')
banos_agrupados_gimnasio_porcentaje.columns = ['banos', 'tiene_gimnasio', 'porcentaje_propiedades']
banos_agrupados_gimnasio_porcentaje
# Out:
#    banos  tiene_gimnasio  porcentaje_propiedades
# 0      1           False                   97.00
# 1      1            True                    3.00
# 2      2           False                   92.55
# 3      2            True                    7.45
# 4      3           False                   90.86
# 5      3            True                    9.14
# 6      4           False                   91.35
# 7      4            True                    8.65

# %%
banos_gimnasio_porcentaje_para_plot = banos_agrupados_gimnasio_porcentaje.copy()
banos_gimnasio_porcentaje_para_plot = common.columna_bool_a_si_no(
                                        banos_gimnasio_porcentaje_para_plot, 
                                        'tiene_gimnasio'
                                    )
banos_gimnasio_porcentaje_para_plot
# Out:
#    banos tiene_gimnasio  porcentaje_propiedades
# 0      1             No                   97.00
# 1      1             Si                    3.00
# 2      2             No                   92.55
# 3      2             Si                    7.45
# 4      3             No                   90.86
# 5      3             Si                    9.14
# 6      4             No                   91.35
# 7      4             Si                    8.65

# %%
plot_barplot_banos_gimnasio_porcentaje = sns.barplot(
                                            x = 'banos',
                                            y = 'porcentaje_propiedades',
                                            hue = 'tiene_gimnasio',
                                            data = banos_gimnasio_porcentaje_para_plot
                                        )

common.setear_titulos_plot(
    plot_barplot_banos_gimnasio_porcentaje,
    'Barplot : \nPorcentaje de propiedades, en Mexico, segun la \ncantidad de baños y la presencia de gimnasio',
    'Cantidad de baños',
    'Porcentaje de propiedades [%]'
)

plot_barplot_banos_gimnasio_porcentaje.legend(title = 'Tienen gimnasio', loc = [0.9, 0.7])

plt.show()

# %% [markdown]
# En este grafico se aprecia mas que el porcentaje de propiedades con 1 baños y sin gimnasio es mayor que la 4 baños, por ejemplo.

# %%
banos_gimnasio_porcentaje_pivot = banos_gimnasio_porcentaje_para_plot.pivot_table(index = 'tiene_gimnasio', columns = 'banos', values = 'porcentaje_propiedades')
banos_gimnasio_porcentaje_pivot_apilados = banos_gimnasio_porcentaje_pivot.cumsum()
banos_gimnasio_porcentaje_pivot_apilados
# Out:
# banos                             1                    2                    3  \
# tiene_gimnasio
# No                            97.00                92.55                90.86
# Si                           100.00               100.00               100.00
#
# banos                             4
# tiene_gimnasio
# No                            91.35
# Si                           100.00

# %%
varios_plots_banos_gimnasio_porcentaje_apilados = common.plot_stacked_barplot(
                                                        banos_gimnasio_porcentaje_pivot_apilados,
                                                        'Tienen \ngimnasio', 1, 0.7
                                                    )
# Titulos
common.setear_titulos_plot(
    varios_plots_banos_gimnasio_porcentaje_apilados[-1],
    'Stacked Barplot : \nPorcentaje de propiedades, en Mexico, segun la cantidad de \nbaños y la presencia de gimnasio',
    'Cantidad de baños',
    'Porcentaje de propiedades [%]'
)

# Porcentajes
common.agregar_valores_stacked_barplot(
    varios_plots_banos_gimnasio_porcentaje_apilados,
    banos_gimnasio_porcentaje_pivot_apilados,
    'k',
    0, -2
)

plt.show()

# %% [markdown]
# ## Banos - Usosmultiples

# %% [markdown]
# ###  ¿Que es usosmultiples?

# %%
zona_banos['usosmultiples'].unique()
# Out:
# array([False,  True])

# %%
zona_banos['usosmultiples'].dtype
# Out:
# dtype('bool')

# %% [markdown]
# ### ¿Cuantos usosmultiples son NaN?

# %%
zona_banos['usosmultiples'].isnull().sum()
# Out:
# 0

# %% [markdown]
# No perdemos ningun dato mas.

# %% [markdown]
# ### ¿Cual es el porcentaje de propiedades, en Mexico, segun la cantidad de baños y la presencia de usosmultiples?

# %%
banos_agrupados_usosmultiples_porcentaje = common.agrupar_calcular_porcentajes_desagrupar(zona_banos, 'banos', 'usosmultiples')
banos_agrupados_usosmultiples_porcentaje.columns = ['banos','tiene_usosmultiples', 'porcentaje_propiedades']
banos_agrupados_usosmultiples_porcentaje
# Out:
#    banos  tiene_usosmultiples  porcentaje_propiedades
# 0      1                False                   97.87
# 1      1                 True                    2.13
# 2      2                False                   93.60
# 3      2                 True                    6.40
# 4      3                False                   91.59
# 5      3                 True                    8.41
# 6      4                False                   91.22
# 7      4                 True                    8.78

# %%
banos_usosmultiples_porcentaje_para_plot = banos_agrupados_usosmultiples_porcentaje.copy()
banos_usosmultiples_porcentaje_para_plot = common.columna_bool_a_si_no(
                                                banos_usosmultiples_porcentaje_para_plot,
                                                'tiene_usosmultiples'
                                            )
    
banos_usosmultiples_porcentaje_para_plot
# Out:
#    banos tiene_usosmultiples  porcentaje_propiedades
# 0      1                  No                   97.87
# 1      1                  Si                    2.13
# 2      2                  No                   93.60
# 3      2                  Si                    6.40
# 4      3                  No                   91.59
# 5      3                  Si                    8.41
# 6      4                  No                   91.22
# 7      4                  Si                    8.78

# %%
plot_barplot_banos_usosmultiples_porcentaje = sns.barplot(
                                                x = 'banos',
                                                y = 'porcentaje_propiedades',
                                                hue = 'tiene_usosmultiples',
                                                data = banos_usosmultiples_porcentaje_para_plot
                                            )
common.setear_titulos_plot(
    plot_barplot_banos_usosmultiples_porcentaje,
    'Barplot : \nPorcentaje de propiedades, en Mexico, segun la \ncantidad de baños, y la presencia de usos multiples',
    'Cantidad de baños',
    'Porcentaje de propiedades [%]'
)

plot_barplot_banos_usosmultiples_porcentaje.legend(title = 'Tienen \nusos \nmultiples', loc = [0.9, 0.6])

plt.show()

# %%
banos_usosmultiples_porcentaje_pivot = banos_usosmultiples_porcentaje_para_plot.pivot_table(
                                                index = 'tiene_usosmultiples', 
                                                columns = 'banos', 
                                                values = 'porcentaje_propiedades'
                                            ) 
banos_usosmultiples_porcentaje_pivot_apilados = banos_usosmultiples_porcentaje_pivot.cumsum()
banos_usosmultiples_porcentaje_pivot_apilados
# Out:
# banos                                  1                    2  \
# tiene_usosmultiples
# No                                 97.87                93.60
# Si                                100.00               100.00
#
# banos                                  3                    4
# tiene_usosmultiples
# No                                 91.59                91.22
# Si                                100.00               100.00

# %%
varios_plots_apilados_banos_usosmultiples_porcentaje = common.plot_stacked_barplot(
                                                            banos_usosmultiples_porcentaje_pivot_apilados,
                                                            'Tienen \nusos \nmultiples',
                                                            1, 0.64
                                                        )
# Titulos
common.setear_titulos_plot(
    varios_plots_apilados_banos_usosmultiples_porcentaje[-1],
    'Stacked Barplot : \nPorcentaje de propiedades, en Mexico, segun la cantidad de \nbaños y la presencia de usos multiples',
    'Cantidad de baños',
    'Porcentaje de propiedades [%]'
)

# Porcentajes
common.agregar_valores_stacked_barplot(
    varios_plots_apilados_banos_usosmultiples_porcentaje,
    banos_usosmultiples_porcentaje_pivot_apilados,
    'k',
    0, -1.5
)

plt.show()

# %% [markdown]
# ## Banos - Piscina

# %% [markdown]
# ### ¿Que es piscina?

# %%
zona_banos['piscina'].unique()
# Out:
# array([False,  True])

# %%
zona_banos['piscina'].dtype
# Out:
# dtype('bool')

# %% [markdown]
# ### ¿Cuantas piscina son NaN?

# %%
zona_banos['piscina'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### ¿Cual es el porcentaje de propidades, en Mexico, segun la cantidad de baños y la presencia de piscina?

# %%
banos_agrupados_piscina_porcentaje = common.agrupar_calcular_porcentajes_desagrupar(zona_banos, 'banos', 'piscina') 
banos_agrupados_piscina_porcentaje.columns = ['banos', 'tiene_piscina', 'porcentaje_propiedades']
banos_agrupados_piscina_porcentaje
# Out:
#    banos  tiene_piscina  porcentaje_propiedades
# 0      1          False                   96.75
# 1      1           True                    3.25
# 2      2          False                   90.32
# 3      2           True                    9.68
# 4      3          False                   86.65
# 5      3           True                   13.35
# 6      4          False                   86.48
# 7      4           True                   13.52

# %%
banos_piscina_porcentaje_para_plot = banos_agrupados_piscina_porcentaje.copy()
banos_piscina_porcentaje_para_plot = common.columna_bool_a_si_no(
                                        banos_piscina_porcentaje_para_plot,
                                        'tiene_piscina'
                                    )
banos_piscina_porcentaje_para_plot
# Out:
#    banos tiene_piscina  porcentaje_propiedades
# 0      1            No                   96.75
# 1      1            Si                    3.25
# 2      2            No                   90.32
# 3      2            Si                    9.68
# 4      3            No                   86.65
# 5      3            Si                   13.35
# 6      4            No                   86.48
# 7      4            Si                   13.52

# %%
plot_barplot_banos_piscina_porcentaje = sns.barplot(
                                            x = 'banos',
                                            y = 'porcentaje_propiedades',
                                            hue = 'tiene_piscina',
                                            data = banos_piscina_porcentaje_para_plot
                                        )
common.setear_titulos_plot(
    plot_barplot_banos_piscina_porcentaje,
    'Barplot : \nPorcentaje de propiedades, en Mexico, segun la \ncantidad de baños y la presencia de piscina',
    'Cantidad de baños',
    'Porcentaje de propiedades [%]'
)

plot_barplot_banos_piscina_porcentaje.legend(title = 'Tienen \npiscina', loc = [0.9, 0.7])

plt.show()

# %% [markdown]
# A diferencia de graficos anteriores hay un porcentaje levemente mayor de propiedades con 3 y/o 4 baños y con piscina.

# %%
banos_piscina_porcentaje_pivot = banos_piscina_porcentaje_para_plot.pivot_table(
                                                index = 'tiene_piscina', 
                                                columns = 'banos', 
                                                values = 'porcentaje_propiedades'
                                            ) 
banos_piscina_porcentaje_pivot_apilados = banos_piscina_porcentaje_pivot.cumsum()
banos_piscina_porcentaje_pivot_apilados
# Out:
# banos                            1                    2                    3  \
# tiene_piscina
# No                           96.75                90.32                86.65
# Si                          100.00               100.00               100.00
#
# banos                            4
# tiene_piscina
# No                           86.48
# Si                          100.00

# %%
varios_plots_apilados_banos_piscina_porcentaje = common.plot_stacked_barplot(
                                                        banos_piscina_porcentaje_pivot_apilados,
                                                        'Tienen \npiscina',
                                                        1, 0.7
                                                    )
# Titulos
common.setear_titulos_plot(
    varios_plots_apilados_banos_piscina_porcentaje[-1],
    'Stacked Barplot : \Porcentaje de propiedades, en Mexico, \nsegun la cantidad de baños y la presencia de piscina',
    'Cantidad de baños',
    'Porcentaje de propiedades [%]'
)

# Porcentajes
common.agregar_valores_stacked_barplot(
    varios_plots_apilados_banos_piscina_porcentaje,
    banos_piscina_porcentaje_pivot_apilados,
    'k',
    0, -1.5
)

plt.show()

# %% [markdown]
# ## Banos - Escuelascercanas

# %% [markdown]
# ### ¿Que es escuelascercanas?

# %%
zona_banos['escuelascercanas'].unique()
# Out:
# array([False,  True])

# %%
zona_banos['escuelascercanas'].dtype
# Out:
# dtype('bool')

# %% [markdown]
# ### ¿Cuantas escuelascercanas son NaN?

# %%
zona_banos['escuelascercanas'].isnull().sum()
# Out:
# 0

# %% [markdown]
# No perdemos mas datos.

# %% [markdown]
# ### ¿Cual es el porcentaje de propiedades, en Mexico, segun la cantidad de baños y la presencia de escuelas cercanas?

# %%
banos_agrupados_escuelascercanas_porcentaje = common.agrupar_calcular_porcentajes_desagrupar(zona_banos, 'banos', 'escuelascercanas')
banos_agrupados_escuelascercanas_porcentaje.columns = ['banos','tiene_escuelascercanas', 'porcentaje_propiedades']
banos_agrupados_escuelascercanas_porcentaje
# Out:
#    banos  tiene_escuelascercanas  porcentaje_propiedades
# 0      1                   False                   53.06
# 1      1                    True                   46.94
# 2      2                   False                   53.06
# 3      2                    True                   46.94
# 4      3                   False                   54.93
# 5      3                    True                   45.07
# 6      4                   False                   56.87
# 7      4                    True                   43.13

# %%
banos_escuelascercanas_porcentaje_para_plot = banos_agrupados_escuelascercanas_porcentaje.copy()
banos_escuelascercanas_porcentaje_para_plot = common.columna_bool_a_si_no(
                                                    banos_escuelascercanas_porcentaje_para_plot,
                                                    'tiene_escuelascercanas'
                                                )
banos_escuelascercanas_porcentaje_para_plot
# Out:
#    banos tiene_escuelascercanas  porcentaje_propiedades
# 0      1                     No                   53.06
# 1      1                     Si                   46.94
# 2      2                     No                   53.06
# 3      2                     Si                   46.94
# 4      3                     No                   54.93
# 5      3                     Si                   45.07
# 6      4                     No                   56.87
# 7      4                     Si                   43.13

# %%
plot_barplot_banos_escuelascercanas_porcentaje = sns.barplot(
                                                    x = 'banos',
                                                    y = 'porcentaje_propiedades',
                                                    hue = 'tiene_escuelascercanas',
                                                    data = banos_escuelascercanas_porcentaje_para_plot
                                                )
common.setear_titulos_plot(
    plot_barplot_banos_escuelascercanas_porcentaje,
    'Barplot : \nPorcentaje de propiedades, en Mexico, segun la cantidad \nde baños y la presencia de escuelas cercanas',
    'Cantidad de baños',
    'Porcentaje de propiedades [%]'
)

plot_barplot_banos_escuelascercanas_porcentaje.legend(title = 'Tienen \nescuelas \ncercanas', loc = [1, 0.64])

plt.show()

# %%
banos_escuelascercanas_porcentaje_pivot = banos_escuelascercanas_porcentaje_para_plot.pivot_table(
                                                index = 'tiene_escuelascercanas', 
                                                columns = 'banos', 
                                                values = 'porcentaje_propiedades'
                                            ) 
banos_escuelascercanas_porcentaje_pivot_apilados = banos_escuelascercanas_porcentaje_pivot.cumsum()
banos_escuelascercanas_porcentaje_pivot_apilados
# Out:
# banos                                     1                    2  \
# tiene_escuelascercanas
# No                                    53.06                53.06
# Si                                   100.00               100.00
#
# banos                                     3                    4
# tiene_escuelascercanas
# No                                    54.93                56.87
# Si                                   100.00               100.00

# %%
varios_plots_apilados_banos_escuelascercanas_porcentaje = common.plot_stacked_barplot(
                                                                banos_escuelascercanas_porcentaje_pivot_apilados,
                                                                'Tienen \nescuelas \ncercanas',
                                                                1, 0.64
                                                            )
# Titulos
common.setear_titulos_plot(
    varios_plots_apilados_banos_escuelascercanas_porcentaje[-1],
    'Stacked Barplot : \nPorcentaje de propiedades, en Mexico, segun la cantidad de \nbaños y la presencia de escuelas cercanas',
    'Cantidad de baños',
    'Porcentaje de propiedades [%]'
)

# Porcentajes
common.agregar_valores_stacked_barplot(
    varios_plots_apilados_banos_escuelascercanas_porcentaje,
    banos_escuelascercanas_porcentaje_pivot_apilados,
    'k',
    0, -1.5
)

plt.show()

# %% [markdown]
# ## Banos - Centroscomercialescercanos

# %% [markdown]
# ### ¿Que es centroscomercialescercanos?

# %%
zona_banos['centroscomercialescercanos'].unique()
# Out:
# array([False,  True])

# %% [markdown]
# ### ¿Cuantos centroscomercialescercanos son NaN?

# %%
zona_banos['centroscomercialescercanos'].isnull().sum()
# Out:
# 0

# %% [markdown]
# No perdemos mas datos.

# %% [markdown]
# ### ¿Cual es el porcenteja de propiedades, en Mexico, tienen centros comerciales cercanos, segun la cantidad de baños?

# %% [markdown]
# Apply aplica una funcion a toda la serie.
# Transform aplica una funcion a cada elemento de la serie.

# %%
banos_agrupados_centroscomercialescercanos_porcentaje = common.agrupar_calcular_porcentajes_desagrupar(zona_banos,'banos', 'centroscomercialescercanos')
banos_agrupados_centroscomercialescercanos_porcentaje.columns = ['banos', 'tiene_centroscomercialescercanos', 'porcentaje_propiedades']
banos_agrupados_centroscomercialescercanos_porcentaje
# Out:
#    banos  tiene_centroscomercialescercanos  porcentaje_propiedades
# 0      1                             False                   57.75
# 1      1                              True                   42.25
# 2      2                             False                   57.79
# 3      2                              True                   42.21
# 4      3                             False                   60.18
# 5      3                              True                   39.82
# 6      4                             False                   62.33
# 7      4                              True                   37.67

# %%
banos_centroscomercialescercanos_porcentaje_para_plot = banos_agrupados_centroscomercialescercanos_porcentaje.copy()
banos_centroscomercialescercanos_porcentaje_para_plot = common.columna_bool_a_si_no(
                                                            banos_centroscomercialescercanos_porcentaje_para_plot,
                                                            'tiene_centroscomercialescercanos'
                                                        )
banos_centroscomercialescercanos_porcentaje_para_plot
# Out:
#    banos tiene_centroscomercialescercanos  porcentaje_propiedades
# 0      1                               No                   57.75
# 1      1                               Si                   42.25
# 2      2                               No                   57.79
# 3      2                               Si                   42.21
# 4      3                               No                   60.18
# 5      3                               Si                   39.82
# 6      4                               No                   62.33
# 7      4                               Si                   37.67

# %%
plot_barplot_banos_centroscomercialescercanos = sns.barplot(
                                                    x = 'banos',
                                                    y = 'porcentaje_propiedades',
                                                    hue = 'tiene_centroscomercialescercanos',
                                                    data = banos_centroscomercialescercanos_porcentaje_para_plot
                                                )
common.setear_titulos_plot(
    plot_barplot_banos_centroscomercialescercanos,
    'Barplot : \nPorcentaje de propiedades, en Mexico, segun la cantidad \nde baños y la presencia de centros comerciales cercanos',
    'Cantidad de baños',
    'Porcentaje de propiedades'
)

plot_barplot_banos_centroscomercialescercanos.legend(
    title = 'Tiene \ncentros \ncomerciales \ncercanos',
    loc = [0.9, 0.58]
)

plt.show()

# %% [markdown]
# Tal se podria hacer un "stacked bar chart", luego.

# %%
banos_centroscomercialescercanos_porcentaje_pivot = banos_centroscomercialescercanos_porcentaje_para_plot.pivot_table(
                                                index = 'tiene_centroscomercialescercanos', 
                                                columns = 'banos', 
                                                values = 'porcentaje_propiedades'
                                            ) 
banos_centroscomercialescercanos_porcentaje_pivot_apilados = banos_centroscomercialescercanos_porcentaje_pivot.cumsum()
banos_centroscomercialescercanos_porcentaje_pivot_apilados
# Out:
# banos                                               1                    2  \
# tiene_centroscomercialescercanos
# No                                              57.75                57.79
# Si                                             100.00               100.00
#
# banos                                               3                    4
# tiene_centroscomercialescercanos
# No                                              60.18                62.33
# Si                                             100.00               100.00

# %%
varios_plots_apilados_banos_centroscomercialescercanos_porcentaje = common.plot_stacked_barplot(
                                                                        banos_centroscomercialescercanos_porcentaje_pivot_apilados,
                                                                        'Tienen \ncentros \ncomerciales \ncercanos',
                                                                        1, 0.58
                                                                    )
# Titulos
common.setear_titulos_plot(
    varios_plots_apilados_banos_centroscomercialescercanos_porcentaje[-1],
    'Stacked Barplot : \nPorcentaje de propiedades, en Mexico, segun la cantidad de \nbaños y la presencia de centros comerciales cercanos',
    'Cantidad de baños',
    'Porcentaje de propiedades [%]'
)

# Porcentajes
common.agregar_valores_stacked_barplot(
    varios_plots_apilados_banos_centroscomercialescercanos_porcentaje,
    banos_centroscomercialescercanos_porcentaje_pivot_apilados,
    'k',
    0, -1.5
)

plt.show()

# %% [markdown]
# ## Banos - Precio

# %% [markdown]
# ### ¿Que es precio?

# %%
zona_banos['precio'].unique()
# Out:
# array([2273000., 3600000., 1200000., ..., 1794000., 3386400.,  684338.])

# %%
zona_banos['precio'].dtype
# Out:
# dtype('float32')

# %% [markdown]
# ### ¿Cuantos precio son NaN?

# %%
zona_banos['precio'].isnull().sum()
# Out:
# 0

# %% [markdown]
# No perdemos datos en el analisis de la relacion con este campo.

# %% [markdown]
# ### ¿Como se distribuye el precio de las propiedades en Mexico, segun la cantidad de baños?

# %%
banos_agrupados_precio_estadisticas = common.agrupar_calcular_estadisticas_desagrupar(zona_banos, 'banos', 'precio')
banos_agrupados_precio_estadisticas
# Out:
#    banos     precio_cuantil_1        precio_median     precio_cuantil_3
# 0      1           500,000.00           745,000.00         1,200,000.00
# 1      2         1,250,000.00         1,850,000.00         2,900,000.00
# 2      3         1,990,000.00         3,050,000.00         4,800,000.00
# 3      4         2,800,000.00         3,899,500.00         5,620,000.00

# %%
plot_boxplot_banos_precio = sns.boxplot(
                                x = 'banos',
                                y = 'precio',
                                data = zona_banos
                            )
#Titulos
common.setear_titulos_plot(
    plot_boxplot_banos_precio,
    'Barplot : \nDitribucion de precio de las propiedades, \nen Mexico, segun la cantidad de baños',
    'Cantidad de baños',
    'Precio [pesos mexicanos]'
)

# Seteo limite en el eje y para mejorar visualizacion
plot_boxplot_banos_precio.set_ylim(0,10000000)

# Elimino notacion cientifica del eje y
plot_boxplot_banos_precio.ticklabel_format(style = 'plain', axis = 'y')

common.agregar_serie_plot(
    plot_boxplot_banos_precio,
    banos_agrupados_precio_estadisticas['precio_median'],
    banos_agrupados_precio_estadisticas['precio_median'],
    'w',
    0, 50000
)

plt.show()

# %% [markdown]
# #### ¿Cual es la distribucion de precios de las propiedades, en Mexico, segun 1 y 2 baños ?

# %%
banos_1_2_agrupados_precio_estadisticas = banos_agrupados_precio_estadisticas.loc[
                                            banos_agrupados_precio_estadisticas['banos'].isin([1,2])
                                        ]
banos_1_2_agrupados_precio_estadisticas
# Out:
#    banos     precio_cuantil_1        precio_median     precio_cuantil_3
# 0      1           500,000.00           745,000.00         1,200,000.00
# 1      2         1,250,000.00         1,850,000.00         2,900,000.00

# %%
plot_boxplot_banos_1_2_precio = sns.boxplot(
                                x = 'banos',
                                y = 'precio',
                                data = zona_banos.loc[zona_banos['banos'].isin([1,2])]
                            )
#Titulos
common.setear_titulos_plot(
    plot_boxplot_banos_1_2_precio,
    'Barplot : \nDitribucion de precio de las propiedades, \nen Mexico, segun 1 y 2 de baños',
    'Cantidad de baños',
    'Precio [pesos mexicanos]'
)

# Seteo limite en el eje y para mejorar visualizacion
plot_boxplot_banos_1_2_precio.set_ylim(0,5500000)

# Elimino notacion cientifica del eje y
plot_boxplot_banos_1_2_precio.ticklabel_format(style = 'plain', axis = 'y')

# Agrego cuantiles y medianas
common.agregar_serie_plot(
    plot_boxplot_banos_1_2_precio,
    banos_1_2_agrupados_precio_estadisticas['precio_cuantil_1'],
    banos_1_2_agrupados_precio_estadisticas['precio_cuantil_1'],
    'w',
    -0.27, 50000
)

common.agregar_serie_plot(
    plot_boxplot_banos_1_2_precio,
    banos_1_2_agrupados_precio_estadisticas['precio_median'],
    banos_1_2_agrupados_precio_estadisticas['precio_median'],
    'w',
    0, 50000
)

common.agregar_serie_plot(
    plot_boxplot_banos_1_2_precio,
    banos_1_2_agrupados_precio_estadisticas['precio_cuantil_3'],
    banos_1_2_agrupados_precio_estadisticas['precio_cuantil_3'],
    'k',
    0.25, 50000
)

plt.show()

# %% [markdown]
# #### ¿Cual es la distribucion de precio de las propiedades, en Mexico, segun 3 y 4 baños?

# %%
banos_3_4_agrupados_precio_estadisticas = banos_agrupados_precio_estadisticas.loc[
                                            banos_agrupados_precio_estadisticas['banos'].isin([3,4])
                                        ]
banos_3_4_agrupados_precio_estadisticas
# Out:
#    banos     precio_cuantil_1        precio_median     precio_cuantil_3
# 2      3         1,990,000.00         3,050,000.00         4,800,000.00
# 3      4         2,800,000.00         3,899,500.00         5,620,000.00

# %%
plot_boxplot_banos_3_4_precio = sns.boxplot(
                                x = 'banos',
                                y = 'precio',
                                data = zona_banos.loc[zona_banos['banos'].isin([3,4])],
                                palette = sns.color_palette(COLORES_BARRAS)[2:4]
                            )
#Titulos
common.setear_titulos_plot(
    plot_boxplot_banos_3_4_precio,
    'Barplot : \nDitribucion de precio de las propiedades, \nen Mexico, segun 3 y 4 de baños',
    'Cantidad de baños',
    'Precio [pesos mexicanos]'
)

# Seteo limite en el eje y para mejorar visualizacion
plot_boxplot_banos_3_4_precio.set_ylim(0,10000000)

# Elimino notacion cientifica del eje y
plot_boxplot_banos_3_4_precio.ticklabel_format(style = 'plain', axis = 'y')

# Agrego cuantiles y medianas
common.agregar_serie_plot(
    plot_boxplot_banos_3_4_precio,
    banos_3_4_agrupados_precio_estadisticas['precio_cuantil_1'],
    banos_3_4_agrupados_precio_estadisticas['precio_cuantil_1'],
    'w',
    -0.27, 50000
)

common.agregar_serie_plot(
    plot_boxplot_banos_3_4_precio,
    banos_3_4_agrupados_precio_estadisticas['precio_median'],
    banos_3_4_agrupados_precio_estadisticas['precio_median'],
    'w',
    0, 50000
)

common.agregar_serie_plot(
    plot_boxplot_banos_3_4_precio,
    banos_3_4_agrupados_precio_estadisticas['precio_cuantil_3'],
    banos_3_4_agrupados_precio_estadisticas['precio_cuantil_3'],
    'k',
    0.25, 50000
)

plt.show()
