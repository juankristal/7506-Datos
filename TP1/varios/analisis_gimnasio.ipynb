# %% [markdown]
# # Analisis de campo 'gimnasio'

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import common.common_pandas_lib as common

# %% [markdown]
# ## Configuraciones

# %% [markdown]
# ### Configuraciones librerias graficas y plots

# %%
COLORES_BARRAS = 'colorblind'
# %matplotlib inline

plt.style.use('default') # haciendo los graficos un poco mas bonitos en matplotlib
plt.rcParams['figure.figsize'] = (18, 8)

sns.set(style="whitegrid", font_scale = 2) # seteando tipo de grid en seaborn
                                           # seteando tamanio de ticks label
sns.set_palette(COLORES_BARRAS)
pd.options.display.float_format = '{:20,.2f}'.format # suprimimos la notacion cientifica en los outputs

# %% [markdown]
# ## Carga optimizada del set de datos

# %%
zona_prop = common.cargar_train_optimizado('train.csv')

# %% [markdown]
# ## Gimnasio

# %% [markdown]
# ## ¿Que valores toma gimnasio?

# %%
zona_prop['gimnasio'].unique()
# Out:
# array([False,  True])

# %% [markdown]
# ## ¿Cuantos datos del set tienen gimansio limpio?

# %%
zona_prop['gimnasio'].isnull().sum()
# Out:
# 0

# %% [markdown]
# No necesitamos descartar ningun dato, en ppio.

# %%
zona_gimnasio = zona_prop.copy() # Para poder realizar modifcaciones sin que pandas se queje

# %% [markdown]
# ## Gimnasio - Antiguedad

# %% [markdown]
# ## Gimnasio - Fecha

# %% [markdown]
# ### ¿Cuantos datos perdemos al descartar fechas NaN?

# %%
zona_gimnasio['fecha'].isnull().sum()
# Out:
# 0

# %% [markdown]
# No perdemos ningun dato.

# %% [markdown]
# ### ¿Como evoluciono el porcentaje de propiedades, en Mexico, segun la presencia de gimnasio con el pasar de los años?

# %%
zona_gimnasio['anio'] = zona_gimnasio['fecha'].dt.year
zona_gimnasio
# Out:
#             id                                             titulo  \
# 0       254099                                  depto. tipo a-402
# 1        53461                     condominio horizontal en venta
# 2       247984              casa en venta urbi 3 recamaras tonala
# 3       209067  casa sola en toluca zinacantepec con credito i...
# 4       185997                                     paseos del sol
# 5       126147                     departamento en venta taxqueña
# 6       139233                 de oportunidad casa en san lorenzo
# 7         5013  casa emilia en venta en selvamar playa del carmen
# 8        44962  pre- venta preciosos depas 2 recamaras con sub...
# 9       134537                                            terreno
# 10       51180                                      mi 2° credito
# 11      103293  departamento en venta, san pedro garza garcia,...
# 12       47890             hermosa casa en zibata queretaro 170m²
# 13      130216                 casa matias romero - sión bancaria
# 14      181436                        casa en venta en valle real
# 15      201923               casa en venta lomas verdes naucalpan
# 16      283945               preciosa casa en cumbres del lago \t
# 17       73348  oportunidad, departamento col del valle, 3 rec...
# 18       40421  últimos terrenos en preventa!! en bukara coto ...
# 19       87655                                                NaN
# 20       90071  terreno residencial en venta en cumbres quinta...
# 21      224513                         casa en venta en querétaro
# 22      129818  comoda casa con recamara en planta baja y ampl...
# 23      146699  casa en condominio en venta, benito juarez, ca...
# 24      235958  casa en venta - colinas del cimatario, queréta...
# 25       97918                           casa venta santa cecilia
# 26       70294  casa en venta de un nivel , frac. misiones de ...
# 27      177031                                                NaN
# 28      144635                      casa en venta en santillana i
# 29      146158              terreno urbano bardeado zona tesistán
# ...        ...                                                ...
# 239970  123855  residencia en las cañadas, gran oportunidad pa...
# 239971    2747  departamento exclusivo para tu familia, vive b...
# 239972  130523           casa para remodelar, excelente ubicación
# 239973  149503           departamento en venta en villa de cortes
# 239974  156730  casa en venta, cuautitlán izcalli, estado de m...
# 239975  258795  casa en uno de los desarrollos con mayor plusv...
# 239976  184779                        casa en venta en campanario
# 239977  214176                                       casa tecamac
# 239978  235796    linda casa en venta,cerca del lago de guadalupe
# 239979  103355         se vende casa en delegacion miguel hidalgo
# 239980  267455              departamentos en renta torres palmira
# 239981  199041         casa en venta en residencial agua caliente
# 239982  252709  casa de 2 recamaras en residencial del bosque ...
# 239983  194027                   casa en venta en san luis potosí
# 239984  262913        en venta mitras centro monterrey nuevo leon
# 239985   64820  casa en venta fuentes de satelite, atizapan, e...
# 239986   41090  excelete torre de departamentos en lomas 4ta s...
# 239987  278167                                                NaN
# 239988  191335                                bodega santa maría
# 239989  175203               casa venta renta en rinconada jurica
# 239990   87498                  casa en venta: bosques del contry
# 239991  137337                    departamento residencial coyuya
# 239992   54886                                      casa en venta
# 239993  207892                               bugambilias (ciudad)
# 239994  110268               hermosa casa en villa de los belenes
# 239995  119879  bonita casas de 2 recamaras a 10 minutos del c...
# 239996  259178  casa en condominio a 10 min. del centro de toluca
# 239997  131932                                   nicolas san juan
# 239998  146867                      casa sola. javier rojo gomez.
# 239999  121958  departamento en bosques de las lomas  / av. st...
#
#                                               descripcion     tipodepropiedad  \
# 0       depto. interior de 80.15m2, consta de sala com...         Apartamento
# 1       <p>entre sonora y guerrero, atr&aacute;s del h...  Casa en condominio
# 2       descripcion \nla mejor ubicacion residencial e...                Casa
# 3       casa en privada con caseta de vigilancia casas...                Casa
# 4       bonito departamento en excelentes condiciones ...         Apartamento
# 5       amplio departamento, estancia de sala y comedo...         Apartamento
# 6       ubicada en esquina, pertenece san lorenzo agen...                Casa
# 7       casa emilia en venta playa del carmenfracciona...                Casa
# 8       <p>pre-venta de preciosos departamento ecologi...         Apartamento
# 9       terreno de 5.500m2 bardeado, uso de suelo h-20...             Terreno
# 10      <p>mi 2&deg; credito<br />para todos aquellos ...                Casa
# 11      departamento nuevo ,256 m2 de construccion,un ...         Apartamento
# 12      <p><strong>casa </strong>en venta en fracciona...                Casa
# 13      flamante casa habitación en condominio horizon...                Casa
# 14      pre venta de residencia en la toscana con exce...                Casa
# 15      <p>casa en dos niveles, 3 recámaras la princip...                Casa
# 16      <p>clave: vcln2450 fecha de actualizaci&oacute...                Casa
# 17      magnifico departamento con excelente distribuc...         Apartamento
# 18      terreno ubicado en bukara coto club, el cual s...             Terreno
# 19      -- rcv151104-lv-27 --    linda casa con area d...                Casa
# 20      <p>excelente terreno plano, frente a parque en...             Terreno
# 21      nocnok id: mx15-bk0340. hermosa casa en conjun...  Casa en condominio
# 22      <p>comoda casa con recamara en planta baja y a...                Casa
# 23      casa en venta en cancun en residencial cumbres...  Casa en condominio
# 24      <p>propiedad en un nivel, con espacios amplios...                Casa
# 25      hermosa casa en santa cecilia en apodaca, cerc...                Casa
# 26      ¡excelente oportunidad!  \n\ncasa de un nivel ...  Casa en condominio
# 27      hermosa casa remodelada, con acabados de lujo,...  Casa en condominio
# 28      casa en coto 3 recamaras, estudio, sala-comedo...  Casa en condominio
# 29      en zona de urbanización progresiva, terreno pl...   Terreno comercial
# ...                                                   ...                 ...
# 239970  residencia en las cañadas, una gran oportunida...                Casa
# 239971  www. \n3 recamaras, 2 baños \n2 autos \nentreg...         Apartamento
# 239972  estado de conservación: para remodelar, área d...                Casa
# 239973  últimos departamentos en preventa dentro de ex...         Apartamento
# 239974  casa en venta en lago de guadalupe. excelente ...                Casa
# 239975  <p>el desarrollo cuenta con barda perimetral c...                Casa
# 239976  bonita y bien ubicada casa en venta, 3 recamar...                Casa
# 239977  hermosa casa, en excelente mantenimiento y muy...                Casa
# 239978  buen proyecto, desarrollada en tres plantas, p...                Casa
# 239979  excelente casa muy bien ubicada en zona tranqu...                Casa
# 239980  departamento en venta avenida palmira , san lu...         Apartamento
# 239981  se vende bonita casa en el fracc. residencial ...                Casa
# 239982  casa de 2 recámaras en residencial del bosque ...                Casa
# 239983  nocnok id: mx16-bo3390. sin posesión física, p...                Casa
# 239984   en excelente ubicación zona mitras centro. am...                Casa
# 239985  casa en venta fuentes de satélite, atizapán, e...  Casa en condominio
# 239986  <p>exclusiva torre de departamentos en venta e...         Apartamento
# 239987  -- rcv347n-287 --    casas nuevas estilo minim...                Casa
# 239988  ideal para inversionista \nideal centro de dis...    Bodega comercial
# 239989  terreno 404m2 \nconst. 347 m2 \n\npreciosa cas...                Casa
# 239990  <p>casa en venta, en magníficas condiciones; e...                Casa
# 239991  departamento ubicado en planta baja, con excel...         Apartamento
# 239992  bonita casa para remodelar en una calle cerrad...  Casa en condominio
# 239993  coto privado de tan solo 7 casas donde cada fa...                Casa
# 239994  <p>moderna casa 3 pisos, muro llor&oacute;n , ...                Casa
# 239995  vendo casa en bosques de ica residencial a 10 ...                Casa
# 239996  casa con un jardin amplio, un cuarto de servic...                Casa
# 239997  departamento con excelente ubicación, muy cerc...         Apartamento
# 239998  casa sola, dividida en cuatro departamentos de...                Casa
# 239999  id:19816, muy bonito e iluminado departamento,...         Apartamento
#
#                                                 direccion  \
# 0                         Avenida Division del Norte 2005
# 1                                              AV. MEXICO
# 2                                             Urbi Tonala
# 3                           IGNACIO MANUEL ALTAMIRANO 128
# 4                                         PASEOS DEL SOL
# 5                                   Condominio Tlalpan 2B
# 6                                                     NaN
# 7                                    condominio el trebol
# 8                          BUENAVISTA DEPTOS CON SUBSIDIO
# 9                                             Av. Morelos
# 10                                          MI 2° CREDITO
# 11                                                    NaN
# 12                               Pitahayas 2 - 58, Zibata
# 13                       MATIAS ROMERO, COLONIA DEL VALLE
# 14                                                    NaN
# 15                                                    NaN
# 16         CUMBRES DEL LAGO JURIQUILLA, QUERETARO, MEXICO
# 17                                      Pazaje Santa Cruz
# 18                                                Milenio
# 19                                     SENDA CELESTIAL 10
# 20               TERRENO RESIDENCIAL EN VENTA EN CUMBRES
# 21                                                    NaN
# 22                                                    NaN
# 23                                                    NaN
# 24                           Colinas del Cimatario   C721
# 25                                          Lopez Velarde
# 26                              MISIONES DE SAN FRANCISCO
# 27                                  PASEO DE LOS LAURELES
# 28                             Coto Santillana I Casa G11
# 29                                camino viejo a Tesistan
# ...                                                   ...
# 239970                       Paseo de los fambruesos 3150
# 239971                                              TOKIO
# 239972                                  Albino Garcia 219
# 239973                                  Pérez de León  61
# 239974                                                NaN
# 239975                                                NaN
# 239976                                                NaN
# 239977                                    AV RANCHO NUEVO
# 239978                                                NaN
# 239979                                         Rio Parana
# 239980                                                NaN
# 239981                                      PRIV. VENECIA
# 239982                                                NaN
# 239983                                                NaN
# 239984                                PROGRESO, MONTERREY
# 239985    FUENTES DE SATÉLITE, ATIZAPÁN, ESTADO DE MÉXICO
# 239986                                                NaN
# 239987                                  Primero de mayo 5
# 239988                                       SANTA MARIA
# 239989                                             Jurica
# 239990                                                NaN
# 239991                                         Coyuya 200
# 239992                            Cerrada villa Picadilly
# 239993                                 Paseo de la Cañada
# 239994  MANUEL AMAYA,ENTRE SEBASTIAN ALLENDE Y AMADO A...
# 239995                                            BOSQUES
# 239996                                Filiberto Navas 325
# 239997                                   Nicolas San Juan
# 239998                              Javier Rojo Gomez 120
# 239999                                          AVE. STIM
#
#                         ciudad              provincia           antiguedad  \
# 0                Benito Juárez       Distrito Federal                  nan
# 1       La Magdalena Contreras       Distrito Federal                10.00
# 2                       Tonalá                Jalisco                 5.00
# 3                 Zinacantepec         Edo. de México                 1.00
# 4                      Zapopan                Jalisco                10.00
# 5                     Coyoacán       Distrito Federal                 5.00
# 6             Oaxaca de Juárez                 Oaxaca                  nan
# 7             Playa del Carmen           Quintana Roo                 2.00
# 8             Villa de Alvarez                 Colima                 1.00
# 9                   Ixtapaluca         Edo. de México                  nan
# 10             San Luis Potosí        San luis Potosí                 0.00
# 11      San Pedro Garza García             Nuevo León                  nan
# 12                   Querétaro              Querétaro                 0.00
# 13               Benito Juárez       Distrito Federal                20.00
# 14                     Zapopan                Jalisco                  nan
# 15         Naucalpan de Juárez         Edo. de México                  nan
# 16                   Querétaro              Querétaro                 0.00
# 17               Benito Juárez       Distrito Federal                 5.00
# 18                   Querétaro              Querétaro                  nan
# 19                   Querétaro              Querétaro                 0.00
# 20                   Monterrey             Nuevo León                 0.00
# 21                   Querétaro              Querétaro                  nan
# 22               Ciudad Madero             Tamaulipas                 0.00
# 23                      Cancún           Quintana Roo                 4.00
# 24                   Querétaro              Querétaro                 4.00
# 25                     Apodaca             Nuevo León                 8.00
# 26                      Puebla                 Puebla                 3.00
# 27              Miguel Hidalgo       Distrito Federal                18.00
# 28                     Zapopan                Jalisco                 1.00
# 29                     Zapopan                Jalisco                20.00
# ...                        ...                    ...                  ...
# 239970                 Zapopan                Jalisco                10.00
# 239971           Benito Juárez       Distrito Federal                 4.00
# 239972              Cuauhtémoc       Distrito Federal                20.00
# 239973           Benito Juárez       Distrito Federal                 1.00
# 239974      Cuautitlán Izcalli         Edo. de México                 4.00
# 239975               Querétaro              Querétaro                  nan
# 239976               Chihuahua              Chihuahua                  nan
# 239977                 Tecámac         Edo. de México                 5.00
# 239978    Atizapán de Zaragoza         Edo. de México                  nan
# 239979          Miguel Hidalgo       Distrito Federal                10.00
# 239980         San Luis Potosí        San luis Potosí                 1.00
# 239981                 Tijuana  Baja California Norte                10.00
# 239982                 Tijuana  Baja California Norte                  nan
# 239983         San Luis Potosí        San luis Potosí                  nan
# 239984               Monterrey             Nuevo León                20.00
# 239985    Atizapán de Zaragoza         Edo. de México                10.00
# 239986         San Luis Potosí        San luis Potosí                 0.00
# 239987           Cuautlancingo                 Puebla                 0.00
# 239988             Guadalajara                Jalisco                 5.00
# 239989               Querétaro              Querétaro                 2.00
# 239990               Guadalupe             Nuevo León                20.00
# 239991               Iztacalco       Distrito Federal                20.00
# 239992            Huixquilucan         Edo. de México                10.00
# 239993                 Zapopan                Jalisco                 1.00
# 239994                 Zapopan                Jalisco                 3.00
# 239995            Zinacantepec         Edo. de México                 0.00
# 239996                  Toluca         Edo. de México                 0.00
# 239997           Benito Juárez       Distrito Federal                20.00
# 239998              Iztapalapa       Distrito Federal                20.00
# 239999   Cuajimalpa de Morelos       Distrito Federal                 1.00
#
#                habitaciones              garages  ...                  lat  \
# 0                      2.00                 1.00  ...                  nan
# 1                      3.00                 2.00  ...                19.31
# 2                      3.00                 2.00  ...                  nan
# 3                      2.00                 1.00  ...                19.30
# 4                      2.00                 1.00  ...                  nan
# 5                      2.00                 1.00  ...                19.30
# 6                      3.00                 1.00  ...                17.14
# 7                      4.00                 2.00  ...                20.67
# 8                      2.00                 1.00  ...                  nan
# 9                       nan                  nan  ...                19.32
# 10                     3.00                 1.00  ...                22.20
# 11                     3.00                 2.00  ...                  nan
# 12                     3.00                 2.00  ...                20.68
# 13                      nan                 0.00  ...                19.37
# 14                      nan                 2.00  ...                20.73
# 15                     3.00                 2.00  ...                19.52
# 16                     3.00                 2.00  ...                20.71
# 17                     3.00                 2.00  ...                  nan
# 18                      nan                 0.00  ...                  nan
# 19                     3.00                 2.00  ...                  nan
# 20                      nan                 0.00  ...                  nan
# 21                     3.00                 2.00  ...                  nan
# 22                     4.00                  nan  ...                22.26
# 23                     3.00                 2.00  ...                21.11
# 24                     3.00                  nan  ...                20.56
# 25                     3.00                 2.00  ...                  nan
# 26                     2.00                 1.00  ...                  nan
# 27                     3.00                 3.00  ...                  nan
# 28                     3.00                 2.00  ...                20.71
# 29                      nan                 0.00  ...                20.78
# ...                     ...                  ...  ...                  ...
# 239970                 5.00                 3.00  ...                20.79
# 239971                 3.00                 2.00  ...                19.37
# 239972                 5.00                 2.00  ...                19.40
# 239973                 2.00                 1.00  ...                  nan
# 239974                 3.00                  nan  ...                19.63
# 239975                 3.00                 2.00  ...                20.65
# 239976                 3.00                 0.00  ...                  nan
# 239977                 1.00                 1.00  ...                  nan
# 239978                 3.00                 2.00  ...                19.60
# 239979                 3.00                 2.00  ...                19.46
# 239980                 2.00                  nan  ...                16.75
# 239981                 2.00                 1.00  ...                32.49
# 239982                 2.00                 1.00  ...                32.51
# 239983                 3.00                  nan  ...                22.16
# 239984                 2.00                 1.00  ...                25.70
# 239985                 3.00                 2.00  ...                  nan
# 239986                 3.00                 2.00  ...                  nan
# 239987                 3.00                 2.00  ...                  nan
# 239988                  nan                 0.00  ...                20.62
# 239989                 3.00                 2.00  ...                20.65
# 239990                 3.00                 2.00  ...                25.66
# 239991                 2.00                 1.00  ...                19.40
# 239992                 3.00                  nan  ...                  nan
# 239993                 3.00                 2.00  ...                20.62
# 239994                 2.00                 2.00  ...                20.60
# 239995                 2.00                 2.00  ...                  nan
# 239996                 3.00                 3.00  ...                19.29
# 239997                 2.00                 1.00  ...                  nan
# 239998                 4.00                 0.00  ...                19.37
# 239999                 3.00                 2.00  ...                  nan
#
#                         lng      fecha  gimnasio  usosmultiples  piscina  \
# 0                       nan 2015-08-23     False          False    False
# 1                    -99.23 2013-06-28     False          False    False
# 2                       nan 2015-10-17     False          False    False
# 3                    -99.69 2012-03-09     False          False    False
# 4                       nan 2016-06-07     False          False    False
# 5                    -99.15 2014-03-18     False          False    False
# 6                    -96.80 2016-02-23     False          False    False
# 7                    -87.04 2016-10-20     False          False    False
# 8                       nan 2014-01-06     False          False    False
# 9                    -98.89 2016-12-22     False          False    False
# 10                  -101.02 2013-01-03     False          False    False
# 11                      nan 2014-12-01     False          False    False
# 12                  -100.32 2013-08-12     False           True    False
# 13                   -99.15 2015-03-31     False          False    False
# 14                  -103.43 2014-11-25     False          False    False
# 15                   -99.26 2015-01-13     False          False    False
# 16                  -100.46 2013-03-06     False          False    False
# 17                      nan 2016-10-30     False          False    False
# 18                      nan 2016-12-03     False          False     True
# 19                      nan 2016-01-15     False          False    False
# 20                      nan 2013-12-02     False          False    False
# 21                      nan 2016-02-01     False          False    False
# 22                   -97.84 2013-12-12     False          False    False
# 23                   -86.85 2015-05-19     False          False    False
# 24                  -100.37 2013-09-26     False          False    False
# 25                      nan 2016-12-31     False          False    False
# 26                      nan 2014-07-22     False          False    False
# 27                      nan 2012-03-07     False          False    False
# 28                  -103.45 2015-01-20     False          False    False
# 29                  -103.48 2016-12-03     False          False    False
# ...                     ...        ...       ...            ...      ...
# 239970              -103.36 2016-12-11     False          False     True
# 239971               -99.15 2016-12-19     False          False    False
# 239972               -99.13 2016-01-19     False          False    False
# 239973                  nan 2013-02-05     False          False    False
# 239974               -99.25 2015-08-05     False          False    False
# 239975              -100.35 2014-04-03     False          False    False
# 239976                  nan 2015-02-09     False          False    False
# 239977                  nan 2015-04-12     False          False    False
# 239978               -99.25 2016-10-24     False          False    False
# 239979               -99.21 2016-03-04     False          False    False
# 239980               -93.09 2016-12-03     False          False    False
# 239981              -116.99 2012-11-20     False          False    False
# 239982              -116.84 2016-02-05     False          False    False
# 239983              -100.97 2016-02-09     False          False    False
# 239984              -100.34 2016-07-30     False          False    False
# 239985                  nan 2016-12-07     False          False    False
# 239986                  nan 2013-09-07     False          False    False
# 239987                  nan 2015-10-28     False          False    False
# 239988              -103.37 2015-11-20     False          False    False
# 239989              -100.43 2016-09-15     False           True     True
# 239990              -100.25 2014-04-12     False          False    False
# 239991               -99.12 2015-03-14     False          False    False
# 239992                  nan 2015-11-23     False          False    False
# 239993              -103.46 2015-03-22     False          False    False
# 239994              -103.45 2013-07-31     False          False    False
# 239995                  nan 2015-02-08     False          False    False
# 239996               -99.69 2014-07-10     False          False    False
# 239997                  nan 2015-03-03     False          False    False
# 239998               -99.08 2014-12-26      True          False    False
# 239999                  nan 2015-06-19     False          False    False
#
#        escuelascercanas  centroscomercialescercanos               precio  anio
# 0                 False                       False         2,273,000.00  2015
# 1                  True                        True         3,600,000.00  2013
# 2                 False                       False         1,200,000.00  2015
# 3                  True                        True           650,000.00  2012
# 4                 False                       False         1,150,000.00  2016
# 5                 False                        True         1,100,000.00  2014
# 6                 False                       False         1,150,000.00  2016
# 7                 False                       False         4,200,000.00  2016
# 8                  True                        True           310,000.00  2014
# 9                 False                       False         6,200,000.00  2016
# 10                 True                        True           488,000.00  2013
# 11                False                       False         7,200,000.00  2014
# 12                 True                        True         1,500,000.00  2013
# 13                False                       False         3,000,000.00  2015
# 14                False                       False         5,300,000.00  2014
# 15                False                       False         3,650,000.00  2015
# 16                 True                        True         2,450,000.00  2013
# 17                 True                        True         4,750,000.00  2016
# 18                 True                        True           794,078.00  2016
# 19                False                       False         1,850,000.00  2016
# 20                False                       False           490,000.00  2013
# 21                False                       False         2,300,000.00  2016
# 22                False                       False         1,340,000.00  2013
# 23                False                       False         3,500,000.00  2015
# 24                 True                        True         3,900,000.00  2013
# 25                 True                        True           850,000.00  2016
# 26                 True                        True           310,000.00  2014
# 27                False                       False        10,800,000.00  2012
# 28                False                       False         2,600,000.00  2015
# 29                 True                       False        10,707,900.00  2016
# ...                 ...                         ...                  ...   ...
# 239970            False                       False         3,350,000.00  2016
# 239971             True                        True         3,750,000.00  2016
# 239972             True                        True         2,400,000.00  2016
# 239973             True                        True         1,260,000.00  2013
# 239974            False                       False         3,300,000.00  2015
# 239975             True                       False         1,275,000.00  2014
# 239976            False                       False         2,020,000.00  2015
# 239977            False                       False           490,000.00  2015
# 239978            False                       False         1,880,000.00  2016
# 239979             True                        True         3,300,000.00  2016
# 239980            False                       False         3,386,400.00  2016
# 239981             True                        True           550,000.00  2012
# 239982            False                       False           357,000.00  2016
# 239983            False                       False           684,338.00  2016
# 239984             True                        True           505,000.00  2016
# 239985             True                        True         2,700,000.00  2016
# 239986            False                       False         2,079,000.00  2013
# 239987            False                       False           830,000.00  2015
# 239988            False                       False         1,990,000.00  2015
# 239989             True                        True         3,850,000.00  2016
# 239990            False                       False         1,495,000.00  2014
# 239991             True                        True         1,450,000.00  2015
# 239992             True                        True         5,500,000.00  2015
# 239993            False                       False         1,650,000.00  2015
# 239994            False                       False         1,350,000.00  2013
# 239995            False                       False           650,000.00  2015
# 239996             True                        True         1,940,000.00  2014
# 239997            False                       False         3,400,000.00  2015
# 239998             True                        True         2,890,000.00  2014
# 239999            False                       False         3,650,000.00  2015
#
# [240000 rows x 24 columns]

# %%
anio_agrupado_gimnasio_porcentaje = common.agrupar_calcular_porcentajes_desagrupar(zona_gimnasio, 'anio', 'gimnasio')
anio_agrupado_gimnasio_porcentaje.columns = ['anio', 'tiene_gimnasio', 'porcentaje_propiedades']
anio_agrupado_gimnasio_porcentaje
# Out:
#    anio  tiene_gimnasio  porcentaje_propiedades
# 0  2012           False                   95.76
# 1  2012            True                    4.24
# 2  2013           False                   95.63
# 3  2013            True                    4.37
# 4  2014           False                   95.23
# 5  2014            True                    4.77
# 6  2015           False                   95.25
# 7  2015            True                    4.75
# 8  2016           False                   91.19
# 9  2016            True                    8.81

# %%
anio_gimnasio_porcentaje_para_plot = common.columna_bool_a_si_no(
                                            anio_agrupado_gimnasio_porcentaje,
                                            'tiene_gimnasio'
                                        )
anio_gimnasio_porcentaje_para_plot
# Out:
#    anio tiene_gimnasio  porcentaje_propiedades
# 0  2012             No                   95.76
# 1  2012             Si                    4.24
# 2  2013             No                   95.63
# 3  2013             Si                    4.37
# 4  2014             No                   95.23
# 5  2014             Si                    4.77
# 6  2015             No                   95.25
# 7  2015             Si                    4.75
# 8  2016             No                   91.19
# 9  2016             Si                    8.81

# %%
plot_barplot_gimnasio_anio_porc = sns.barplot(
                                    x = 'anio',
                                    y = 'porcentaje_propiedades',
                                    hue = 'tiene_gimnasio',
                                    data = anio_gimnasio_porcentaje_para_plot
                                )

common.setear_titulos_plot(
    plot_barplot_gimnasio_anio_porc,
    'Barplot : \nPorcentaje de propiedades, en Mexico, \nsegun la presencia de gimnasio, por año',
    'Año de puesta en venta',
    'Porcentaje de propiedades [%]'
)

plot_barplot_gimnasio_anio_porc.legend(title = 'Tienen gimnasio', loc = [1,0.5])
plt.show()

# %% [markdown]
# Vemos que el porcentaje de propiedades con gimnasio es bastante bajo.
# Este porcentaje parece mantenerse constante entre 2012 y 2015, y tiene un leve aumento en el 2016.

# %%
anio_gimnasio_porcentaje_pivot = anio_gimnasio_porcentaje_para_plot.pivot_table(index = 'tiene_gimnasio', columns = 'anio', values = 'porcentaje_propiedades')
anio_gimnasio_porcentaje_pivot_apilados = anio_gimnasio_porcentaje_pivot.cumsum()
anio_gimnasio_porcentaje_pivot_apilados
# Out:
# anio                           2012                 2013                 2014  \
# tiene_gimnasio
# No                            95.76                95.63                95.23
# Si                           100.00               100.00               100.00
#
# anio                           2015                 2016
# tiene_gimnasio
# No                            95.25                91.19
# Si                           100.00               100.00

# %%
varios_plots_apilados_anio_gimnasio_porcentaje = common.plot_stacked_barplot(
                                                        anio_gimnasio_porcentaje_pivot_apilados,
                                                        'Tienen gimnasio',
                                                        1, 0.76
                                                    )
# Titulos
common.setear_titulos_plot(
    varios_plots_apilados_anio_gimnasio_porcentaje[-1],
    'Stacked Barplot : \nPorcentaje de propiedades, en Mexico, por año de \npuesta en venta, segun la presencia de gimnasio',
    'Año de puesta en venta',
    'Porcentaje de propiedades [%]'
)

# Porcentajes
common.agregar_valores_stacked_barplot(
    varios_plots_apilados_anio_gimnasio_porcentaje,
    anio_gimnasio_porcentaje_pivot_apilados,
    'w',
    0,-3
)

plt.show()

# %% [markdown]
# ## Gimnasio - Usosmultiples

# %% [markdown]
# ### ¿Cuantos datos perdemos por descartar usosmultiples NaN?

# %%
zona_gimnasio['usosmultiples'].isnull().sum()
# Out:
# 0

# %% [markdown]
# No perdemos ningun dato.

# %% [markdown]
# ### ¿Que es usosmultiples?

# %%
zona_gimnasio['usosmultiples'].unique()
# Out:
# array([False,  True])

# %% [markdown]
# ### ¿Como se relaciona la presencia de gimnasio con la presencia de usosmutiples?

# %%
gimnasio_usosmultiples_agrupados_cant = zona_gimnasio.groupby(['gimnasio', 'usosmultiples']).agg({'gimnasio' : 'count'})
gimnasio_usosmultiples_agrupados_cant.columns = ['cantidad_propiedades']
gimnasio_usosmultiples_agrupados_cant.reset_index(inplace = True)
gimnasio_usosmultiples_agrupados_cant.columns = ['tiene_gimnasio', 'tiene_usosmultiples', 'cantidad_propiedades']
gimnasio_usosmultiples_pivot_cant = gimnasio_usosmultiples_agrupados_cant.pivot_table(index = 'tiene_gimnasio', columns = 'tiene_usosmultiples', values = 'cantidad_propiedades')
gimnasio_usosmultiples_pivot_cant
# Out:
# tiene_usosmultiples   False  True
# tiene_gimnasio
# False                218121   6885
# True                   8657   6337

# %%
gimnasio_usosmultiples_pivot_cant_para_plot = gimnasio_usosmultiples_pivot_cant.copy()
gimnasio_usosmultiples_pivot_cant_para_plot.columns = ['No', 'Si']
gimnasio_usosmultiples_pivot_cant_para_plot.columns.name = 'tiene_usosmultiples'
gimnasio_usosmultiples_pivot_cant_para_plot.index = ['No', 'Si']
gimnasio_usosmultiples_pivot_cant_para_plot.index.name = 'tiene_gimnasio'
gimnasio_usosmultiples_pivot_cant_para_plot
# Out:
# tiene_usosmultiples      No    Si
# tiene_gimnasio
# No                   218121  6885
# Si                     8657  6337

# %%
plot_heatmap_gimnasio_usosmultiples_cant = sns.heatmap(gimnasio_usosmultiples_pivot_cant_para_plot, cmap = 'Blues')
plot_heatmap_gimnasio_usosmultiples_cant.invert_yaxis()

common.setear_titulos_plot(
    plot_heatmap_gimnasio_usosmultiples_cant,
    'Heatmap : \nCantidad de propiedades para cada combinacion \nde tener gimnasio y usosmultiples',
    'Tienen usos multiples',
    'Tienen gimnasio'
)

plt.show()

# %% [markdown]
# El mapa de calor no muestra una alta concentracion de propiedades que no tienen ni gimnasio ni usos multiples

# %%
gimnasio_usosmultiples_agrupados_cant
# Out:
#    tiene_gimnasio  tiene_usosmultiples  cantidad_propiedades
# 0           False                False                218121
# 1           False                 True                  6885
# 2            True                False                  8657
# 3            True                 True                  6337

# %%
gimnasio_usosmultiples_cant_para_plot = gimnasio_usosmultiples_agrupados_cant.copy()
gimnasio_usosmultiples_cant_para_plot = common.columna_bool_a_si_no(gimnasio_usosmultiples_cant_para_plot, 'tiene_gimnasio')
gimnasio_usosmultiples_cant_para_plot = common.columna_bool_a_si_no(gimnasio_usosmultiples_cant_para_plot, 'tiene_usosmultiples')
gimnasio_usosmultiples_cant_para_plot
# Out:
#   tiene_gimnasio tiene_usosmultiples  cantidad_propiedades
# 0             No                  No                218121
# 1             No                  Si                  6885
# 2             Si                  No                  8657
# 3             Si                  Si                  6337

# %%
plot_barplot_gimnasio_usosmultiples_cant = sns.barplot(
                                            x = 'tiene_gimnasio',
                                            y = 'cantidad_propiedades',
                                            hue = 'tiene_usosmultiples',
                                            data = gimnasio_usosmultiples_cant_para_plot
                                        )

common.setear_titulos_plot(
    plot_barplot_gimnasio_usosmultiples_cant,
    'Barplot : \nCantidad de propiedades, en Mexico, segun \nla presencia de gimnasio y usos multiples',
    'Tienen gimnasio',
    'Cantidad de propiedades'
)

plot_barplot_gimnasio_usosmultiples_cant.legend(title = 'Tienen usos multiples')
plt.show()

# %% [markdown]
# Vemos que la mayoria de las propiedades no tienen ni gimnasio ni usos multiples

# %% [markdown]
# ## Gimnasio - Piscina

# %% [markdown]
# ### ¿Cuantos datos perdemos si descartamos piscina NaN?

# %%
zona_gimnasio['piscina'].isnull().sum()
# Out:
# 0

# %% [markdown]
# No perdemos ningun dato.

# %% [markdown]
# ### ¿Que es piscina?

# %%
zona_gimnasio['piscina'].unique()
# Out:
# array([False,  True])

# %% [markdown]
# ### ¿Cuantas propiedades en Mexico tienen gimnasio y piscina?

# %%
gimnasio_piscina_agrupados_cant = zona_gimnasio.groupby(['gimnasio', 'piscina']).agg({'gimnasio' : 'count'})
gimnasio_piscina_agrupados_cant.columns = ['cantidad_propiedades']
gimnasio_piscina_agrupados_cant.reset_index(inplace = True)
gimnasio_piscina_agrupados_cant.columns = ['tiene_gimnasio', 'tiene_piscina', 'cantidad_propiedades']
gimnasio_piscina_agrupados_cant
# Out:
#    tiene_gimnasio  tiene_piscina  cantidad_propiedades
# 0           False          False                211400
# 1           False           True                 13606
# 2            True          False                  7628
# 3            True           True                  7366

# %%
gimnasio_piscina_cant_para_plot = gimnasio_piscina_agrupados_cant.copy()
gimnasio_piscina_cant_para_plot = common.columna_bool_a_si_no(gimnasio_piscina_cant_para_plot, 'tiene_gimnasio')
gimnasio_piscina_cant_para_plot = common.columna_bool_a_si_no(gimnasio_piscina_cant_para_plot, 'tiene_piscina')
gimnasio_piscina_cant_para_plot
# Out:
#   tiene_gimnasio tiene_piscina  cantidad_propiedades
# 0             No            No                211400
# 1             No            Si                 13606
# 2             Si            No                  7628
# 3             Si            Si                  7366

# %%
plot_barplot_gimnasio_piscina_cant = sns.barplot(
                                        x = 'tiene_gimnasio',
                                        y = 'cantidad_propiedades',
                                        hue = 'tiene_piscina',
                                        data = gimnasio_piscina_cant_para_plot
                                    )

common.setear_titulos_plot(
    plot_barplot_gimnasio_piscina_cant,
    'Barplot : \nCantidad de propiedades, en Mexico, segun \nla presencia de gimnasio y piscina',
    'Tienen gimnasio',
    'Cantidad de propiedades'
)

plot_barplot_gimnasio_piscina_cant.legend(title = 'Tienen piscina')
plt.show()

# %% [markdown]
# A ojo !, vemos que NO tiene gimnasio es mas probable que no tenga piscina; en caso contrario, ya no podriamos afirmar lo mismo con tanta precision

# %%
plot_barplot_gimnasio_true_piscina_cant = sns.barplot(
                                            x = 'tiene_piscina',
                                            y = 'cantidad_propiedades',
                                            data = gimnasio_piscina_cant_para_plot.loc[gimnasio_piscina_cant_para_plot['tiene_gimnasio'] == 'Si']
)

common.setear_titulos_plot(
    plot_barplot_gimnasio_true_piscina_cant,
    'Barplot : \nCantidad de propiedades, en Mexico, que tienen \ngimnasio, segun la presencia de piscina',
    'Tienen piscina',
    'Cantidad de propiedades'
)

plt.show()

# %% [markdown]
# Con este acercamiento a las propiedades que tienen gimnasio, estamos seguros de que no podemos estar seguros, si tambien tienen piscina o no.

# %% [markdown]
# ## Gimnasio - Escuelascercanas

# %% [markdown]
# ### ¿Cuantos datos perdemos si descartamos escuelascercanas NaN?

# %%
zona_gimnasio['escuelascercanas'].isnull().sum()
# Out:
# 0

# %% [markdown]
# No perdemos ningun dato.

# %% [markdown]
# ### ¿Que es escuelascercanas?

# %%
zona_gimnasio['escuelascercanas'].unique()
# Out:
# array([False,  True])

# %% [markdown]
# ## ¿Cuantas propiedades, en Mexico, pueden tener gimnasio y escuelascercanas?

# %%
gimnasio_escuelascercanas_agrupados_cant = zona_gimnasio.groupby(['gimnasio', 'escuelascercanas']).agg({'gimnasio' : 'count'})
gimnasio_escuelascercanas_agrupados_cant.columns = ['cantidad_propiedades']
gimnasio_escuelascercanas_agrupados_cant.reset_index(inplace = True)
gimnasio_escuelascercanas_agrupados_cant.columns = ['tiene_gimnasio', 'tiene_escuelascercanas', 'cantidad_propiedades']
gimnasio_escuelascercanas_agrupados_cant
# Out:
#    tiene_gimnasio  tiene_escuelascercanas  cantidad_propiedades
# 0           False                   False                130977
# 1           False                    True                 94029
# 2            True                   False                  2429
# 3            True                    True                 12565

# %%
gimnasio_escuelascercanas_cant_para_plot = gimnasio_escuelascercanas_agrupados_cant.copy()
gimnasio_escuelascercanas_cant_para_plot = common.columna_bool_a_si_no(gimnasio_escuelascercanas_cant_para_plot, 'tiene_gimnasio')
gimnasio_escuelascercanas_cant_para_plot = common.columna_bool_a_si_no(gimnasio_escuelascercanas_cant_para_plot, 'tiene_escuelascercanas')
gimnasio_escuelascercanas_cant_para_plot
# Out:
#   tiene_gimnasio tiene_escuelascercanas  cantidad_propiedades
# 0             No                     No                130977
# 1             No                     Si                 94029
# 2             Si                     No                  2429
# 3             Si                     Si                 12565

# %%
plot_barplot_gimnasio_escuelascercanas_cant = sns.barplot(
                                                x = 'tiene_gimnasio',
                                                y = 'cantidad_propiedades',
                                                hue = 'tiene_escuelascercanas',
                                                data = gimnasio_escuelascercanas_cant_para_plot
                                            )

common.setear_titulos_plot(
    plot_barplot_gimnasio_escuelascercanas_cant,
    'Barplot : \nCantidad de propiedades, en Mexico, segun la \npresencia de gimnasio y escuelas cercanas',
    'Tienen gimnasio',
    'Cantidad de propiedades'
)

plot_barplot_gimnasio_escuelascercanas_cant.legend(title = 'Tienen escuelas cercanas')
plt.show()

# %% [markdown]
# En este caso, parece haber una ligera mayor cantidad de propiedades sin gimnasio, y sin escuelas cercanas que con ellas.
# Por otro lado, para las propiedades que si tienen gimnasio, parace haber mas cantidad de ellas con escuelas cercanas. Aunque en este ultimo caso, la muestra es mucho menor que la primera.

# %%
plot_barplot_gimnasio_true_escuelascercanas_cant = sns.barplot(
                                                x = 'tiene_escuelascercanas',
                                                y = 'cantidad_propiedades',
                                                data = gimnasio_escuelascercanas_cant_para_plot[gimnasio_escuelascercanas_cant_para_plot['tiene_gimnasio'] == 'Si']
                                            )
common.setear_titulos_plot(
    plot_barplot_gimnasio_true_escuelascercanas_cant,
    'Barplot : \nCantidad de propiedades, en Mexico, con gimnasio, \nsegun la presencia de escuelas cercanas',
    'Tienen escuelas cercanas',
    'Cantidad de propiedades'
)

plt.show()

# %% [markdown]
# En este acercamiento se aprecia mejor la diferencia en cantidades de propiedades, para aquellas que tienen gimnasio diferenciando entre las que tienen escuelas cercanas, y las que no.
# Las propieades con gimnasio y escuelas cercanas son mayoria por sobre las que no tienen escuelas cercanas.

# %%
gimnasio_escuelascercanas_pivot = gimnasio_escuelascercanas_agrupados_cant.pivot_table(index = 'tiene_gimnasio', columns = 'tiene_escuelascercanas', values = 'cantidad_propiedades')
gimnasio_escuelascercanas_pivot
# Out:
# tiene_escuelascercanas   False  True
# tiene_gimnasio
# False                   130977  94029
# True                      2429  12565

# %%
gimnasio_escuelascercanas_pivot_para_plot = gimnasio_escuelascercanas_pivot.copy()
gimnasio_escuelascercanas_pivot_para_plot.columns = ['No', 'Si']
gimnasio_escuelascercanas_pivot_para_plot.columns.name = 'tiene_escuelascercanas'
gimnasio_escuelascercanas_pivot_para_plot.index = ['No', 'Si']
gimnasio_escuelascercanas_pivot_para_plot.index.name = 'tiene_gimnasio'
gimnasio_escuelascercanas_pivot_para_plot
# Out:
# tiene_escuelascercanas      No     Si
# tiene_gimnasio
# No                      130977  94029
# Si                        2429  12565

# %%
plot_heatmap_gimnasio_escuelascercanas_cant = sns.heatmap(
                                                    gimnasio_escuelascercanas_pivot_para_plot, 
                                                    cmap = 'Blues',
                                                    cbar_kws={'label': 'Cantidad de propiedades'}
                                                )
plot_heatmap_gimnasio_escuelascercanas_cant.invert_yaxis()

common.setear_titulos_plot(
    plot_heatmap_gimnasio_escuelascercanas_cant,
    'Heatmap : \nCantidad de propiedades, en Mexico, segun la \npresencia de gimnasio y escuelas cercanas',
    'Tienen escuelas cercanas',
    'Tienen gimnasio'
)
plt.show()

# %% [markdown]
# Se puede apreciar una gran presencia propiedades sin gimnasio y sin escuelas cercanas, seguido de una cantidad importante (pero menor) de propiedades sin gimnasio y con escuelas cercanas.
# En menor media, vemos que las propieades con gimnasio y escuelas cercanas dominan por sobre las que no tienen escuelas cercanas.

# %% [markdown]
# ## Gimnasio - Precio

# %% [markdown]
# ### ¿Cuantos datos perdemos si descartamos todos los precios NaN?

# %%
zona_gimnasio['precio'].isnull().sum()
# Out:
# 0

# %% [markdown]
# No perdemos ningun dato.

# %% [markdown]
# ### ¿Que es precio?

# %%
zona_gimnasio['precio'].unique()
# Out:
# array([2273000., 3600000., 1200000., ..., 1794000., 3386400.,  684338.])

# %%
zona_gimnasio['precio'].dtype
# Out:
# dtype('float32')

# %% [markdown]
# ### ¿Como se distribuye el precio de una propiedad, en Mexico, segun la presencia de gimnasio?

# %%
gimnasio_agrupado_precio_estadisticas = common.agrupar_calcular_estadisticas_desagrupar(zona_gimnasio, 'gimnasio', 'precio')
gimnasio_agrupado_precio_estadisticas.rename(columns = {'gimnasio' : 'tiene_gimnasio'}, inplace = True)
gimnasio_agrupado_precio_estadisticas
# Out:
#    tiene_gimnasio     precio_cuantil_1        precio_median  \
# 0           False           930,000.00         1,797,000.00
# 1            True         1,920,000.00         3,233,000.00
#
#       precio_cuantil_3
# 0         3,250,000.00
# 1         5,195,000.00

# %%
zona_gimnasio_para_plot = zona_gimnasio.filter(['gimnasio', 'precio']).copy()
zona_gimnasio_para_plot = common.columna_bool_a_si_no(zona_gimnasio_para_plot, 'gimnasio')
zona_gimnasio_para_plot
# Out:
#        gimnasio               precio
# 0            No         2,273,000.00
# 1            No         3,600,000.00
# 2            No         1,200,000.00
# 3            No           650,000.00
# 4            No         1,150,000.00
# 5            No         1,100,000.00
# 6            No         1,150,000.00
# 7            No         4,200,000.00
# 8            No           310,000.00
# 9            No         6,200,000.00
# 10           No           488,000.00
# 11           No         7,200,000.00
# 12           No         1,500,000.00
# 13           No         3,000,000.00
# 14           No         5,300,000.00
# 15           No         3,650,000.00
# 16           No         2,450,000.00
# 17           No         4,750,000.00
# 18           No           794,078.00
# 19           No         1,850,000.00
# 20           No           490,000.00
# 21           No         2,300,000.00
# 22           No         1,340,000.00
# 23           No         3,500,000.00
# 24           No         3,900,000.00
# 25           No           850,000.00
# 26           No           310,000.00
# 27           No        10,800,000.00
# 28           No         2,600,000.00
# 29           No        10,707,900.00
# ...         ...                  ...
# 239970       No         3,350,000.00
# 239971       No         3,750,000.00
# 239972       No         2,400,000.00
# 239973       No         1,260,000.00
# 239974       No         3,300,000.00
# 239975       No         1,275,000.00
# 239976       No         2,020,000.00
# 239977       No           490,000.00
# 239978       No         1,880,000.00
# 239979       No         3,300,000.00
# 239980       No         3,386,400.00
# 239981       No           550,000.00
# 239982       No           357,000.00
# 239983       No           684,338.00
# 239984       No           505,000.00
# 239985       No         2,700,000.00
# 239986       No         2,079,000.00
# 239987       No           830,000.00
# 239988       No         1,990,000.00
# 239989       No         3,850,000.00
# 239990       No         1,495,000.00
# 239991       No         1,450,000.00
# 239992       No         5,500,000.00
# 239993       No         1,650,000.00
# 239994       No         1,350,000.00
# 239995       No           650,000.00
# 239996       No         1,940,000.00
# 239997       No         3,400,000.00
# 239998       Si         2,890,000.00
# 239999       No         3,650,000.00
#
# [240000 rows x 2 columns]

# %%
plot_boxplot_gimnasio_precio_estadist = sns.boxplot(
                                            x = 'gimnasio',
                                            y = 'precio',
                                            data = zona_gimnasio_para_plot
                                        )
# Titulos
common.setear_titulos_plot(
    plot_boxplot_gimnasio_precio_estadist,
    'Boxplot : \nDistribucion del precio de las propiedades, \nen Mexico, segun la presencia de gimnasio',
    'Tienen gimnasio',
    'Precio [peso mexicanos]'
)

# Elimino notacion cientifica del eje y
plot_boxplot_gimnasio_precio_estadist.ticklabel_format(style = 'plain', axis = 'y')

# Agrego cuantiles y mediana
common.agregar_serie_plot(
    plot_boxplot_gimnasio_precio_estadist,
    gimnasio_agrupado_precio_estadisticas['precio_cuantil_1'],
    gimnasio_agrupado_precio_estadisticas['precio_cuantil_1'],
    'w', 
    -0.27, 150000
)

common.agregar_serie_plot(
    plot_boxplot_gimnasio_precio_estadist,
    gimnasio_agrupado_precio_estadisticas['precio_median'],
    gimnasio_agrupado_precio_estadisticas['precio_median'],
    'w',
    0, 250000
)

common.agregar_serie_plot(
    plot_boxplot_gimnasio_precio_estadist,
    gimnasio_agrupado_precio_estadisticas['precio_cuantil_3'],
    gimnasio_agrupado_precio_estadisticas['precio_cuantil_3'],
    'k',
    0.27, 100000
)

plt.show()

# %% [markdown]
# Vemos que la presencia de gimnasio sube ligeramente el precio de la propiedad.
