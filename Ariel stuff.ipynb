# %% [markdown]
# # Analisis Exploratorio Tp1 (Ariel)

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %% [markdown]
# ## Levanto el archivo

# %%
# %matplotlib inline

plt.style.use('default') # haciendo los graficos un poco mas bonitos en matplotlib
plt.rcParams['figure.figsize'] = (18, 8)

sns.set(style="whitegrid", font_scale = 2) # seteando tipo de grid en seaborn
                                           # seteando tamanio de ticks label
pd.options.display.float_format = '{:20,.2f}'.format # suprimimos la notacion cientifica en los outputs

# %%
df = pd.read_csv("train.csv", dtype = {"centroscomercialescercanos" : "bool",
                                       "escuelascercanas" : "bool",
                                       "piscina" : "bool",
                                       "gimnasio" : "bool",
                                       "usosmultiples" : "bool",
                                       "tipodepropiedad" : "category",
                                       "provincia" : "category",
                                       "ciudad" : "category",
                                       "habitaciones" : "float32",
                                       "banos" : "float32",
                                       "garages" : "float32",
                                       "antiguedad" : "float32"})

# %%
df["fecha"] = pd.to_datetime(df["fecha"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240000 entries, 0 to 239999
# Data columns (total 23 columns):
# id                            240000 non-null int64
# titulo                        234613 non-null object
# descripcion                   238381 non-null object
# tipodepropiedad               239954 non-null category
# direccion                     186928 non-null object
# ciudad                        239628 non-null category
# provincia                     239845 non-null category
# antiguedad                    196445 non-null float32
# habitaciones                  217529 non-null float32
# garages                       202235 non-null float32
# banos                         213779 non-null float32
# metroscubiertos               222600 non-null float64
# metrostotales                 188533 non-null float64
# idzona                        211379 non-null float64
# lat                           116512 non-null float64
# lng                           116512 non-null float64
# fecha                         240000 non-null datetime64[ns]
# gimnasio                      240000 non-null bool
# usosmultiples                 240000 non-null bool
# piscina                       240000 non-null bool
# escuelascercanas              240000 non-null bool
# centroscomercialescercanos    240000 non-null bool
# precio                        240000 non-null float64
# dtypes: bool(5), category(3), datetime64[ns](1), float32(4), float64(6), int64(1), object(3)
# memory usage: 25.9+ MB

# %% [markdown]
# ## Checkeo los datos

# %%
df.shape
# Out:
# (240000, 23)

# %%
df.count()
# Out:
# id                            240000
# titulo                        234613
# descripcion                   238381
# tipodepropiedad               239954
# direccion                     186928
# ciudad                        239628
# provincia                     239845
# antiguedad                    196445
# habitaciones                  217529
# garages                       202235
# banos                         213779
# metroscubiertos               222600
# metrostotales                 188533
# idzona                        211379
# lat                           116512
# lng                           116512
# fecha                         240000
# gimnasio                      240000
# usosmultiples                 240000
# piscina                       240000
# escuelascercanas              240000
# centroscomercialescercanos    240000
# precio                        240000
# dtype: int64

# %%
aux = df.groupby("tipodepropiedad").count()
aux
# Out:
#                                    id  titulo  descripcion  direccion  ciudad  \
# tipodepropiedad
# Apartamento                     57341   56119        57026      47851   57264
# Bodega comercial                 1406    1359         1387       1041    1404
# Casa                           141717  138518       140729     107582  141479
# Casa en condominio              19297   18674        19147      15584   19284
# Casa uso de suelo                 708     698          704        525     706
# Departamento Compartido           141     141          140        141     141
# Duplex                            343     343          343        342     343
# Edificio                         1396    1354         1382       1116    1396
# Huerta                             20      19           20         18      20
# Inmuebles productivos urbanos     200     199          198        193     200
# Local Comercial                  3055    3029         3039       1990    3051
# Local en centro comercial         165     165          164        158     165
# Lote                                5       5            5          0       5
# Nave industrial                    76      76           76         69      76
# Oficina comercial                1741    1694         1731       1340    1739
# Otros                             134     133          134          5     134
# Quinta Vacacional                 395     391          394        279     395
# Rancho                            170     163          166        150     170
# Terreno                          9945    9821         9889       7752    9939
# Terreno comercial                1326    1300         1294        541    1316
# Terreno industrial                 31      31           31         12      31
# Villa                             340     334          338        235     340
# Hospedaje                           1       1            1          1       1
# Garage                              1       0            1          1       1
#
#                                provincia  antiguedad  habitaciones  garages  \
# tipodepropiedad
# Apartamento                        57300       48290         56347    53605
# Bodega comercial                    1404        1129           157      881
# Casa                              141620      119026        138379   117756
# Casa en condominio                 19293       16286         19082    16060
# Casa uso de suelo                    707         616           502      468
# Departamento Compartido              141         134           137      137
# Duplex                               343         337           340      336
# Edificio                            1396        1201           303      873
# Huerta                                20          18             7       15
# Inmuebles productivos urbanos        200         198            83      150
# Local Comercial                     3055        2240           375     1834
# Local en centro comercial            165         137            22      120
# Lote                                   5           1             0        1
# Nave industrial                       76          71            13       56
# Oficina comercial                   1739        1410           324     1202
# Otros                                134         126            69       52
# Quinta Vacacional                    395         340           362      156
# Rancho                               170         154           142       75
# Terreno                             9943        3721           478     7542
# Terreno comercial                   1322         716            72      713
# Terreno industrial                    31          14             3        5
# Villa                                340         270           303      181
# Hospedaje                              1           0             1        1
# Garage                                 1           0             0        1
#
#                                 banos  ...  idzona    lat    lng   fecha  \
# tipodepropiedad                        ...
# Apartamento                     56004  ...   52779  30035  30035   57341
# Bodega comercial                  746  ...    1219    696    696    1406
# Casa                           133108  ...  123156  65628  65628  141717
# Casa en condominio              18494  ...   16657   9733   9733   19297
# Casa uso de suelo                 551  ...     636    414    414     708
# Departamento Compartido           134  ...     140     66     66     141
# Duplex                            338  ...     343    169    169     343
# Edificio                          367  ...    1286    802    802    1396
# Huerta                              8  ...      17      4      4      20
# Inmuebles productivos urbanos      72  ...     190    125    125     200
# Local Comercial                  1318  ...    2659   1641   1641    3055
# Local en centro comercial          43  ...     159     85     85     165
# Lote                                0  ...       2      1      1       5
# Nave industrial                    44  ...      70     46     46      76
# Oficina comercial                 981  ...    1569    932    932    1741
# Otros                              71  ...      96    105    105     134
# Quinta Vacacional                 341  ...     335    190    190     395
# Rancho                            137  ...     147     78     78     170
# Terreno                           523  ...    8678   4913   4913    9945
# Terreno comercial                 174  ...     914    669    669    1326
# Terreno industrial                  9  ...      24     26     26      31
# Villa                             300  ...     297    139    139     340
# Hospedaje                           0  ...       1      0      0       1
# Garage                              0  ...       1      0      0       1
#
#                                gimnasio  usosmultiples  piscina  \
# tipodepropiedad
# Apartamento                       57341          57341    57341
# Bodega comercial                   1406           1406     1406
# Casa                             141717         141717   141717
# Casa en condominio                19297          19297    19297
# Casa uso de suelo                   708            708      708
# Departamento Compartido             141            141      141
# Duplex                              343            343      343
# Edificio                           1396           1396     1396
# Huerta                               20             20       20
# Inmuebles productivos urbanos       200            200      200
# Local Comercial                    3055           3055     3055
# Local en centro comercial           165            165      165
# Lote                                  5              5        5
# Nave industrial                      76             76       76
# Oficina comercial                  1741           1741     1741
# Otros                               134            134      134
# Quinta Vacacional                   395            395      395
# Rancho                              170            170      170
# Terreno                            9945           9945     9945
# Terreno comercial                  1326           1326     1326
# Terreno industrial                   31             31       31
# Villa                               340            340      340
# Hospedaje                             1              1        1
# Garage                                1              1        1
#
#                                escuelascercanas  centroscomercialescercanos  \
# tipodepropiedad
# Apartamento                               57341                       57341
# Bodega comercial                           1406                        1406
# Casa                                     141717                      141717
# Casa en condominio                        19297                       19297
# Casa uso de suelo                           708                         708
# Departamento Compartido                     141                         141
# Duplex                                      343                         343
# Edificio                                   1396                        1396
# Huerta                                       20                          20
# Inmuebles productivos urbanos               200                         200
# Local Comercial                            3055                        3055
# Local en centro comercial                   165                         165
# Lote                                          5                           5
# Nave industrial                              76                          76
# Oficina comercial                          1741                        1741
# Otros                                       134                         134
# Quinta Vacacional                           395                         395
# Rancho                                      170                         170
# Terreno                                    9945                        9945
# Terreno comercial                          1326                        1326
# Terreno industrial                           31                          31
# Villa                                       340                         340
# Hospedaje                                     1                           1
# Garage                                        1                           1
#
#                                precio
# tipodepropiedad
# Apartamento                     57341
# Bodega comercial                 1406
# Casa                           141717
# Casa en condominio              19297
# Casa uso de suelo                 708
# Departamento Compartido           141
# Duplex                            343
# Edificio                         1396
# Huerta                             20
# Inmuebles productivos urbanos     200
# Local Comercial                  3055
# Local en centro comercial         165
# Lote                                5
# Nave industrial                    76
# Oficina comercial                1741
# Otros                             134
# Quinta Vacacional                 395
# Rancho                            170
# Terreno                          9945
# Terreno comercial                1326
# Terreno industrial                 31
# Villa                             340
# Hospedaje                           1
# Garage                              1
#
# [24 rows x 22 columns]

# %%
#Lotes, hospedajes y garages hay menos de 10 datos, los elimino
#Tambien elimino los que no tienen tipo de propiedad (53 filas en total)
df = df[(df["tipodepropiedad"] != "Lote") | (df["tipodepropiedad"] != "Garage") | (df["tipodepropiedad"] != "Hospedaje")]

# %% [markdown]
# ## Comienzo el análisis

# %%
xhabgb = df.groupby("habitaciones")#Por habitacion group by
xhab = xhabgb.agg({"precio" : ["mean", "std"], "antiguedad" : "mean", "banos" : "mean"}) #Por habitacion Data frame
xhab["cantidad"] = df["habitaciones"].value_counts()

# %%
xhab.columns = ["precio_mean", "precio_std", "antiguedad_mean", "banos_mean", "cantidad"]
xhab.reset_index(inplace=True)
xhab["precioxhab_mean"] = xhab["precio_mean"] / xhab["habitaciones"]
xhab
# Out:
#    habitaciones   precio_mean    precio_std  antiguedad_mean  banos_mean  \
# 0           1.0  1.806075e+06  1.549486e+06         8.336390    1.153532
# 1           2.0  1.616978e+06  1.652623e+06         7.615968    1.453537
# 2           3.0  2.769696e+06  2.149077e+06         7.295936    2.328763
# 3           4.0  3.494552e+06  2.317539e+06        11.321439    2.856033
# 4           5.0  3.284925e+06  2.255342e+06        14.637267    2.858830
# 5           6.0  3.165559e+06  2.110283e+06        17.311510    2.956450
# 6           7.0  3.562564e+06  2.295235e+06        18.087755    3.000000
# 7           8.0  3.432464e+06  2.178783e+06        18.185841    3.124464
# 8           9.0  3.936174e+06  2.806284e+06        20.078432    3.000000
# 9          10.0  4.520162e+06  2.735238e+06        16.533783    2.785047
#
#    cantidad  precioxhab_mean
# 0      5069     1.806075e+06
# 1     57802     8.084892e+05
# 2    121869     9.232320e+05
# 3     25065     8.736379e+05
# 4      4595     6.569850e+05
# 5      1669     5.275931e+05
# 6       539     5.089377e+05
# 7       398     4.290580e+05
# 8       179     4.373527e+05
# 9       316     4.520162e+05

# %%
sns.boxplot(x="habitaciones", y="precio", data=df, palette="hls")

# %%
#Separar de a 5
sns.boxplot(x="habitaciones", y="antiguedad", data=df, palette="hls")

# %%
xhab.plot("habitaciones", "precio_mean", kind="line")
xhab.plot("habitaciones", "precioxhab_mean", kind="line")
xhab.plot("habitaciones", "cantidad", kind="line")

# %%
frame = xhabgb["tipodepropiedad"].value_counts().to_frame()
frame.columns = ["cantidad"]
frame.reset_index(inplace=True)
frame.pivot(index="habitaciones", columns="tipodepropiedad", values="cantidad")
# Out:
# tipodepropiedad  Apartamento  Bodega comercial     Casa  Casa en condominio  \
# habitaciones
# 1.0                   2841.0              47.0   1549.0               186.0
# 2.0                  30040.0              42.0  23789.0              3004.0
# 3.0                  22566.0              30.0  84651.0             13608.0
# 4.0                    780.0              18.0  21714.0              2095.0
# 5.0                     64.0              10.0   4179.0               143.0
# 6.0                     23.0               5.0   1458.0                29.0
# 7.0                      6.0               1.0    458.0                 5.0
# 8.0                     13.0               3.0    298.0                 6.0
# 9.0                      9.0               1.0    120.0                 2.0
# 10.0                     5.0               NaN    163.0                 4.0
#
# tipodepropiedad  Casa uso de suelo  Departamento Compartido  Duplex  Edificio  \
# habitaciones
# 1.0                           12.0                      8.0     8.0      11.0
# 2.0                           53.0                     61.0   194.0      35.0
# 3.0                          150.0                     62.0   109.0      36.0
# 4.0                          133.0                      2.0    13.0      21.0
# 5.0                           48.0                      NaN     9.0      22.0
# 6.0                           34.0                      2.0     6.0      45.0
# 7.0                           24.0                      NaN     NaN      18.0
# 8.0                           16.0                      NaN     1.0      28.0
# 9.0                            9.0                      NaN     NaN      16.0
# 10.0                          23.0                      2.0     NaN      71.0
#
# tipodepropiedad  Hospedaje  Huerta  ...  Local en centro comercial  \
# habitaciones                        ...
# 1.0                    NaN     NaN  ...                       12.0
# 2.0                    NaN     5.0  ...                        8.0
# 3.0                    NaN     1.0  ...                        NaN
# 4.0                    NaN     1.0  ...                        NaN
# 5.0                    NaN     NaN  ...                        2.0
# 6.0                    NaN     NaN  ...                        NaN
# 7.0                    1.0     NaN  ...                        NaN
# 8.0                    NaN     NaN  ...                        NaN
# 9.0                    NaN     NaN  ...                        NaN
# 10.0                   NaN     NaN  ...                        NaN
#
# tipodepropiedad  Nave industrial  Oficina comercial  Otros  Quinta Vacacional  \
# habitaciones
# 1.0                          1.0               56.0    6.0               40.0
# 2.0                          5.0               39.0   31.0              130.0
# 3.0                          3.0               66.0   30.0              121.0
# 4.0                          3.0               53.0    2.0               49.0
# 5.0                          1.0               35.0    NaN               12.0
# 6.0                          NaN               29.0    NaN                6.0
# 7.0                          NaN               13.0    NaN                2.0
# 8.0                          NaN               13.0    NaN                1.0
# 9.0                          NaN                6.0    NaN                1.0
# 10.0                         NaN               14.0    NaN                NaN
#
# tipodepropiedad  Rancho  Terreno  Terreno comercial  Terreno industrial  Villa
# habitaciones
# 1.0                22.0    111.0               17.0                 1.0   30.0
# 2.0                34.0    127.0               13.0                 NaN   96.0
# 3.0                56.0    138.0               22.0                 NaN  134.0
# 4.0                15.0     58.0               11.0                 1.0   33.0
# 5.0                 9.0     23.0                6.0                 NaN    4.0
# 6.0                 3.0      8.0                2.0                 NaN    3.0
# 7.0                 1.0      4.0                NaN                 NaN    NaN
# 8.0                 2.0      3.0                NaN                 NaN    3.0
# 9.0                 NaN      1.0                NaN                 1.0    NaN
# 10.0                NaN      5.0                1.0                 NaN    NaN
#
# [10 rows x 22 columns]

# %%
frame.plot(x="habitaciones", y="cantidad", kind="")

# %%
xpropgb = df.groupby("tipodepropiedad")
xprop = xpropgb.agg({"precio" : "mean", "antiguedad" : "mean", "banos" : "mean"})

# %%
xprop["cantidad"] = df["tipodepropiedad"].value_counts()
xprop
# Out:
#                                      precio  antiguedad     banos  cantidad
# tipodepropiedad
# Apartamento                    2.763769e+06    8.362021  1.816817     57341
# Bodega comercial               2.693758e+06    9.635961  1.847185      1406
# Casa                           2.398158e+06    8.272588  2.240429    141717
# Casa en condominio             2.898927e+06    6.328626  2.366065     19297
# Casa uso de suelo              3.732469e+06   17.998377  2.404719       708
# Departamento Compartido        2.560162e+06    6.149254  1.791045       141
# Duplex                         1.271758e+06    9.851632  1.360947       343
# Edificio                       5.009499e+06   15.890924  2.626703      1396
# Huerta                         3.543350e+06    8.777778  1.625000        20
# Inmuebles productivos urbanos  3.743070e+06   15.671718  2.388889       200
# Local Comercial                2.365064e+06    9.119197  1.808801      3055
# Local en centro comercial      2.212631e+06    7.569343  1.697674       165
# Lote                           9.887608e+05    0.000000       NaN         5
# Nave industrial                3.742600e+06   10.887324  2.204545        76
# Oficina comercial              3.148533e+06   12.840425  1.975535      1741
# Otros                          2.881689e+06    3.888889  2.000000       134
# Quinta Vacacional              3.187426e+06    7.544117  2.299120       395
# Rancho                         4.032682e+06   10.467532  1.861314       170
# Terreno                        1.805202e+06    1.031443  1.692161      9945
# Terreno comercial              2.472025e+06    5.030726  1.810345      1326
# Terreno industrial             3.647994e+06    7.285714  1.666667        31
# Villa                          2.767352e+06    6.629630  2.216667       340
# Hospedaje                      3.000000e+06         NaN       NaN         1
# Garage                         5.000000e+05         NaN       NaN         1

# %%
xprophab = df.groupby(["tipodepropiedad", "habitaciones"]).agg({"precio" : "mean", "banos" : "mean", "antiguedad" : "mean"})
xprophab
# Out:
#                                     precio     banos  antiguedad
# tipodepropiedad habitaciones
# Apartamento     1.0           2.185763e+06  1.120327    8.732762
#                 2.0           2.152656e+06  1.554512    8.184624
#                 3.0           3.552820e+06  2.207489    8.588063
#                 4.0           5.387999e+06  3.175657    8.598820
#                 5.0           4.777039e+06  3.045455   12.224138
# ...                                    ...       ...         ...
# Garage          6.0                    NaN       NaN         NaN
#                 7.0                    NaN       NaN         NaN
#                 8.0                    NaN       NaN         NaN
#                 9.0                    NaN       NaN         NaN
#                 10.0                   NaN       NaN         NaN
#
# [240 rows x 3 columns]

# %%
xprovgb = df.groupby("provincia")
xprov = xprovgb.agg({"precio" : "mean", "antiguedad" : "mean", "banos" : "mean"})
xprov["cantidad"] = df["provincia"].value_counts()
xprov.reset_index(inplace=True)
xprov
# Out:
#                 provincia               precio           antiguedad  \
# 0          Aguascalientes         1,477,188.77                 7.52
# 1   Baja California Norte           767,441.75                 5.79
# 2     Baja California Sur         1,216,452.82                 2.46
# 3                Campeche         1,570,917.82                 3.91
# 4                 Chiapas         1,924,125.72                 5.41
# 5               Chihuahua         1,744,530.61                 6.52
# 6                Coahuila         1,505,305.45                 6.31
# 7                  Colima         1,531,380.16                 5.67
# 8        Distrito Federal         3,471,705.09                12.19
# 9                 Durango         1,210,388.98                 4.99
# 10         Edo. de México         2,762,284.34                10.03
# 11             Guanajuato         1,866,959.43                 5.73
# 12               Guerrero         2,548,741.86                 7.61
# 13                Hidalgo         1,305,550.54                 3.47
# 14                Jalisco         2,367,693.58                 6.64
# 15              Michoacán         1,478,503.67                 7.06
# 16                Morelos         2,290,088.01                 6.46
# 17                Nayarit         1,426,790.82                 4.68
# 18             Nuevo León         2,717,757.65                 7.54
# 19                 Oaxaca         1,575,517.89                 5.40
# 20                 Puebla         2,298,403.64                 4.55
# 21              Querétaro         2,144,108.90                 3.70
# 22           Quintana Roo         2,402,966.94                 4.54
# 23        San luis Potosí         1,921,445.90                 3.98
# 24                Sinaloa         1,634,571.64                 6.15
# 25                 Sonora         1,483,715.86                 5.94
# 26                Tabasco         2,300,480.23                 5.30
# 27             Tamaulipas         1,589,666.98                 5.55
# 28               Tlaxcala         1,080,993.34                 3.69
# 29               Veracruz         1,890,069.70                 4.63
# 30                Yucatán         2,035,394.69                 3.07
# 31              Zacatecas         1,453,747.80                 6.40
#
#                   banos  cantidad
# 0                  2.12      1753
# 1                  1.37      3220
# 2                  1.61      1700
# 3                  1.96       263
# 4                  2.21      1126
# 5                  2.13      4590
# 6                  2.14      3695
# 7                  2.04      1008
# 8                  1.99     58790
# 9                  1.95      2275
# 10                 2.08     41604
# 11                 2.23      2860
# 12                 2.29      2678
# 13                 1.81      2521
# 14                 2.22     21238
# 15                 1.90      2471
# 16                 2.35      7337
# 17                 1.89      1352
# 18                 2.31     15324
# 19                 1.85       711
# 20                 2.25     10421
# 21                 2.40     16988
# 22                 2.34      4756
# 23                 2.25      8411
# 24                 2.03      1806
# 25                 1.89      2988
# 26                 2.34       994
# 27                 1.95      2303
# 28                 1.55       839
# 29                 2.27      5760
# 30                 2.59      7925
# 31                 1.80        94

# %%
xprovmax = xprov.loc[(xprov["cantidad"] >= 10000)]
xprovmax.plot(x="provincia", y="cantidad", kind="bar")
