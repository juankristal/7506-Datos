# %% [markdown]
# # Analisis Exploratorio Tp1 (Ariel)

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %% [markdown]
# ## Levanto el archivo

# %%
# %matplotlib inline

plt.style.use('default') # haciendo los graficos un poco mas bonitos en matplotlib
plt.rcParams['figure.figsize'] = (18, 8)

sns.set(style="whitegrid", font_scale = 2) # seteando tipo de grid en seaborn
                                           # seteando tamanio de ticks label
pd.options.display.float_format = '{:20,.2f}'.format # suprimimos la notacion cientifica en los outputs

# %%
df = pd.read_csv("train.csv", dtype = {"centroscomercialescercanos" : "bool",
                                       "escuelascercanas" : "bool",
                                       "piscina" : "bool",
                                       "gimnasio" : "bool",
                                       "usosmultiples" : "bool",
                                       #"tipodepropiedad" : "category",
                                       #"provincia" : "category",
                                       "ciudad" : "category",
                                       "habitaciones" : "float32",
                                       "banos" : "float32",
                                       "garages" : "float32",
                                       "antiguedad" : "float32"})

# %%
df["fecha"] = pd.to_datetime(df["fecha"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240000 entries, 0 to 239999
# Data columns (total 23 columns):
# id                            240000 non-null int64
# titulo                        234613 non-null object
# descripcion                   238381 non-null object
# tipodepropiedad               239954 non-null object
# direccion                     186928 non-null object
# ciudad                        239628 non-null category
# provincia                     239845 non-null object
# antiguedad                    196445 non-null float32
# habitaciones                  217529 non-null float32
# garages                       202235 non-null float32
# banos                         213779 non-null float32
# metroscubiertos               222600 non-null float64
# metrostotales                 188533 non-null float64
# idzona                        211379 non-null float64
# lat                           116512 non-null float64
# lng                           116512 non-null float64
# fecha                         240000 non-null datetime64[ns]
# gimnasio                      240000 non-null bool
# usosmultiples                 240000 non-null bool
# piscina                       240000 non-null bool
# escuelascercanas              240000 non-null bool
# centroscomercialescercanos    240000 non-null bool
# precio                        240000 non-null float64
# dtypes: bool(5), category(1), datetime64[ns](1), float32(4), float64(6), int64(1), object(5)
# memory usage: 29.1+ MB

# %% [markdown]
# ## Checkeo los datos

# %%
df.shape
# Out:
# (240000, 23)

# %%
df.count()
# Out:
# id                            240000
# titulo                        234613
# descripcion                   238381
# tipodepropiedad               239954
# direccion                     186928
# ciudad                        239628
# provincia                     239845
# antiguedad                    196445
# habitaciones                  217529
# garages                       202235
# banos                         213779
# metroscubiertos               222600
# metrostotales                 188533
# idzona                        211379
# lat                           116512
# lng                           116512
# fecha                         240000
# gimnasio                      240000
# usosmultiples                 240000
# piscina                       240000
# escuelascercanas              240000
# centroscomercialescercanos    240000
# precio                        240000
# dtype: int64

# %%
aux = df.groupby("tipodepropiedad").count()
aux
# Out:
#                                    id  titulo  descripcion  direccion  ciudad  \
# tipodepropiedad
# Apartamento                     57341   56119        57026      47851   57264
# Bodega comercial                 1406    1359         1387       1041    1404
# Casa                           141717  138518       140729     107582  141479
# Casa en condominio              19297   18674        19147      15584   19284
# Casa uso de suelo                 708     698          704        525     706
# Departamento Compartido           141     141          140        141     141
# Duplex                            343     343          343        342     343
# Edificio                         1396    1354         1382       1116    1396
# Garage                              1       0            1          1       1
# Hospedaje                           1       1            1          1       1
# Huerta                             20      19           20         18      20
# Inmuebles productivos urbanos     200     199          198        193     200
# Local Comercial                  3055    3029         3039       1990    3051
# Local en centro comercial         165     165          164        158     165
# Lote                                5       5            5          0       5
# Nave industrial                    76      76           76         69      76
# Oficina comercial                1741    1694         1731       1340    1739
# Otros                             134     133          134          5     134
# Quinta Vacacional                 395     391          394        279     395
# Rancho                            170     163          166        150     170
# Terreno                          9945    9821         9889       7752    9939
# Terreno comercial                1326    1300         1294        541    1316
# Terreno industrial                 31      31           31         12      31
# Villa                             340     334          338        235     340
#
#                                provincia  antiguedad  habitaciones  garages  \
# tipodepropiedad
# Apartamento                        57300       48290         56347    53605
# Bodega comercial                    1404        1129           157      881
# Casa                              141620      119026        138379   117756
# Casa en condominio                 19293       16286         19082    16060
# Casa uso de suelo                    707         616           502      468
# Departamento Compartido              141         134           137      137
# Duplex                               343         337           340      336
# Edificio                            1396        1201           303      873
# Garage                                 1           0             0        1
# Hospedaje                              1           0             1        1
# Huerta                                20          18             7       15
# Inmuebles productivos urbanos        200         198            83      150
# Local Comercial                     3055        2240           375     1834
# Local en centro comercial            165         137            22      120
# Lote                                   5           1             0        1
# Nave industrial                       76          71            13       56
# Oficina comercial                   1739        1410           324     1202
# Otros                                134         126            69       52
# Quinta Vacacional                    395         340           362      156
# Rancho                               170         154           142       75
# Terreno                             9943        3721           478     7542
# Terreno comercial                   1322         716            72      713
# Terreno industrial                    31          14             3        5
# Villa                                340         270           303      181
#
#                                 banos  ...  idzona    lat    lng   fecha  \
# tipodepropiedad                        ...
# Apartamento                     56004  ...   52779  30035  30035   57341
# Bodega comercial                  746  ...    1219    696    696    1406
# Casa                           133108  ...  123156  65628  65628  141717
# Casa en condominio              18494  ...   16657   9733   9733   19297
# Casa uso de suelo                 551  ...     636    414    414     708
# Departamento Compartido           134  ...     140     66     66     141
# Duplex                            338  ...     343    169    169     343
# Edificio                          367  ...    1286    802    802    1396
# Garage                              0  ...       1      0      0       1
# Hospedaje                           0  ...       1      0      0       1
# Huerta                              8  ...      17      4      4      20
# Inmuebles productivos urbanos      72  ...     190    125    125     200
# Local Comercial                  1318  ...    2659   1641   1641    3055
# Local en centro comercial          43  ...     159     85     85     165
# Lote                                0  ...       2      1      1       5
# Nave industrial                    44  ...      70     46     46      76
# Oficina comercial                 981  ...    1569    932    932    1741
# Otros                              71  ...      96    105    105     134
# Quinta Vacacional                 341  ...     335    190    190     395
# Rancho                            137  ...     147     78     78     170
# Terreno                           523  ...    8678   4913   4913    9945
# Terreno comercial                 174  ...     914    669    669    1326
# Terreno industrial                  9  ...      24     26     26      31
# Villa                             300  ...     297    139    139     340
#
#                                gimnasio  usosmultiples  piscina  \
# tipodepropiedad
# Apartamento                       57341          57341    57341
# Bodega comercial                   1406           1406     1406
# Casa                             141717         141717   141717
# Casa en condominio                19297          19297    19297
# Casa uso de suelo                   708            708      708
# Departamento Compartido             141            141      141
# Duplex                              343            343      343
# Edificio                           1396           1396     1396
# Garage                                1              1        1
# Hospedaje                             1              1        1
# Huerta                               20             20       20
# Inmuebles productivos urbanos       200            200      200
# Local Comercial                    3055           3055     3055
# Local en centro comercial           165            165      165
# Lote                                  5              5        5
# Nave industrial                      76             76       76
# Oficina comercial                  1741           1741     1741
# Otros                               134            134      134
# Quinta Vacacional                   395            395      395
# Rancho                              170            170      170
# Terreno                            9945           9945     9945
# Terreno comercial                  1326           1326     1326
# Terreno industrial                   31             31       31
# Villa                               340            340      340
#
#                                escuelascercanas  centroscomercialescercanos  \
# tipodepropiedad
# Apartamento                               57341                       57341
# Bodega comercial                           1406                        1406
# Casa                                     141717                      141717
# Casa en condominio                        19297                       19297
# Casa uso de suelo                           708                         708
# Departamento Compartido                     141                         141
# Duplex                                      343                         343
# Edificio                                   1396                        1396
# Garage                                        1                           1
# Hospedaje                                     1                           1
# Huerta                                       20                          20
# Inmuebles productivos urbanos               200                         200
# Local Comercial                            3055                        3055
# Local en centro comercial                   165                         165
# Lote                                          5                           5
# Nave industrial                              76                          76
# Oficina comercial                          1741                        1741
# Otros                                       134                         134
# Quinta Vacacional                           395                         395
# Rancho                                      170                         170
# Terreno                                    9945                        9945
# Terreno comercial                          1326                        1326
# Terreno industrial                           31                          31
# Villa                                       340                         340
#
#                                precio
# tipodepropiedad
# Apartamento                     57341
# Bodega comercial                 1406
# Casa                           141717
# Casa en condominio              19297
# Casa uso de suelo                 708
# Departamento Compartido           141
# Duplex                            343
# Edificio                         1396
# Garage                              1
# Hospedaje                           1
# Huerta                             20
# Inmuebles productivos urbanos     200
# Local Comercial                  3055
# Local en centro comercial         165
# Lote                                5
# Nave industrial                    76
# Oficina comercial                1741
# Otros                             134
# Quinta Vacacional                 395
# Rancho                            170
# Terreno                          9945
# Terreno comercial                1326
# Terreno industrial                 31
# Villa                             340
#
# [24 rows x 22 columns]

# %%
#Lotes, hospedajes y garages hay menos de 10 datos, los elimino
#Tambien elimino los que no tienen tipo de propiedad (53 filas en total)
df = df[(df["tipodepropiedad"] != "Lote") | (df["tipodepropiedad"] != "Garage") | (df["tipodepropiedad"] != "Hospedaje")]

# %% [markdown]
# ## Comienzo el análisis

# %%
xhabgb = df.groupby("habitaciones")#Por habitacion group by
xhab = xhabgb.agg({"precio" : ["mean", "std"], "antiguedad" : "mean", "banos" : "mean", "piscina" : "sum", "garages" : "mean"}) #Por habitacion Data frame
xhab["cantidad"] = df["habitaciones"].value_counts()

# %%
xhab.columns = ["precio_mean", "precio_std", "antiguedad_mean", "banos_mean", "piscina_sum", "garages_mean", "cantidad"]
xhab.reset_index(inplace=True)
xhab["precioxhab_mean"] = xhab["precio_mean"] / xhab["habitaciones"]
xhab
# Out:
#           habitaciones          precio_mean           precio_std  \
# 0                 1.00         1,806,074.64         1,549,486.15
# 1                 2.00         1,616,899.96         1,652,561.10
# 2                 3.00         2,769,606.78         2,149,011.87
# 3                 4.00         3,494,388.63         2,317,473.54
# 4                 5.00         3,284,971.94         2,255,098.95
# 5                 6.00         3,165,558.67         2,110,282.81
# 6                 7.00         3,562,563.99         2,295,234.99
# 7                 8.00         3,432,464.06         2,178,783.38
# 8                 9.00         3,936,173.91         2,806,283.55
# 9                10.00         4,520,161.52         2,735,238.19
#
#        antiguedad_mean           banos_mean          piscina_sum  \
# 0                 8.34                 1.15               633.00
# 1                 7.62                 1.45             4,407.00
# 2                 7.30                 2.33            12,721.00
# 3                11.32                 2.86             2,226.00
# 4                14.64                 2.86               239.00
# 5                17.31                 2.96                57.00
# 6                18.09                 3.00                 8.00
# 7                18.19                 3.12                13.00
# 8                20.08                 3.00                 2.00
# 9                16.53                 2.79                 3.00
#
#           garages_mean  cantidad      precioxhab_mean
# 0                 0.99      5069         1,806,074.64
# 1                 1.28     57808           808,449.98
# 2                 1.82    121887           923,202.26
# 3                 1.93     25068           873,597.16
# 4                 1.77      4596           656,994.39
# 5                 1.55      1669           527,593.11
# 6                 1.57       539           508,937.71
# 7                 1.41       398           429,058.01
# 8                 1.38       179           437,352.66
# 9                 1.13       316           452,016.15

# %%
sns.boxplot(x="habitaciones", y="precio", data=df, palette="hls")

# %%
#Separar de a 5
sns.boxplot(x="habitaciones", y="antiguedad", data=df, palette="hls")

# %%
xhab.plot("habitaciones", "precio_mean", kind="barh")
xhab.plot("habitaciones", "precioxhab_mean", kind="barh")
xhab.plot("habitaciones", "cantidad", kind="barh")

# %%
#Veo cuales son los tipos de propiedades con mas propiedades
df["tipodepropiedad"].value_counts()
# Out:
# Casa                             141717
# Apartamento                       57341
# Casa en condominio                19297
# Terreno                            9945
# Local Comercial                    3055
# Oficina comercial                  1741
# Bodega comercial                   1406
# Edificio                           1396
# Terreno comercial                  1326
# Casa uso de suelo                   708
# Quinta Vacacional                   395
# Duplex                              343
# Villa                               340
# Inmuebles productivos urbanos       200
# Rancho                              170
# Local en centro comercial           165
# Departamento Compartido             141
# Otros                               134
# Nave industrial                      76
# Terreno industrial                   31
# Huerta                               20
# Lote                                  5
# Garage                                1
# Hospedaje                             1
# Name: tipodepropiedad, dtype: int64

# %%
#Segun el tipo de propiedad que porcentaje tiene el dato de habitaciones
serieaux = aux["habitaciones"] / aux["id"]
serieaux.sort_values(ascending=False)
#Esto me da una idea de que tan importante es la cantidad de habitaciones para cada tipo de propiedad
#Por ejemplo, en un terreno es un dato que no es importante, mientras en una casa sí
# Out:
# tipodepropiedad
# Hospedaje                                       1.00
# Duplex                                          0.99
# Casa en condominio                              0.99
# Apartamento                                     0.98
# Casa                                            0.98
# Departamento Compartido                         0.97
# Quinta Vacacional                               0.92
# Villa                                           0.89
# Rancho                                          0.84
# Casa uso de suelo                               0.71
# Otros                                           0.51
# Inmuebles productivos urbanos                   0.41
# Huerta                                          0.35
# Edificio                                        0.22
# Oficina comercial                               0.19
# Nave industrial                                 0.17
# Local en centro comercial                       0.13
# Local Comercial                                 0.12
# Bodega comercial                                0.11
# Terreno industrial                              0.10
# Terreno comercial                               0.05
# Terreno                                         0.05
# Lote                                            0.00
# Garage                                          0.00
# dtype: float64

# %%
#Ahora veo la cantidad de propiedades en venta según el tipo de propiedad
#Por esto y lo hecho en la celda de arriba elijo analizar
prophab = ["Casa", "Apartamento", "Casa en condominio"]
#Me baso en cantidad de propiedades y en que la mayoria tenga el dato de habs
df["tipodepropiedad"].value_counts()
# Out:
# Casa                             141717
# Apartamento                       57341
# Casa en condominio                19297
# Terreno                            9945
# Local Comercial                    3055
# Oficina comercial                  1741
# Bodega comercial                   1406
# Edificio                           1396
# Terreno comercial                  1326
# Casa uso de suelo                   708
# Quinta Vacacional                   395
# Duplex                              343
# Villa                               340
# Inmuebles productivos urbanos       200
# Rancho                              170
# Local en centro comercial           165
# Departamento Compartido             141
# Otros                               134
# Nave industrial                      76
# Terreno industrial                   31
# Huerta                               20
# Lote                                  5
# Garage                                1
# Hospedaje                             1
# Name: tipodepropiedad, dtype: int64

# %%
#Me quedo con los 5 mas "populares"
df["cantidad"] = 1
dfmaspop = df.groupby(["tipodepropiedad", "habitaciones"]).agg({"cantidad" : "sum"}).reset_index()
dfmaspop = dfmaspop.pivot(index="habitaciones", columns="tipodepropiedad", values="cantidad")
dfmaspop = dfmaspop.fillna(0)
dfmaspop = dfmaspop[prophab]
dfmaspop
# Out:
# tipodepropiedad                 Casa          Apartamento   Casa en condominio
# habitaciones
#  1.00                       1,549.00             2,841.00               186.00
#  2.00                      23,789.00            30,040.00             3,004.00
#  3.00                      84,651.00            22,566.00            13,608.00
#  4.00                      21,714.00               780.00             2,095.00
#  5.00                       4,179.00                64.00               143.00
#  6.00                       1,458.00                23.00                29.00
#  7.00                         458.00                 6.00                 5.00
#  8.00                         298.00                13.00                 6.00
#  9.00                         120.00                 9.00                 2.00
# 10.00                         163.00                 5.00                 4.00

# %%
#Divido cada columna por los totales, asi me quedo con porcentajes
cant_total_por_hab = dfmaspop.sum(axis=1)
dfmaspop = dfmaspop.div(cant_total_por_hab, axis=0)
dfmaspop
# Out:
# tipodepropiedad                 Casa          Apartamento   Casa en condominio
# habitaciones
#  1.00                           0.34                 0.62                 0.04
#  2.00                           0.42                 0.53                 0.05
#  3.00                           0.70                 0.19                 0.11
#  4.00                           0.88                 0.03                 0.09
#  5.00                           0.95                 0.01                 0.03
#  6.00                           0.97                 0.02                 0.02
#  7.00                           0.98                 0.01                 0.01
#  8.00                           0.94                 0.04                 0.02
#  9.00                           0.92                 0.07                 0.02
# 10.00                           0.95                 0.03                 0.02

# %%
sns.heatmap(dfmaspop)
dfmaspop.plot.bar(stacked=True)

# %%
xpropgb = df.groupby("tipodepropiedad")
xprop = xpropgb.agg({"precio" : "mean", "antiguedad" : "mean", "banos" : "mean"})

# %%
xprop["cantidad"] = df["tipodepropiedad"].value_counts()
xprop.sort_values(by="cantidad", ascending=False)
# Out:
#                                             precio           antiguedad  \
# tipodepropiedad
# Casa                                  2,398,157.71                 8.27
# Apartamento                           2,763,768.66                 8.36
# Casa en condominio                    2,898,927.04                 6.33
# Terreno                               1,805,201.80                 1.03
# Local Comercial                       2,365,064.16                 9.12
# Oficina comercial                     3,148,532.75                12.84
# Bodega comercial                      2,693,757.70                 9.64
# Edificio                              5,009,499.37                15.89
# Terreno comercial                     2,472,024.59                 5.03
# Casa uso de suelo                     3,732,469.23                18.00
# Quinta Vacacional                     3,187,426.46                 7.54
# Duplex                                1,271,757.97                 9.85
# Villa                                 2,767,351.76                 6.63
# Inmuebles productivos urbanos         3,743,070.11                15.67
# Rancho                                4,032,681.51                10.47
# Local en centro comercial             2,212,631.13                 7.57
# Departamento Compartido               2,560,161.89                 6.15
# Otros                                 2,881,688.86                 3.89
# Nave industrial                       3,742,600.00                10.89
# Terreno industrial                    3,647,994.45                 7.29
# Huerta                                3,543,350.00                 8.78
# Lote                                    988,760.80                 0.00
# Hospedaje                             3,000,000.00                  nan
# Garage                                  500,000.00                  nan
#
#                                              banos  cantidad
# tipodepropiedad
# Casa                                          2.24    141717
# Apartamento                                   1.82     57341
# Casa en condominio                            2.37     19297
# Terreno                                       1.69      9945
# Local Comercial                               1.81      3055
# Oficina comercial                             1.98      1741
# Bodega comercial                              1.85      1406
# Edificio                                      2.63      1396
# Terreno comercial                             1.81      1326
# Casa uso de suelo                             2.40       708
# Quinta Vacacional                             2.30       395
# Duplex                                        1.36       343
# Villa                                         2.22       340
# Inmuebles productivos urbanos                 2.39       200
# Rancho                                        1.86       170
# Local en centro comercial                     1.70       165
# Departamento Compartido                       1.79       141
# Otros                                         2.00       134
# Nave industrial                               2.20        76
# Terreno industrial                            1.67        31
# Huerta                                        1.62        20
# Lote                                           nan         5
# Hospedaje                                      nan         1
# Garage                                         nan         1

# %%
xprovgb = df.groupby("provincia")
xprov = xprovgb.agg({"precio" : "mean", "antiguedad" : "mean", "banos" : "mean"})
xprov["cantidad"] = df["provincia"].value_counts()
xprov.reset_index(inplace=True)
xprov
# Out:
#                 provincia               precio           antiguedad  \
# 0          Aguascalientes         1,477,188.77                 7.52
# 1   Baja California Norte           767,441.75                 5.79
# 2     Baja California Sur         1,216,452.82                 2.46
# 3                Campeche         1,570,917.82                 3.91
# 4                 Chiapas         1,924,125.72                 5.41
# 5               Chihuahua         1,744,530.61                 6.52
# 6                Coahuila         1,505,305.45                 6.31
# 7                  Colima         1,531,380.16                 5.67
# 8        Distrito Federal         3,471,705.09                12.19
# 9                 Durango         1,210,388.98                 4.99
# 10         Edo. de México         2,762,464.91                10.03
# 11             Guanajuato         1,866,959.43                 5.73
# 12               Guerrero         2,548,741.86                 7.61
# 13                Hidalgo         1,305,550.54                 3.47
# 14                Jalisco         2,367,693.58                 6.64
# 15              Michoacán         1,478,503.67                 7.06
# 16                Morelos         2,290,088.01                 6.46
# 17                Nayarit         1,426,790.82                 4.68
# 18             Nuevo León         2,717,757.65                 7.54
# 19                 Oaxaca         1,575,517.89                 5.40
# 20                 Puebla         2,298,403.64                 4.55
# 21              Querétaro         2,144,108.90                 3.70
# 22           Quintana Roo         2,402,966.94                 4.54
# 23        San luis Potosí         1,920,424.96                 3.98
# 24                Sinaloa         1,634,571.64                 6.15
# 25                 Sonora         1,483,715.86                 5.94
# 26                Tabasco         2,300,480.23                 5.30
# 27             Tamaulipas         1,589,666.98                 5.55
# 28               Tlaxcala         1,080,993.34                 3.69
# 29               Veracruz         1,889,788.52                 4.63
# 30                Yucatán         2,036,019.84                 3.07
# 31              Zacatecas         1,453,747.80                 6.40
#
#                   banos  cantidad
# 0                  2.12      1753
# 1                  1.37      3220
# 2                  1.61      1700
# 3                  1.96       263
# 4                  2.21      1126
# 5                  2.13      4590
# 6                  2.14      3695
# 7                  2.04      1008
# 8                  1.99     58790
# 9                  1.95      2275
# 10                 2.08     41607
# 11                 2.23      2860
# 12                 2.29      2678
# 13                 1.81      2521
# 14                 2.22     21238
# 15                 1.90      2471
# 16                 2.35      7337
# 17                 1.89      1352
# 18                 2.31     15324
# 19                 1.85       711
# 20                 2.25     10421
# 21                 2.40     16988
# 22                 2.34      4756
# 23                 2.25      8447
# 24                 2.03      1806
# 25                 1.89      2988
# 26                 2.34       994
# 27                 1.95      2303
# 28                 1.55       839
# 29                 2.27      5762
# 30                 2.59      7928
# 31                 1.80        94

# %%
xprovmax = xprov.loc[(xprov["cantidad"] >= 10000)]
xprovmax.plot(x="provincia", y="cantidad", kind="bar")

# %%
xprovcount = xprovgb.count()
seriesprov = xprovcount["habitaciones"] / xprovcount["id"]
seriesprov.sort_values(ascending=False)
# Out:
# provincia
# Baja California Norte                   0.98
# Morelos                                 0.95
# Guerrero                                0.95
# Edo. de México                          0.94
# Baja California Sur                     0.93
# Yucatán                                 0.93
# Tlaxcala                                0.92
# Sonora                                  0.92
# Distrito Federal                        0.92
# Guanajuato                              0.91
# Coahuila                                0.91
# Michoacán                               0.91
# Puebla                                  0.90
# Hidalgo                                 0.90
# Aguascalientes                          0.90
# Colima                                  0.90
# Tamaulipas                              0.89
# Durango                                 0.89
# Veracruz                                0.88
# Zacatecas                               0.88
# Quintana Roo                            0.88
# Querétaro                               0.88
# Sinaloa                                 0.88
# Nuevo León                              0.88
# Jalisco                                 0.87
# San luis Potosí                         0.87
# Chiapas                                 0.86
# Nayarit                                 0.86
# Tabasco                                 0.85
# Oaxaca                                  0.84
# Chihuahua                               0.84
# Campeche                                0.79
# dtype: float64

# %%
provmaspop = ["Distrito Federal", "Edo. de México", "Jalisco", "Querétaro", "Nuevo León", "Puebla", "Yucatán"]
df["provincia"].value_counts()
# Out:
# Distrito Federal         58790
# Edo. de México           41607
# Jalisco                  21238
# Querétaro                16988
# Nuevo León               15324
# Puebla                   10421
# San luis Potosí           8447
# Yucatán                   7928
# Morelos                   7337
# Veracruz                  5762
# Quintana Roo              4756
# Chihuahua                 4590
# Coahuila                  3695
# Baja California Norte     3220
# Sonora                    2988
# Guanajuato                2860
# Guerrero                  2678
# Hidalgo                   2521
# Michoacán                 2471
# Tamaulipas                2303
# Durango                   2275
# Sinaloa                   1806
# Aguascalientes            1753
# Baja California Sur       1700
# Nayarit                   1352
# Chiapas                   1126
# Colima                    1008
# Tabasco                    994
# Tlaxcala                   839
# Oaxaca                     711
# Campeche                   263
# Zacatecas                   94
# Name: provincia, dtype: int64

# %%
df["cantidad"] = 1
dfciudad = df.groupby(["provincia", "habitaciones"]).agg({"cantidad" : "sum"}).reset_index()
dfciudad = dfciudad.pivot(index="habitaciones", columns="provincia", values="cantidad")
dfciudad = dfciudad.fillna(0)
dfciudad = dfciudad[provmaspop]
dfciudad
# Out:
# provincia        Distrito Federal       Edo. de México              Jalisco  \
# habitaciones
#  1.00                    2,218.00               548.00               250.00
#  2.00                   21,062.00             9,406.00             4,188.00
#  3.00                   23,479.00            22,200.00            10,492.00
#  4.00                    5,065.00             5,359.00             2,645.00
#  5.00                    1,118.00               859.00               586.00
#  6.00                      514.00               321.00               192.00
#  7.00                      196.00               107.00                69.00
#  8.00                      142.00                66.00                43.00
#  9.00                       59.00                33.00                24.00
# 10.00                      116.00                58.00                38.00
#
# provincia               Querétaro           Nuevo León               Puebla  \
# habitaciones
#  1.00                      186.00               307.00               239.00
#  2.00                    2,160.00             2,986.00             1,927.00
#  3.00                   10,856.00             8,189.00             6,010.00
#  4.00                    1,530.00             1,435.00             1,023.00
#  5.00                      160.00               321.00               149.00
#  6.00                       53.00               104.00                30.00
#  7.00                       10.00                21.00                 9.00
#  8.00                       14.00                24.00                15.00
#  9.00                        8.00                 6.00                 4.00
# 10.00                        6.00                16.00                14.00
#
# provincia                 Yucatán
# habitaciones
#  1.00                      157.00
#  2.00                    1,475.00
#  3.00                    4,637.00
#  4.00                      931.00
#  5.00                       97.00
#  6.00                       36.00
#  7.00                        3.00
#  8.00                        7.00
#  9.00                        1.00
# 10.00                        1.00

# %%
cant_total_por_prov = dfciudad.sum(axis=1)
dfciudad = dfciudad.div(cant_total_por_prov, axis=0)
dfciudad
# Out:
# provincia        Distrito Federal       Edo. de México              Jalisco  \
# habitaciones
#  1.00                        0.57                 0.14                 0.06
#  2.00                        0.49                 0.22                 0.10
#  3.00                        0.27                 0.26                 0.12
#  4.00                        0.28                 0.30                 0.15
#  5.00                        0.34                 0.26                 0.18
#  6.00                        0.41                 0.26                 0.15
#  7.00                        0.47                 0.26                 0.17
#  8.00                        0.46                 0.21                 0.14
#  9.00                        0.44                 0.24                 0.18
# 10.00                        0.47                 0.23                 0.15
#
# provincia               Querétaro           Nuevo León               Puebla  \
# habitaciones
#  1.00                        0.05                 0.08                 0.06
#  2.00                        0.05                 0.07                 0.04
#  3.00                        0.13                 0.10                 0.07
#  4.00                        0.09                 0.08                 0.06
#  5.00                        0.05                 0.10                 0.05
#  6.00                        0.04                 0.08                 0.02
#  7.00                        0.02                 0.05                 0.02
#  8.00                        0.05                 0.08                 0.05
#  9.00                        0.06                 0.04                 0.03
# 10.00                        0.02                 0.06                 0.06
#
# provincia                 Yucatán
# habitaciones
#  1.00                        0.04
#  2.00                        0.03
#  3.00                        0.05
#  4.00                        0.05
#  5.00                        0.03
#  6.00                        0.03
#  7.00                        0.01
#  8.00                        0.02
#  9.00                        0.01
# 10.00                        0.00

# %%
sns.heatmap(dfciudad)
dfciudad.plot.bar(stacked=True)

# %%
consum = df[df["usosmultiples"] == True]

# %%
consum
# Out:
#             id                                             titulo  \
# 12       47890             hermosa casa en zibata queretaro 170m²
# 31      118889  vendo hermosa casa en fraccionamiento lomas de...
# 34      173573                casa en venta lomas de la herradura
# 62      263775            excelente casa en condominio horizontal
# 64      171944              nuevo al poniente y en parcialidades.
# ...        ...                                                ...
# 239887   98806  departamento en venta en interlomas, huixquilucan
# 239908   13986       casa en condominio en venta en jardín dorado
# 239948   48555                  venta en misión jardines, zapopan
# 239952  252801                               departamento lo alto
# 239989  175203               casa venta renta en rinconada jurica
#
#                                               descripcion     tipodepropiedad  \
# 12      <p><strong>casa </strong>en venta en fracciona...                Casa
# 31      <p>vendo hermosa casa en fraccionamiento lomas...                Casa
# 34      casa iluminada, con buena distribucion, 350m2 ...                Casa
# 62      de solo 40 casas a un costado de la prepa del ...  Casa en condominio
# 64      un nuevo estilo de vida al sur de la ciudad. \...         Apartamento
# ...                                                   ...                 ...
# 239887  <p>exclusivo departamento dise&ntilde;ado y de...         Apartamento
# 239908  casa adjudicada en fraccionamiento terrabella,...  Casa en condominio
# 239948  bonita casa, en fraccionamiento residencial mi...  Casa en condominio
# 239952  excelente departamento en renta (amueblado $45...         Apartamento
# 239989  terreno 404m2 \nconst. 347 m2 \n\npreciosa cas...                Casa
#
#                                              direccion          ciudad  \
# 12                            Pitahayas 2 - 58, Zibata       Querétaro
# 31                FRACCIONAMIENTO LOMAS DE SAN ALFONSO          Puebla
# 34                            PASEO DE LA HERRADURA 00    Huixquilucan
# 62                                              VERONA         Metepec
# 64                                   Av. de las Torres  Alvaro Obregón
# ...                                                ...             ...
# 239887  Hacienda de Gaviotas, Interlomas, Huixquilucan    Huixquilucan
# 239908                                    Del Nardo 40         Tijuana
# 239948                             Mision Gardenias 17         Zapopan
# 239952                               Blvd. Bosque Real    Huixquilucan
# 239989                                          Jurica       Querétaro
#
#                     provincia           antiguedad         habitaciones  \
# 12                  Querétaro                 0.00                 3.00
# 31                     Puebla                 5.00                 3.00
# 34             Edo. de México                20.00                 4.00
# 62             Edo. de México                 5.00                 4.00
# 64           Distrito Federal                 0.00                 2.00
# ...                       ...                  ...                  ...
# 239887         Edo. de México                 7.00                 3.00
# 239908  Baja California Norte                 5.00                 3.00
# 239948                Jalisco                 9.00                 2.00
# 239952         Edo. de México                 5.00                 3.00
# 239989              Querétaro                 2.00                 3.00
#
#                     garages  ...                  lat                  lng  \
# 12                     2.00  ...                20.68              -100.32
# 31                     2.00  ...                18.97               -98.24
# 34                      nan  ...                19.41               -99.27
# 62                      nan  ...                  nan                  nan
# 64                     2.00  ...                19.33               -99.24
# ...                     ...  ...                  ...                  ...
# 239887                 3.00  ...                19.37               -99.35
# 239908                 1.00  ...                32.53              -116.88
# 239948                 1.00  ...                20.75              -103.44
# 239952                 3.00  ...                  nan                  nan
# 239989                 2.00  ...                20.65              -100.43
#
#             fecha  gimnasio  usosmultiples  piscina escuelascercanas  \
# 12     2013-08-12     False           True    False             True
# 31     2013-01-20     False           True    False             True
# 34     2016-11-19     False           True    False             True
# 62     2014-04-22     False           True    False            False
# 64     2016-12-10      True           True     True             True
# ...           ...       ...            ...      ...              ...
# 239887 2013-05-03      True           True     True            False
# 239908 2012-05-29     False           True    False            False
# 239948 2012-10-04     False           True    False             True
# 239952 2015-10-06      True           True     True             True
# 239989 2016-09-15     False           True     True             True
#
#         centroscomercialescercanos               precio  cantidad
# 12                            True         1,500,000.00         1
# 31                            True         1,450,000.00         1
# 34                            True         7,900,000.00         1
# 62                           False         3,250,000.00         1
# 64                            True         3,500,000.00         1
# ...                            ...                  ...       ...
# 239887                        True         6,080,000.00         1
# 239908                       False           540,000.00         1
# 239948                        True           595,000.00         1
# 239952                        True         7,050,000.00         1
# 239989                        True         3,850,000.00         1
#
# [13222 rows x 24 columns]

# %%
consumdf = consum.groupby("tipodepropiedad").agg({"precio" : "mean"})
consumdf["cantidad_con_sum"] = df[(df["usosmultiples"] == True)]["tipodepropiedad"].value_counts()
consumdf.reset_index(inplace=True)
consumdf
# Out:
#            tipodepropiedad               precio  cantidad_con_sum
# 0              Apartamento         4,154,345.78              6187
# 1                     Casa         3,610,687.59              5099
# 2       Casa en condominio         3,342,641.23              1907
# 3  Departamento Compartido         4,163,549.81                26
# 4                 Edificio         1,470,000.00                 1
# 5        Oficina comercial         1,912,500.00                 2

# %%
consumdf.iloc[[0, 1, 2]].plot(x="tipodepropiedad", y="cantidad_con_sum", kind="bar")

# %%
df["cantidad"] = 1
sum_df = df.groupby("usosmultiples").agg({"precio" : "mean", "cantidad" : "sum", "antiguedad" : "mean",
                                          "habitaciones" : "mean", "banos" : "mean"})
sum_df
# Out:
#                             precio  cantidad           antiguedad  \
# usosmultiples
# False                 2,455,262.00    226778                 8.35
# True                  3,827,091.02     13222                 4.59
#
#                       habitaciones                banos
# usosmultiples
# False                         2.90                 2.11
# True                          2.88                 2.49

# %%
sum_2 = df.groupby(["provincia", "usosmultiples"]).agg({"cantidad" : "sum"}).reset_index()
sum_2 = sum_2.pivot(index="usosmultiples", columns="provincia", values="cantidad")
sum_2
# Out:
# provincia      Aguascalientes  Baja California Norte  Baja California Sur  \
# usosmultiples
# False                    1643                   3186                 1695
# True                      110                     34                    5
#
# provincia      Campeche  Chiapas  Chihuahua  Coahuila  Colima  \
# usosmultiples
# False               262     1118       4563      3671     986
# True                  1        8         27        24      22
#
# provincia      Distrito Federal  Durango  ...  Quintana Roo  San luis Potosí  \
# usosmultiples                             ...
# False                     54746     2254  ...          4401             8368
# True                       4044       21  ...           355               79
#
# provincia      Sinaloa  Sonora  Tabasco  Tamaulipas  Tlaxcala  Veracruz  \
# usosmultiples
# False             1769    2961      981        2299       836      5605
# True                37      27       13           4         3       157
#
# provincia      Yucatán  Zacatecas
# usosmultiples
# False             7800         91
# True               128          3
#
# [2 rows x 32 columns]
