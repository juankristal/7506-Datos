# %% [markdown]
# # XGBoost - train simple - RandomSearch 1

# %% [markdown]
# Continuamos la busqueda de hiper-parametros para el modelo de train simple (sin columnas complejas), a partir de los resultados del random search 0

# %% [markdown]
# ## Imports

# %%
import common.common_machine_learning as common
import common.my_pipeline as my_pipe
import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error
from xgboost import XGBRegressor
import time

# %% [markdown]
# ### Ignorar FutureWarnings

# %%
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## Constantes

# %%
TARGET = 'precio'
K = 3
RANDOM_SEMILLA = 3 # numero favorito (de la suerte)
XGB_RE_OBJECTIVE = 'reg:squarederror'

# %% [markdown]
# La ultima busqueda realizo 10 iteraciones con K = 3 => Fueron 30 fit's.
# Todo eso tardo aprox. 20 minutos.

# %%
20/30
# Out:
# 0.6666666666666666

# %% [markdown]
# Aproximadamente tarda 0.7 minutos / fit

# %%
30/(20/30)
# Out:
# 45.0

# %% [markdown]
# En 45 fits gasto 30 minutos. Y hago 3 fits por cada iter.

# %%
45/3
# Out:
# 15.0

# %% [markdown]
# Entonces con 15 iteracion deberia tardar 30 minutos aprox.

# %%
N_ITER = 15

# %% [markdown]
# ## Carga del set de datos y pre-pre-procesamiento

# %%
train = common.cargar_set_optimizado('sets_de_datos/train.csv', index_col = 0)

X = train.drop([TARGET], axis = 1).copy()
y = train[TARGET].copy()

X = common.eliminar_columnas_complejas(X)
X = X.fillna(value = {'tipodepropiedad' : 'nan', 'provincia' : 'nan', 'ciudad' : 'nan'})

# %% [markdown]
# ## Pipeline

# %%
pre_procesar_pipe = my_pipe.get_train_simple_pre_pipeline()
busqueda_pipe = Pipeline(steps = [
    ('pre-procesar', pre_procesar_pipe),
    ('xgb_regressor', XGBRegressor(objective = XGB_RE_OBJECTIVE))
])

# %% [markdown]
# ## Busqueda 1

# %%
hyper_params = {
    "xgb_regressor__n_estimators": [650 ,850], # default 100,
    "xgb_regressor__learning_rate": [0.01, 0.05], # default 0.1
    "xgb_regressor__gamma": [0.2, 0.8],
    "xgb_regressor__lambda": [0.8, 1.2],
    "xgb_regressor__max_depth": [4, 7], # default 3 # < 15 columnas = cantidad columnas feature originales
    "xgb_regressor__subsample": [0.65, 0.45],
    "xgb_regressor__colsample_bytree": [0.65, 0.45],
    "xgb_regressor__min_child_weight": [3, 6]
}

busqueda = RandomizedSearchCV(
            busqueda_pipe, 
            param_distributions=hyper_params,
            random_state = RANDOM_SEMILLA,
            n_iter = N_ITER,
            cv=K, 
            verbose=1, 
            n_jobs=1, 
            return_train_score=True,
            iid = True
        )

# %%
tiempo_inicio = time.time()
busqueda = busqueda.fit(X,y)
tiempo_fin = time.time()
minutos = (tiempo_fin - tiempo_inicio) / 60
print('Tiempo de busqueda : {0:.2f} minutos'.format(minutos))
# Out:
# Fitting 3 folds for each of 15 candidates, totalling 45 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed: 33.8min finished
# Tiempo de busqueda : 35.28 minutos

# %% [markdown]
# Nice timing !

# %%
common.busqueda_mostrar_resultados_df(busqueda.cv_results_)
#common.busqueda_guardar_resultados_df(busqueda.cv_results_, 'resultados_busquedas/dima_xgboost_train_simple_busqueda_1_resultados.csv')

# %%
pd.read_csv('resultados_busquedas/dima_xgboost_train_simple_busqueda_1_resultados.csv')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       27.723460      0.699899         1.607233        0.076304
# 1       56.104165      0.131847         5.050726        0.060570
# 2       45.909231      0.455328         5.220357        0.019243
# 3       28.910614      0.046303         1.579733        0.012599
# 4       43.721508      0.104325         3.825348        0.030971
# 5       23.742591      0.013895         1.723847        0.002533
# 6       37.023111      0.023565         2.155373        0.022482
# 7       29.229402      0.030524         1.602895        0.011864
# 8       59.490831      0.034887         5.414282        0.034787
# 9       36.503590      0.015209         3.731583        0.012041
# 10      37.013720      0.128230         2.192168        0.044625
# 11      24.607766      0.021838         1.683207        0.005563
# 12      29.442466      0.743717         1.619884        0.025590
# 13      35.798003      0.145169         2.063198        0.016914
# 14      36.412091      0.540328         2.074821        0.034705
#
#     param_xgb_regressor__subsample  param_xgb_regressor__n_estimators  \
# 0                             0.65                                650
# 1                             0.45                                850
# 2                             0.65                                850
# 3                             0.45                                650
# 4                             0.45                                650
# 5                             0.65                                650
# 6                             0.65                                850
# 7                             0.45                                650
# 8                             0.65                                850
# 9                             0.65                                650
# 10                            0.65                                850
# 11                            0.65                                650
# 12                            0.65                                650
# 13                            0.65                                850
# 14                            0.45                                850
#
#     param_xgb_regressor__min_child_weight  param_xgb_regressor__max_depth  \
# 0                                       3                               4
# 1                                       6                               7
# 2                                       6                               7
# 3                                       3                               4
# 4                                       3                               7
# 5                                       3                               4
# 6                                       6                               4
# 7                                       6                               4
# 8                                       6                               7
# 9                                       6                               7
# 10                                      6                               4
# 11                                      6                               4
# 12                                      3                               4
# 13                                      3                               4
# 14                                      6                               4
#
#     param_xgb_regressor__learning_rate  param_xgb_regressor__lambda  ...  \
# 0                                 0.05                          0.8  ...
# 1                                 0.05                          0.8  ...
# 2                                 0.05                          1.2  ...
# 3                                 0.01                          0.8  ...
# 4                                 0.05                          1.2  ...
# 5                                 0.05                          0.8  ...
# 6                                 0.01                          0.8  ...
# 7                                 0.01                          1.2  ...
# 8                                 0.01                          0.8  ...
# 9                                 0.01                          0.8  ...
# 10                                0.01                          1.2  ...
# 11                                0.01                          0.8  ...
# 12                                0.01                          0.8  ...
# 13                                0.05                          0.8  ...
# 14                                0.05                          0.8  ...
#
#     split1_test_score  split2_test_score mean_test_score  std_test_score  \
# 0            0.516062           0.515008        0.515396        0.000473
# 1            0.531258           0.531151        0.531237        0.000063
# 2            0.519387           0.518627        0.519214        0.000427
# 3            0.489600           0.489077        0.489094        0.000406
# 4            0.531611           0.530374        0.531154        0.000554
# 5            0.507899           0.507176        0.507501        0.000299
# 6            0.496987           0.495778        0.496164        0.000583
# 7            0.489568           0.488886        0.489019        0.000405
# 8            0.526457           0.526051        0.526353        0.000217
# 9            0.498778           0.498641        0.498742        0.000073
# 10           0.496987           0.495778        0.496164        0.000583
# 11           0.476473           0.476834        0.476428        0.000351
# 12           0.490117           0.488559        0.489125        0.000704
# 13           0.517879           0.517121        0.517508        0.000309
# 14           0.516121           0.515598        0.515846        0.000214
#
#     rank_test_score  split0_train_score  split1_train_score  \
# 0                 7            0.525111            0.525693
# 1                 1            0.577172            0.577093
# 2                 4            0.549751            0.550694
# 3                13            0.492043            0.491444
# 4                 2            0.574525            0.574501
# 5                 8            0.514799            0.514582
# 6                10            0.499720            0.499564
# 7                14            0.491986            0.491383
# 8                 3            0.544459            0.544217
# 9                 9            0.508404            0.508249
# 10               10            0.499720            0.499564
# 11               15            0.478795            0.478195
# 12               12            0.492253            0.492016
# 13                5            0.529657            0.529866
# 14                6            0.527132            0.527157
#
#     split2_train_score  mean_train_score  std_train_score
# 0             0.525193          0.525332         0.000257
# 1             0.578927          0.577730         0.000847
# 2             0.551100          0.550515         0.000565
# 3             0.491753          0.491747         0.000245
# 4             0.574592          0.574539         0.000039
# 5             0.514519          0.514633         0.000120
# 6             0.499107          0.499463         0.000260
# 7             0.491522          0.491630         0.000258
# 8             0.544809          0.544495         0.000243
# 9             0.508573          0.508409         0.000132
# 10            0.499107          0.499463         0.000260
# 11            0.478766          0.478586         0.000276
# 12            0.491261          0.491843         0.000423
# 13            0.529814          0.529779         0.000089
# 14            0.527601          0.527297         0.000216
#
# [15 rows x 24 columns]
