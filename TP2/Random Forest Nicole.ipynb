# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
import common.common_machine_learning as common

#pd.set_option('display.float_format', lambda x: '%.0f' % x)

# %%
def evaluar_rf(modelo, X_test, y_test):
    y_pred = modelo.predict(X_test)
    errors = abs(y_pred - y_test)
    mape = 100 * np.mean(errors / y_test)
    accuracy = 100 - mape
    print('Performance del modelo:')
    print('Average Error: {:0.4f} degrees.'.format(np.mean(errors)))
    print('Accuracy = {:0.2f}%.'.format(accuracy))
    
    return accuracy

# %%
TARGET = 'precio'
columnas = ["tipodepropiedad", "ciudad", "antiguedad", "metroscubiertos",
           "metrostotales", "gimnasio", "usosmultiples", "piscina", "escuelascercanas", "centroscomercialescercanos", "precio"]

# %%
train = pd.read_csv('sets_de_datos/train.csv', index_col = 0)
test = pd.read_csv('sets_de_datos/test.csv', index_col = 0)

# %%
train = train[columnas]
train["antiguedad"].fillna(train["antiguedad"].mean(),inplace=True)
train["metroscubiertos"].fillna(train["metroscubiertos"].mean(), inplace=True)
train["metrostotales"].fillna(train["metrostotales"].mean(), inplace=True)
train["precio"].fillna(train["precio"].mean(), inplace=True)
train.dropna(subset=["tipodepropiedad", "ciudad"], inplace=True)
train.fillna(0, inplace=True)

#test = train[columnas]
#test["antiguedad"].fillna(train["antiguedad"].mean(),inplace=True)
#test["metroscubiertos"].fillna(train["metroscubiertos"].mean(), inplace=True)
#test["metrostotales"].fillna(train["metrostotales"].mean(), inplace=True)
#test["precio"].fillna(train["precio"].mean(), inplace=True)
#test.dropna(subset=["tipodepropiedad", "ciudad"], inplace=True)
#test.fillna(0, inplace=True)

# %%
ciudades_validas = train["ciudad"].value_counts().to_frame().reset_index()
ciudades_validas.columns = ["ciudad", "cantidad"]
ciudades_validas.shape
# Out:
# (875, 2)

# %%
# Elimino las ciudades con menos de 100 casas para reducir la cantidad de col cuando se haga OHE
ciudades_validas = ciudades_validas[ciudades_validas["cantidad"] >= 100]
train = pd.merge(train, ciudades_validas, on = "ciudad", how = "inner")
train = train.drop(["cantidad"], axis = 1)
ciudades_validas.shape
# Out:
# (146, 2)

# %%
train_OHE  = pd.get_dummies(train)

# %%
train
# Out:
#            tipodepropiedad         ciudad  antiguedad  metroscubiertos  \
# 0              Apartamento  Benito Juárez    8.116114             80.0
# 1                     Casa  Benito Juárez   20.000000            227.0
# 2              Apartamento  Benito Juárez    5.000000            127.0
# 3              Apartamento  Benito Juárez    0.000000             98.0
# 4              Apartamento  Benito Juárez    6.000000            160.0
# 5              Apartamento  Benito Juárez    5.000000            122.0
# 6              Apartamento  Benito Juárez    3.000000            120.0
# 7              Apartamento  Benito Juárez   48.000000             75.0
# 8              Apartamento  Benito Juárez    8.116114             86.0
# 9              Apartamento  Benito Juárez   20.000000            120.0
# 10             Apartamento  Benito Juárez   10.000000             90.0
# 11      Casa en condominio  Benito Juárez    0.000000            300.0
# 12      Casa en condominio  Benito Juárez    0.000000            195.0
# 13             Apartamento  Benito Juárez    4.000000             80.0
# 14             Apartamento  Benito Juárez    4.000000            130.0
# 15             Apartamento  Benito Juárez    0.000000            101.0
# 16             Apartamento  Benito Juárez   20.000000            193.0
# 17             Apartamento  Benito Juárez   10.000000            105.0
# 18             Apartamento  Benito Juárez    5.000000            112.0
# 19             Apartamento  Benito Juárez    8.116114            120.0
# 20      Casa en condominio  Benito Juárez    5.000000            120.0
# 21             Apartamento  Benito Juárez    2.000000            180.0
# 22             Apartamento  Benito Juárez    1.000000             80.0
# 23             Apartamento  Benito Juárez   20.000000            100.0
# 24                    Casa  Benito Juárez   10.000000            256.0
# 25             Apartamento  Benito Juárez   10.000000             84.0
# 26             Apartamento  Benito Juárez    1.000000            159.0
# 27             Apartamento  Benito Juárez    2.000000             75.0
# 28      Casa en condominio  Benito Juárez    1.000000            250.0
# 29             Apartamento  Benito Juárez    8.000000            100.0
# ...                    ...            ...         ...              ...
# 232932                Casa    Chicoloapan    6.000000             67.0
# 232933                Casa    Chicoloapan   11.000000             97.0
# 232934                Casa    Chicoloapan   10.000000             61.0
# 232935                Casa    Chicoloapan    8.116114            330.0
# 232936                Casa    Chicoloapan    5.000000            240.0
# 232937                Casa    Chicoloapan    5.000000            220.0
# 232938  Casa en condominio    Chicoloapan   10.000000             70.0
# 232939                Casa    Chicoloapan    5.000000            220.0
# 232940                Casa    Chicoloapan    4.000000             55.0
# 232941                Casa    Chicoloapan    5.000000             70.0
# 232942                Casa    Chicoloapan    8.116114            135.0
# 232943                Casa    Chicoloapan    4.000000             59.0
# 232944  Casa en condominio    Chicoloapan   10.000000            138.0
# 232945                Casa    Chicoloapan    5.000000             43.0
# 232946                Casa    Chicoloapan    5.000000            120.0
# 232947                Casa    Chicoloapan    5.000000            100.0
# 232948                Casa    Chicoloapan    8.116114             50.0
# 232949  Casa en condominio    Chicoloapan    5.000000             90.0
# 232950         Apartamento    Chicoloapan   10.000000             61.0
# 232951                Casa    Chicoloapan   10.000000             61.0
# 232952             Terreno    Chicoloapan    8.116114            160.0
# 232953                Casa    Chicoloapan   10.000000             60.0
# 232954                Casa    Chicoloapan   20.000000             80.0
# 232955                Casa    Chicoloapan   10.000000            201.0
# 232956                Casa    Chicoloapan   26.000000            240.0
# 232957                Casa    Chicoloapan    8.116114             60.0
# 232958                Casa    Chicoloapan   20.000000             72.0
# 232959                Casa    Chicoloapan    0.000000             65.0
# 232960  Casa en condominio    Chicoloapan    4.000000             60.0
# 232961                Casa    Chicoloapan    9.000000             70.0
#
#         metrostotales  gimnasio  usosmultiples  piscina  escuelascercanas  \
# 0           80.000000       0.0            0.0      0.0               0.0
# 1          185.000000       0.0            0.0      0.0               0.0
# 2          127.000000       0.0            0.0      0.0               1.0
# 3          176.765145       0.0            0.0      0.0               0.0
# 4          176.765145       0.0            0.0      0.0               0.0
# 5          122.000000       0.0            0.0      0.0               1.0
# 6          176.765145       1.0            0.0      0.0               0.0
# 7           75.000000       0.0            0.0      0.0               1.0
# 8           86.000000       0.0            0.0      0.0               0.0
# 9          120.000000       0.0            0.0      0.0               0.0
# 10         176.765145       0.0            0.0      0.0               0.0
# 11         176.765145       0.0            0.0      0.0               0.0
# 12         117.000000       0.0            0.0      0.0               1.0
# 14                             0.0  2800000.0
# 15                             0.0  3286000.0
# 16                             1.0  5700000.0
# 17                             1.0  3500000.0
# 18                             1.0  3500000.0
# 19                             0.0  4360608.0
# 20                             1.0  5000000.0
# 21                             0.0  6300000.0
# 22                             1.0  2000000.0
# 23                             0.0  1330000.0
# 24                             0.0  3400000.0
# 25                             1.0  1100000.0
# 26                             0.0  4650000.0
# 27                             1.0  3300000.0
# 28                             1.0  8000000.0
# 29                             0.0  3050000.0
# ...                            ...        ...
# 232932                         1.0   395000.0
# 232933                         0.0   675000.0
# 232934                         0.0   550000.0
# 232935                         0.0  1800000.0
# 232936                         1.0  1990000.0
# 232937                         0.0   850000.0
# 232938                         1.0   517000.0
# 232939                         0.0   850000.0
# 232940                         1.0   430000.0
# 232941                         0.0   700000.0
# 232942                         0.0  1490000.0
# 232943                         1.0   550000.0
# 232944                         0.0   800000.0
# 232945                         0.0   450000.0
# 232946                         1.0   870000.0
# 232947                         1.0  1050000.0
# 232948                         0.0   385000.0
# 232949                         0.0   499000.0
# 232950                         0.0   550000.0
# 232951                         0.0   550000.0
# 232952                         0.0   365000.0
# 232953                         1.0   530000.0
# 232954                         1.0   540000.0
# 232955                         1.0   900000.0
# 232956                         0.0  2200000.0
# 232957                         0.0   490000.0
# 232958                         0.0   630500.0
# 232959                         0.0   500000.0
# 232960                         0.0   850000.0
# 232961                         1.0   395000.0
#
# [232962 rows x 11 columns]

# %%
X = train_OHE.drop([TARGET], axis = 1).copy().values
y = list(train_OHE[TARGET].copy())

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 0)

# %%
X_train
# Out:
# array([[ 10.        , 108.        ,  61.        , ...,   0.        ,
#           0.        ,   0.        ],
#        [  0.        , 300.        , 370.        , ...,   0.        ,
#           0.        ,   0.        ],
#        [ 10.        , 160.        , 176.76514456, ...,   0.        ,
#           0.        ,   0.        ],
#        ...,
#        [  5.        , 150.        , 200.        , ...,   0.        ,
#           0.        ,   0.        ],
#        [  3.        , 215.        , 194.        , ...,   0.        ,
#           0.        ,   0.        ],
#        [ 10.        , 430.        , 176.76514456, ...,   0.        ,
#           0.        ,   0.        ]])

# %%
mejor_rf = RandomForestRegressor(n_estimators = 200, min_samples_split = 5, min_samples_leaf = 1, max_features = "sqrt",
                                max_depth = 50)
mejor_rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=50,
#                       max_features='sqrt', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=5,
#                       min_weight_fraction_leaf=0.0, n_estimators=200,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
evaluar_rf(mejor_rf, X_test, y_test)
# Out:
# Performance del modelo:
# Average Error: 664556.4277 degrees.
# Accuracy = 67.23%.
# 67.2300576704138

# %%
test_OHE = pd.get_dummies(test)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-24-17d6082cbec4> in <module>
# ----> 1 test_OHE = pd.get_dummies(test)
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     857             dummy = _get_dummies_1d(col[1], prefix=pre, prefix_sep=sep,
#     858                                     dummy_na=dummy_na, sparse=sparse,
# --> 859                                     drop_first=drop_first, dtype=dtype)
#     860             with_dummies.append(dummy)
#     861         result = concat(with_dummies, axis=1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in _get_dummies_1d(data, prefix, prefix_sep, dummy_na, sparse, drop_first, dtype)
#     961
#     962     else:
# --> 963         dummy_mat = np.eye(number_of_cols, dtype=dtype).take(codes, axis=0)
#     964
#     965         if not dummy_na:
#
# MemoryError:

# %%
test_OHE

# %%
y_pred = mejor_rf.predict(X_test)

# %%
df = pd.DataFrame({"id": X_test[:,0], "target": y_pred})
#df = df.head(60000)
#df = df.astype({'id': 'int32', 'target': 'int32'})

# %%
filename = 'RF_submit.csv'

df.to_csv(filename,index=False)

# %%
df
