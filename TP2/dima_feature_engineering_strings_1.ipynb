# %% [markdown]
# ## imports

# %%
import pandas as pd
import numpy as np
import time
import string
from nltk.corpus import stopwords 
import re
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# Ignore FutureWarning's

# %%
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## Bibliografia

# %% [markdown]
# Los features basados en strings que se extraen del set datos, estan basados en la siguiente publicacion de kaggle para otro set de datos.

# %% [markdown]
# Biblografia:
# https://www.kaggle.com/lalitparihar44/detailed-text-based-feature-engineering

# %% [markdown]
# Funciones de la publicacion que re-utilizo

# %%
#Function for removing punctuations from string
def remove_punctuations_from_string(string1):
    string1 = string1.lower() #changing to lower case
    translation_table = dict.fromkeys(map(ord, string.punctuation), ' ') #creating dictionary of punc & None
    string2 = string1.translate(translation_table) #translating string1
    return string2
#lets check the function on our test string.

# %%
#The punctuations have been removed from the string. Lets write a similar function for removing
#stopwords.
def remove_stopwords_from_string(string1):
    pattern = re.compile(r'\b(' + r'|'.join(stopwords.words('spanish')) + r')\b\s*') #compiling all stopwords.
    string2 = pattern.sub('', string1) #replacing the occurrences of stopwords in string1
    return string2

# %% [markdown]
# ## Constantes

# %%
_SOLO_PALABRAS_IMPORTANTES = '_solo_palabras_importantes'
_SIN_SIGNOS_PUNTUACION = '_sin_signos_puntuacion'
_CANTIDAD_PALABRAS_IMPORTANTES = '_cantidad_palabras_importantes'
_CANTIDAD_CARACTERES_IMPORTANTES = '_cantidad_caracteres_en_palabras_importantes'
_LONGITUD_MEDIA_PALABRA  = '_longitud_media_palabra'
_CANTIDAD_STOPWORDS = '_cantidad_stopwords'
_CANTIDAD_SIGNOS_PUNTACION = '_cantidad_signos_puntacion'
_CANTIDAD_PALABRAS_MAYUSCULA = '_cantidad_palabras_en_mayuscula'
_CANTIDAD_TITULOS = '_cantidad_titulos'

_CANTIDAD_PALABRAS_TOP_K = '_cantidad_palabras_top_k'
_CANTIDAD_PALABRAS_BOTTOM_K = '_cantidad_palabras_bottom_k'
_CANTIDAD_PALABRAS_EMPIEZAN_TOP_K  = '_cantidad_palabras_empiezan_en_top_k'
_CANTIDAD_PALARAS_TERMINAN_TOP_K = 'cantidad_palabras_terminan_en_top_k'

# %% [markdown]
# ## Funciones auxiliares

# %%
def plot_precio_vs_feature(lista_cols, sufijo_feature, lista_cotas = []):    
    colores = ['blue', 'orange', 'green']
    for i, col in enumerate(lista_cols):
        train_plot = train_strings
        if lista_cotas != []:
            train_plot = train_plot.loc[train_plot[col + sufijo_feature] < lista_cotas[i]] 
        plt.figure()
        plt.scatter(train_plot[col + sufijo_feature], train_plot['precio'], color = colores[i%3])
        plt.xlabel(sufijo_feature.replace('_',' '))
        plt.ylabel('Precio')
        plt.title('Precio VS \n' + sufijo_feature.replace('_',' ') + '\npor ' + col)

# %%
def plot_feature_precio_cantidad(lista_cols, sufijo_feature, lista_cotas = []):
    colores = ['blue', 'orange', 'green']
    train_plot = train_strings.copy()
    train_plot['cuenta'] = 1
    for i, col in enumerate(lista_cols):
        cota = 1000
        if lista_cotas != []:
            cota = lista_cotas[i%len(colores)]
        train_plot = train_plot.loc[train_plot.groupby([col + sufijo_feature])['cuenta'].transform(lambda x : x.sum() > cota)]
        fig, ax =  plt.subplots(1,2)
        fig.tight_layout()
        ax[0].scatter(train_plot[col + sufijo_feature], train_plot['precio'], color = colores[i%len(colores)])
        train_cuenta = train_plot[col + sufijo_feature].value_counts()
        ax[1].bar(train_cuenta.index, train_cuenta.values, color = colores[i%len(colores)])
        ax[0].set_title('Precio vs \n' + sufijo_feature + '\npor ' + col)
        ax[1].set_title('Cantidad registros vs \n' + sufijo_feature + '\npor ' + col)

# %% [markdown]
# ## Set de datos

# %%
train = common.cargar_set_optimizado('sets_de_datos/train.csv', index_col = 0)

# %% [markdown]
# ## Analisis

# %%
cols_string = ['titulo', 'descripcion', 'direccion']
train_strings = train[cols_string+['precio']]
display(train_strings)
# Out:
#                                                    titulo  \
# id
# 254099                                  depto. tipo a-402
# 53461                      condominio horizontal en venta
# 247984              casa en venta urbi 3 recamaras tonala
# 209067  casa sola en toluca zinacantepec con credito i...
# 185997                                     paseos del sol
# 126147                     departamento en venta taxqueña
# 139233                 de oportunidad casa en san lorenzo
# 5013    casa emilia en venta en selvamar playa del carmen
# 44962   pre- venta preciosos depas 2 recamaras con sub...
# 134537                                            terreno
# 51180                                       mi 2° credito
# 103293  departamento en venta, san pedro garza garcia,...
# 47890              hermosa casa en zibata queretaro 170m²
# 130216                 casa matias romero - sión bancaria
# 181436                        casa en venta en valle real
# 201923               casa en venta lomas verdes naucalpan
# 283945               preciosa casa en cumbres del lago \t
# 73348   oportunidad, departamento col del valle, 3 rec...
# 40421   últimos terrenos en preventa!! en bukara coto ...
# 87655                                                 NaN
# 90071   terreno residencial en venta en cumbres quinta...
# 224513                         casa en venta en querétaro
# 129818  comoda casa con recamara en planta baja y ampl...
# 146699  casa en condominio en venta, benito juarez, ca...
# 235958  casa en venta - colinas del cimatario, queréta...
# 97918                            casa venta santa cecilia
# 70294   casa en venta de un nivel , frac. misiones de ...
# 177031                                                NaN
# 144635                      casa en venta en santillana i
# 146158              terreno urbano bardeado zona tesistán
# ...                                                   ...
# 123855  residencia en las cañadas, gran oportunidad pa...
# 2747    departamento exclusivo para tu familia, vive b...
# 130523           casa para remodelar, excelente ubicación
# 149503           departamento en venta en villa de cortes
# 156730  casa en venta, cuautitlán izcalli, estado de m...
# 258795  casa en uno de los desarrollos con mayor plusv...
# 184779                        casa en venta en campanario
# 214176                                       casa tecamac
# 235796    linda casa en venta,cerca del lago de guadalupe
# 103355         se vende casa en delegacion miguel hidalgo
# 267455              departamentos en renta torres palmira
# 199041         casa en venta en residencial agua caliente
# 252709  casa de 2 recamaras en residencial del bosque ...
# 194027                   casa en venta en san luis potosí
# 262913        en venta mitras centro monterrey nuevo leon
# 64820   casa en venta fuentes de satelite, atizapan, e...
# 41090   excelete torre de departamentos en lomas 4ta s...
# 278167                                                NaN
# 191335                                bodega santa maría
# 175203               casa venta renta en rinconada jurica
# 87498                   casa en venta: bosques del contry
# 137337                    departamento residencial coyuya
# 54886                                       casa en venta
# 207892                               bugambilias (ciudad)
# 110268               hermosa casa en villa de los belenes
# 119879  bonita casas de 2 recamaras a 10 minutos del c...
# 259178  casa en condominio a 10 min. del centro de toluca
# 131932                                   nicolas san juan
# 146867                      casa sola. javier rojo gomez.
# 121958  departamento en bosques de las lomas  / av. st...
#
#                                               descripcion  \
# id
# 254099  depto. interior de 80.15m2, consta de sala com...
# 53461   <p>entre sonora y guerrero, atr&aacute;s del h...
# 247984  descripcion \nla mejor ubicacion residencial e...
# 209067  casa en privada con caseta de vigilancia casas...
# 185997  bonito departamento en excelentes condiciones ...
# 126147  amplio departamento, estancia de sala y comedo...
# 139233  ubicada en esquina, pertenece san lorenzo agen...
# 5013    casa emilia en venta playa del carmenfracciona...
# 44962   <p>pre-venta de preciosos departamento ecologi...
# 134537  terreno de 5.500m2 bardeado, uso de suelo h-20...
# 51180   <p>mi 2&deg; credito<br />para todos aquellos ...
# 103293  departamento nuevo ,256 m2 de construccion,un ...
# 47890   <p><strong>casa </strong>en venta en fracciona...
# 130216  flamante casa habitación en condominio horizon...
# 181436  pre venta de residencia en la toscana con exce...
# 201923  <p>casa en dos niveles, 3 recámaras la princip...
# 283945  <p>clave: vcln2450 fecha de actualizaci&oacute...
# 73348   magnifico departamento con excelente distribuc...
# 40421   terreno ubicado en bukara coto club, el cual s...
# 87655   -- rcv151104-lv-27 --    linda casa con area d...
# 90071   <p>excelente terreno plano, frente a parque en...
# 224513  nocnok id: mx15-bk0340. hermosa casa en conjun...
# 129818  <p>comoda casa con recamara en planta baja y a...
# 146699  casa en venta en cancun en residencial cumbres...
# 235958  <p>propiedad en un nivel, con espacios amplios...
# 97918   hermosa casa en santa cecilia en apodaca, cerc...
# 70294   ¡excelente oportunidad!  \n\ncasa de un nivel ...
# 177031  hermosa casa remodelada, con acabados de lujo,...
# 144635  casa en coto 3 recamaras, estudio, sala-comedo...
# 146158  en zona de urbanización progresiva, terreno pl...
# ...                                                   ...
# 123855  residencia en las cañadas, una gran oportunida...
# 2747    www. \n3 recamaras, 2 baños \n2 autos \nentreg...
# 130523  estado de conservación: para remodelar, área d...
# 149503  últimos departamentos en preventa dentro de ex...
# 156730  casa en venta en lago de guadalupe. excelente ...
# 258795  <p>el desarrollo cuenta con barda perimetral c...
# 184779  bonita y bien ubicada casa en venta, 3 recamar...
# 214176  hermosa casa, en excelente mantenimiento y muy...
# 235796  buen proyecto, desarrollada en tres plantas, p...
# 103355  excelente casa muy bien ubicada en zona tranqu...
# 267455  departamento en venta avenida palmira , san lu...
# 199041  se vende bonita casa en el fracc. residencial ...
# 252709  casa de 2 recámaras en residencial del bosque ...
# 194027  nocnok id: mx16-bo3390. sin posesión física, p...
# 262913   en excelente ubicación zona mitras centro. am...
# 64820   casa en venta fuentes de satélite, atizapán, e...
# 41090   <p>exclusiva torre de departamentos en venta e...
# 278167  -- rcv347n-287 --    casas nuevas estilo minim...
# 191335  ideal para inversionista \nideal centro de dis...
# 175203  terreno 404m2 \nconst. 347 m2 \n\npreciosa cas...
# 87498   <p>casa en venta, en magníficas condiciones; e...
# 137337  departamento ubicado en planta baja, con excel...
# 54886   bonita casa para remodelar en una calle cerrad...
# 207892  coto privado de tan solo 7 casas donde cada fa...
# 110268  <p>moderna casa 3 pisos, muro llor&oacute;n , ...
# 119879  vendo casa en bosques de ica residencial a 10 ...
# 259178  casa con un jardin amplio, un cuarto de servic...
# 131932  departamento con excelente ubicación, muy cerc...
# 146867  casa sola, dividida en cuatro departamentos de...
# 121958  id:19816, muy bonito e iluminado departamento,...
#
#                                                 direccion      precio
# id
# 254099                    Avenida Division del Norte 2005   2273000.0
# 53461                                          AV. MEXICO   3600000.0
# 247984                                        Urbi Tonala   1200000.0
# 209067                      IGNACIO MANUEL ALTAMIRANO 128    650000.0
# 185997                                    PASEOS DEL SOL    1150000.0
# 126147                              Condominio Tlalpan 2B   1100000.0
# 139233                                                NaN   1150000.0
# 5013                                 condominio el trebol   4200000.0
# 44962                      BUENAVISTA DEPTOS CON SUBSIDIO    310000.0
# 134537                                        Av. Morelos   6200000.0
# 51180                                       MI 2° CREDITO    488000.0
# 103293                                                NaN   7200000.0
# 47890                            Pitahayas 2 - 58, Zibata   1500000.0
# 130216                   MATIAS ROMERO, COLONIA DEL VALLE   3000000.0
# 181436                                                NaN   5300000.0
# 201923                                                NaN   3650000.0
# 283945     CUMBRES DEL LAGO JURIQUILLA, QUERETARO, MEXICO   2450000.0
# 73348                                   Pazaje Santa Cruz   4750000.0
# 40421                                             Milenio    794078.0
# 87655                                  SENDA CELESTIAL 10   1850000.0
# 90071            TERRENO RESIDENCIAL EN VENTA EN CUMBRES     490000.0
# 224513                                                NaN   2300000.0
# 129818                                                NaN   1340000.0
# 146699                                                NaN   3500000.0
# 235958                       Colinas del Cimatario   C721   3900000.0
# 97918                                       Lopez Velarde    850000.0
# 70294                           MISIONES DE SAN FRANCISCO    310000.0
# 177031                              PASEO DE LOS LAURELES  10800000.0
# 144635                         Coto Santillana I Casa G11   2600000.0
# 146158                            camino viejo a Tesistan  10707900.0
# ...                                                   ...         ...
# 123855                       Paseo de los fambruesos 3150   3350000.0
# 2747                                                TOKIO   3750000.0
# 130523                                  Albino Garcia 219   2400000.0
# 149503                                  Pérez de León  61   1260000.0
# 156730                                                NaN   3300000.0
# 258795                                                NaN   1275000.0
# 184779                                                NaN   2020000.0
# 214176                                    AV RANCHO NUEVO    490000.0
# 235796                                                NaN   1880000.0
# 103355                                         Rio Parana   3300000.0
# 267455                                                NaN   3386400.0
# 199041                                      PRIV. VENECIA    550000.0
# 252709                                                NaN    357000.0
# 194027                                                NaN    684338.0
# 262913                                PROGRESO, MONTERREY    505000.0
# 64820     FUENTES DE SATÉLITE, ATIZAPÁN, ESTADO DE MÉXICO   2700000.0
# 41090                                                 NaN   2079000.0
# 278167                                  Primero de mayo 5    830000.0
# 191335                                       SANTA MARIA    1990000.0
# 175203                                             Jurica   3850000.0
# 87498                                                 NaN   1495000.0
# 137337                                         Coyuya 200   1450000.0
# 54886                             Cerrada villa Picadilly   5500000.0
# 207892                                 Paseo de la Cañada   1650000.0
# 110268  MANUEL AMAYA,ENTRE SEBASTIAN ALLENDE Y AMADO A...   1350000.0
# 119879                                            BOSQUES    650000.0
# 259178                                Filiberto Navas 325   1940000.0
# 131932                                   Nicolas San Juan   3400000.0
# 146867                              Javier Rojo Gomez 120   2890000.0
# 121958                                          AVE. STIM   3650000.0
#
# [240000 rows x 4 columns]

# %%
train_strings.isnull().sum()
# Out:
# titulo          5387
# descripcion     1619
# direccion      53072
# precio             0
# dtype: int64

# %%
train_strings = train_strings.fillna(value = {'titulo' : '', 'descripcion' : '', 'direccion' : ''})
train_strings.isnull().sum()
# Out:
# titulo         0
# descripcion    0
# direccion      0
# precio         0
# dtype: int64

# %% [markdown]
# La siguiente operacion toma unos minutos

# %%
t0 = time.time()
for col in cols_string:
    train_strings[col + _SIN_SIGNOS_PUNTUACION] = train_strings[col].apply(
                                                        lambda x: remove_punctuations_from_string(x))
    train_strings[col + _SOLO_PALABRAS_IMPORTANTES] =\
        train_strings[col + _SIN_SIGNOS_PUNTUACION].apply(lambda x: 
                                                                remove_stopwords_from_string(x))
t1 = time.time()

# %%
(t1 - t0)/60

# %%
train_strings
# Out:
#                                                    titulo  \
# id
# 254099                                  depto. tipo a-402
# 53461                      condominio horizontal en venta
# 247984              casa en venta urbi 3 recamaras tonala
# 209067  casa sola en toluca zinacantepec con credito i...
# 185997                                     paseos del sol
# 126147                     departamento en venta taxqueña
# 139233                 de oportunidad casa en san lorenzo
# 5013    casa emilia en venta en selvamar playa del carmen
# 44962   pre- venta preciosos depas 2 recamaras con sub...
# 134537                                            terreno
# 51180                                       mi 2° credito
# 103293  departamento en venta, san pedro garza garcia,...
# 47890              hermosa casa en zibata queretaro 170m²
# 130216                 casa matias romero - sión bancaria
# 181436                        casa en venta en valle real
# 201923               casa en venta lomas verdes naucalpan
# 283945               preciosa casa en cumbres del lago \t
# 73348   oportunidad, departamento col del valle, 3 rec...
# 40421   últimos terrenos en preventa!! en bukara coto ...
# 87655
# 90071   terreno residencial en venta en cumbres quinta...
# 224513                         casa en venta en querétaro
# 129818  comoda casa con recamara en planta baja y ampl...
# 146699  casa en condominio en venta, benito juarez, ca...
# 235958  casa en venta - colinas del cimatario, queréta...
# 97918                            casa venta santa cecilia
# 70294   casa en venta de un nivel , frac. misiones de ...
# 177031
# 144635                      casa en venta en santillana i
# 146158              terreno urbano bardeado zona tesistán
# ...                                                   ...
# 123855  residencia en las cañadas, gran oportunidad pa...
# 2747    departamento exclusivo para tu familia, vive b...
# 130523           casa para remodelar, excelente ubicación
# 149503           departamento en venta en villa de cortes
# 156730  casa en venta, cuautitlán izcalli, estado de m...
# 258795  casa en uno de los desarrollos con mayor plusv...
# 184779                        casa en venta en campanario
# 214176                                       casa tecamac
# 235796    linda casa en venta,cerca del lago de guadalupe
# 103355         se vende casa en delegacion miguel hidalgo
# 267455              departamentos en renta torres palmira
# 199041         casa en venta en residencial agua caliente
# 252709  casa de 2 recamaras en residencial del bosque ...
# 194027                   casa en venta en san luis potosí
# 262913        en venta mitras centro monterrey nuevo leon
# 64820   casa en venta fuentes de satelite, atizapan, e...
# 41090   excelete torre de departamentos en lomas 4ta s...
# 278167
# 191335                                bodega santa maría
# 175203               casa venta renta en rinconada jurica
# 87498                   casa en venta: bosques del contry
# 137337                    departamento residencial coyuya
# 54886                                       casa en venta
# 207892                               bugambilias (ciudad)
# 110268               hermosa casa en villa de los belenes
# 119879  bonita casas de 2 recamaras a 10 minutos del c...
# 259178  casa en condominio a 10 min. del centro de toluca
# 131932                                   nicolas san juan
# 146867                      casa sola. javier rojo gomez.
# 121958  departamento en bosques de las lomas  / av. st...
#
#                                               descripcion  \
# id
# 254099  depto. interior de 80.15m2, consta de sala com...
# 53461   <p>entre sonora y guerrero, atr&aacute;s del h...
# 247984  descripcion \nla mejor ubicacion residencial e...
# 209067  casa en privada con caseta de vigilancia casas...
# 185997  bonito departamento en excelentes condiciones ...
# 126147  amplio departamento, estancia de sala y comedo...
# 139233  ubicada en esquina, pertenece san lorenzo agen...
# 5013    casa emilia en venta playa del carmenfracciona...
# 44962   <p>pre-venta de preciosos departamento ecologi...
# 134537  terreno de 5.500m2 bardeado, uso de suelo h-20...
# 51180   <p>mi 2&deg; credito<br />para todos aquellos ...
# 103293  departamento nuevo ,256 m2 de construccion,un ...
# 47890   <p><strong>casa </strong>en venta en fracciona...
# 130216  flamante casa habitación en condominio horizon...
# 181436  pre venta de residencia en la toscana con exce...
# 201923  <p>casa en dos niveles, 3 recámaras la princip...
# 283945  <p>clave: vcln2450 fecha de actualizaci&oacute...
# 73348   magnifico departamento con excelente distribuc...
# 40421   terreno ubicado en bukara coto club, el cual s...
# 87655   -- rcv151104-lv-27 --    linda casa con area d...
# 90071   <p>excelente terreno plano, frente a parque en...
# 224513  nocnok id: mx15-bk0340. hermosa casa en conjun...
# 129818  <p>comoda casa con recamara en planta baja y a...
# 146699  casa en venta en cancun en residencial cumbres...
# 235958  <p>propiedad en un nivel, con espacios amplios...
# 97918   hermosa casa en santa cecilia en apodaca, cerc...
# 70294   ¡excelente oportunidad!  \n\ncasa de un nivel ...
# 177031  hermosa casa remodelada, con acabados de lujo,...
# 144635  casa en coto 3 recamaras, estudio, sala-comedo...
# 146158  en zona de urbanización progresiva, terreno pl...
# ...                                                   ...
# 123855  residencia en las cañadas, una gran oportunida...
# 2747    www. \n3 recamaras, 2 baños \n2 autos \nentreg...
# 130523  estado de conservación: para remodelar, área d...
# 149503  últimos departamentos en preventa dentro de ex...
# 156730  casa en venta en lago de guadalupe. excelente ...
# 258795  <p>el desarrollo cuenta con barda perimetral c...
# 184779  bonita y bien ubicada casa en venta, 3 recamar...
# 214176  hermosa casa, en excelente mantenimiento y muy...
# 235796  buen proyecto, desarrollada en tres plantas, p...
# 103355  excelente casa muy bien ubicada en zona tranqu...
# 267455  departamento en venta avenida palmira , san lu...
# 199041  se vende bonita casa en el fracc. residencial ...
# 252709  casa de 2 recámaras en residencial del bosque ...
# 194027  nocnok id: mx16-bo3390. sin posesión física, p...
# 262913   en excelente ubicación zona mitras centro. am...
# 64820   casa en venta fuentes de satélite, atizapán, e...
# 41090   <p>exclusiva torre de departamentos en venta e...
# 278167  -- rcv347n-287 --    casas nuevas estilo minim...
# 191335  ideal para inversionista \nideal centro de dis...
# 175203  terreno 404m2 \nconst. 347 m2 \n\npreciosa cas...
# 87498   <p>casa en venta, en magníficas condiciones; e...
# 137337  departamento ubicado en planta baja, con excel...
# 54886   bonita casa para remodelar en una calle cerrad...
# 207892  coto privado de tan solo 7 casas donde cada fa...
# 110268  <p>moderna casa 3 pisos, muro llor&oacute;n , ...
# 119879  vendo casa en bosques de ica residencial a 10 ...
# 259178  casa con un jardin amplio, un cuarto de servic...
# 131932  departamento con excelente ubicación, muy cerc...
# 146867  casa sola, dividida en cuatro departamentos de...
# 121958  id:19816, muy bonito e iluminado departamento,...
#
#                                                 direccion      precio  \
# id
# 254099                    Avenida Division del Norte 2005   2273000.0
# 53461                                          AV. MEXICO   3600000.0
# 247984                                        Urbi Tonala   1200000.0
# 209067                      IGNACIO MANUEL ALTAMIRANO 128    650000.0
# 185997                                    PASEOS DEL SOL    1150000.0
# 126147                              Condominio Tlalpan 2B   1100000.0
# 139233                                                      1150000.0
# 5013                                 condominio el trebol   4200000.0
# 44962                      BUENAVISTA DEPTOS CON SUBSIDIO    310000.0
# 134537                                        Av. Morelos   6200000.0
# 51180                                       MI 2° CREDITO    488000.0
# 103293                                                      7200000.0
# 47890                            Pitahayas 2 - 58, Zibata   1500000.0
# 130216                   MATIAS ROMERO, COLONIA DEL VALLE   3000000.0
# 181436                                                      5300000.0
# 201923                                                      3650000.0
# 283945     CUMBRES DEL LAGO JURIQUILLA, QUERETARO, MEXICO   2450000.0
# 73348                                   Pazaje Santa Cruz   4750000.0
# 40421                                             Milenio    794078.0
# 87655                                  SENDA CELESTIAL 10   1850000.0
# 90071            TERRENO RESIDENCIAL EN VENTA EN CUMBRES     490000.0
# 224513                                                      2300000.0
# 129818                                                      1340000.0
# 146699                                                      3500000.0
# 235958                       Colinas del Cimatario   C721   3900000.0
# 97918                                       Lopez Velarde    850000.0
# 70294                           MISIONES DE SAN FRANCISCO    310000.0
# 177031                              PASEO DE LOS LAURELES  10800000.0
# 144635                         Coto Santillana I Casa G11   2600000.0
# 146158                            camino viejo a Tesistan  10707900.0
# ...                                                   ...         ...
# 123855                       Paseo de los fambruesos 3150   3350000.0
# 2747                                                TOKIO   3750000.0
# 130523                                  Albino Garcia 219   2400000.0
# 149503                                  Pérez de León  61   1260000.0
# 156730                                                      3300000.0
# 258795                                                      1275000.0
# 184779                                                      2020000.0
# 214176                                    AV RANCHO NUEVO    490000.0
# 235796                                                      1880000.0
# 103355                                         Rio Parana   3300000.0
# 267455                                                      3386400.0
# 199041                                      PRIV. VENECIA    550000.0
# 252709                                                       357000.0
# 194027                                                       684338.0
# 262913                                PROGRESO, MONTERREY    505000.0
# 64820     FUENTES DE SATÉLITE, ATIZAPÁN, ESTADO DE MÉXICO   2700000.0
# 41090                                                       2079000.0
# 278167                                  Primero de mayo 5    830000.0
# 191335                                       SANTA MARIA    1990000.0
# 175203                                             Jurica   3850000.0
# 87498                                                       1495000.0
# 137337                                         Coyuya 200   1450000.0
# 54886                             Cerrada villa Picadilly   5500000.0
# 207892                                 Paseo de la Cañada   1650000.0
# 110268  MANUEL AMAYA,ENTRE SEBASTIAN ALLENDE Y AMADO A...   1350000.0
# 119879                                            BOSQUES    650000.0
# 259178                                Filiberto Navas 325   1940000.0
# 131932                                   Nicolas San Juan   3400000.0
# 146867                              Javier Rojo Gomez 120   2890000.0
# 121958                                          AVE. STIM   3650000.0
#
#                              titulo_sin_signos_puntuacion  \
# id
# 254099                                  depto  tipo a 402
# 53461                      condominio horizontal en venta
# 247984              casa en venta urbi 3 recamaras tonala
# 209067  casa sola en toluca zinacantepec con credito i...
# 185997                                     paseos del sol
# 126147                     departamento en venta taxqueña
# 139233                 de oportunidad casa en san lorenzo
# 5013    casa emilia en venta en selvamar playa del carmen
# 44962   pre  venta preciosos depas 2 recamaras con sub...
# 134537                                            terreno
# 51180                                       mi 2° credito
# 103293  departamento en venta  san pedro garza garcia ...
# 47890              hermosa casa en zibata queretaro 170m²
# 130216                 casa matias romero   sión bancaria
# 181436                        casa en venta en valle real
# 201923               casa en venta lomas verdes naucalpan
# 283945               preciosa casa en cumbres del lago \t
# 73348   oportunidad  departamento col del valle  3 rec...
# 40421   últimos terrenos en preventa   en bukara coto ...
# 87655
# 90071   terreno residencial en venta en cumbres quinta...
# 224513                         casa en venta en querétaro
# 129818  comoda casa con recamara en planta baja y ampl...
# 146699  casa en condominio en venta  benito juarez  ca...
# 235958  casa en venta   colinas del cimatario  queréta...
# 97918                            casa venta santa cecilia
# 70294   casa en venta de un nivel   frac  misiones de ...
# 177031
# 144635                      casa en venta en santillana i
# 146158              terreno urbano bardeado zona tesistán
# ...                                                   ...
# 123855  residencia en las cañadas  gran oportunidad pa...
# 2747    departamento exclusivo para tu familia  vive b...
# 130523           casa para remodelar  excelente ubicación
# 149503           departamento en venta en villa de cortes
# 156730  casa en venta  cuautitlán izcalli  estado de m...
# 258795  casa en uno de los desarrollos con mayor plusv...
# 184779                        casa en venta en campanario
# 214176                                       casa tecamac
# 235796    linda casa en venta cerca del lago de guadalupe
# 103355         se vende casa en delegacion miguel hidalgo
# 267455              departamentos en renta torres palmira
# 199041         casa en venta en residencial agua caliente
# 252709  casa de 2 recamaras en residencial del bosque ...
# 194027                   casa en venta en san luis potosí
# 262913        en venta mitras centro monterrey nuevo leon
# 64820   casa en venta fuentes de satelite  atizapan  e...
# 41090   excelete torre de departamentos en lomas 4ta s...
# 278167
# 191335                                bodega santa maría
# 175203               casa venta renta en rinconada jurica
# 87498                   casa en venta  bosques del contry
# 137337                    departamento residencial coyuya
# 54886                                       casa en venta
# 207892                               bugambilias  ciudad
# 110268               hermosa casa en villa de los belenes
# 119879  bonita casas de 2 recamaras a 10 minutos del c...
# 259178  casa en condominio a 10 min  del centro de toluca
# 131932                                   nicolas san juan
# 146867                      casa sola  javier rojo gomez
# 121958  departamento en bosques de las lomas    av  st...
#
#                          titulo_solo_palabras_importantes  \
# id
# 254099                                    depto  tipo 402
# 53461                         condominio horizontal venta
# 247984                 casa venta urbi 3 recamaras tonala
# 209067  casa sola toluca zinacantepec credito infonavi...
# 185997                                         paseos sol
# 126147                        departamento venta taxqueña
# 139233                       oportunidad casa san lorenzo
# 5013              casa emilia venta selvamar playa carmen
# 44962     pre  venta preciosos depas 2 recamaras subsidio
# 134537                                            terreno
# 51180                                          2° credito
# 103293  departamento venta  san pedro garza garcia  nu...
# 47890                 hermosa casa zibata queretaro 170m²
# 130216                 casa matias romero   sión bancaria
# 181436                              casa venta valle real
# 201923                  casa venta lomas verdes naucalpan
# 283945                      preciosa casa cumbres lago \t
# 73348   oportunidad  departamento col valle  3 recs  2...
# 40421   últimos terrenos preventa   bukara coto club  ...
# 87655
# 90071      terreno residencial venta cumbres quinta real
# 224513                               casa venta querétaro
# 129818      comoda casa recamara planta baja amplio patio
# 146699  casa condominio venta  benito juarez  cancun  ...
# 235958  casa venta   colinas cimatario  querétaro    c721
# 97918                            casa venta santa cecilia
# 70294     casa venta nivel   frac  misiones san francisco
# 177031
# 144635                            casa venta santillana i
# 146158              terreno urbano bardeado zona tesistán
# ...                                                   ...
# 123855  residencia cañadas  gran oportunidad poder rem...
# 2747          departamento exclusivo familia  vive bien
# 130523                casa remodelar  excelente ubicación
# 149503                    departamento venta villa cortes
# 156730             casa venta  cuautitlán izcalli  méxico
# 258795         casa desarrollos mayor plusvalía  refugio
# 184779                              casa venta campanario
# 214176                                       casa tecamac
# 235796              linda casa venta cerca lago guadalupe
# 103355               vende casa delegacion miguel hidalgo
# 267455                 departamentos renta torres palmira
# 199041               casa venta residencial agua caliente
# 252709   casa 2 recamaras residencial bosque  blvd  2000
# 194027                         casa venta san luis potosí
# 262913           venta mitras centro monterrey nuevo leon
# 64820   casa venta fuentes satelite  atizapan  méxico ...
# 41090      excelete torre departamentos lomas 4ta secciòn
# 278167
# 191335                                bodega santa maría
# 175203                  casa venta renta rinconada jurica
# 87498                          casa venta  bosques contry
# 137337                    departamento residencial coyuya
# 54886                                          casa venta
# 207892                               bugambilias  ciudad
# 110268                         hermosa casa villa belenes
# 119879  bonita casas 2 recamaras 10 minutos centro toluca
# 259178              casa condominio 10 min  centro toluca
# 131932                                   nicolas san juan
# 146867                      casa sola  javier rojo gomez
# 121958   departamento bosques lomas    av  stim via 19816
#
#                         descripcion_sin_signos_puntuacion  \
# id
# 254099  depto  interior de 80 15m2  consta de sala com...
# 53461    p entre sonora y guerrero  atr aacute s del h...
# 247984  descripcion \nla mejor ubicacion residencial e...
# 209067  casa en privada con caseta de vigilancia casas...
# 185997  bonito departamento en excelentes condiciones ...
# 126147  amplio departamento  estancia de sala y comedo...
# 139233  ubicada en esquina  pertenece san lorenzo agen...
# 5013    casa emilia en venta playa del carmenfracciona...
# 44962    p pre venta de preciosos departamento ecologi...
# 134537  terreno de 5 500m2 bardeado  uso de suelo h 20...
# 51180    p mi 2 deg  credito br   para todos aquellos ...
# 103293  departamento nuevo  256 m2 de construccion un ...
# 47890    p  strong casa   strong en venta en fracciona...
# 130216  flamante casa habitación en condominio horizon...
# 181436  pre venta de residencia en la toscana con exce...
# 201923   p casa en dos niveles  3 recámaras la princip...
# 283945   p clave  vcln2450 fecha de actualizaci oacute...
# 73348   magnifico departamento con excelente distribuc...
# 40421   terreno ubicado en bukara coto club  el cual s...
# 87655      rcv151104 lv 27       linda casa con area d...
# 90071    p excelente terreno plano  frente a parque en...
# 224513  nocnok id  mx15 bk0340  hermosa casa en conjun...
# 129818   p comoda casa con recamara en planta baja y a...
# 146699  casa en venta en cancun en residencial cumbres...
# 235958   p propiedad en un nivel  con espacios amplios...
# 97918   hermosa casa en santa cecilia en apodaca  cerc...
# 70294   ¡excelente oportunidad   \n\ncasa de un nivel ...
# 177031  hermosa casa remodelada  con acabados de lujo ...
# 144635  casa en coto 3 recamaras  estudio  sala comedo...
# 146158  en zona de urbanización progresiva  terreno pl...
# ...                                                   ...
# 123855  residencia en las cañadas  una gran oportunida...
# 2747    www  \n3 recamaras  2 baños \n2 autos \nentreg...
# 130523  estado de conservación  para remodelar  área d...
# 149503  últimos departamentos en preventa dentro de ex...
# 156730  casa en venta en lago de guadalupe  excelente ...
# 258795   p el desarrollo cuenta con barda perimetral c...
# 184779  bonita y bien ubicada casa en venta  3 recamar...
# 214176  hermosa casa  en excelente mantenimiento y muy...
# 235796  buen proyecto  desarrollada en tres plantas  p...
# 103355  excelente casa muy bien ubicada en zona tranqu...
# 267455  departamento en venta avenida palmira   san lu...
# 199041  se vende bonita casa en el fracc  residencial ...
# 252709  casa de 2 recámaras en residencial del bosque ...
# 194027  nocnok id  mx16 bo3390  sin posesión física  p...
# 262913   en excelente ubicación zona mitras centro  am...
# 64820   casa en venta fuentes de satélite  atizapán  e...
# 41090    p exclusiva torre de departamentos en venta e...
# 278167     rcv347n 287       casas nuevas estilo minim...
# 191335  ideal para inversionista \nideal centro de dis...
# 175203  terreno 404m2 \nconst  347 m2 \n\npreciosa cas...
# 87498    p casa en venta  en magníficas condiciones  e...
# 137337  departamento ubicado en planta baja  con excel...
# 54886   bonita casa para remodelar en una calle cerrad...
# 207892  coto privado de tan solo 7 casas donde cada fa...
# 110268   p moderna casa 3 pisos  muro llor oacute n   ...
# 119879  vendo casa en bosques de ica residencial a 10 ...
# 259178  casa con un jardin amplio  un cuarto de servic...
# 131932  departamento con excelente ubicación  muy cerc...
# 146867  casa sola  dividida en cuatro departamentos de...
# 121958  id 19816  muy bonito e iluminado departamento ...
#
#                     descripcion_solo_palabras_importantes  \
# id
# 254099  depto  interior 80 15m2  consta sala comedor c...
# 53461    p sonora guerrero  atr aacute s hospital  aac...
# 247984  descripcion \nmejor ubicacion residencial orie...
# 209067  casa privada caseta vigilancia casas dos tres ...
# 185997  bonito departamento excelentes condiciones bue...
# 126147  amplio departamento  estancia sala comedor par...
# 139233  ubicada esquina  pertenece san lorenzo agencia...
# 5013    casa emilia venta playa carmenfraccionamiento ...
# 44962    p pre venta preciosos departamento ecologicos...
# 134537  terreno 5 500m2 bardeado  uso suelo h 200 plan...
# 51180    p 2 deg  credito br   aquellos trabajadores p...
# 103293  departamento nuevo  256 m2 construccion depart...
# 47890    p  strong casa   strong venta fraccionamiento...
# 130216  flamante casa habitación condominio horizontal...
# 181436  pre venta residencia toscana excelente distrib...
# 201923   p casa dos niveles  3 recámaras principal bañ...
# 283945   p clave  vcln2450 fecha actualizaci oacute n ...
# 73348   magnifico departamento excelente distribución ...
# 40421   terreno ubicado bukara coto club  compone 100 ...
# 87655      rcv151104 lv 27       linda casa area estac...
# 90071    p excelente terreno plano  frente parque call...
# 224513  nocnok id  mx15 bk0340  hermosa casa conjunto ...
# 129818   p comoda casa recamara planta baja amplio pat...
# 146699  casa venta cancun residencial cumbres casa res...
# 235958   p propiedad nivel  espacios amplios iluminado...
# 97918   hermosa casa santa cecilia apodaca  cerca cent...
# 70294   ¡excelente oportunidad   \n\ncasa nivel fracci...
# 177031  hermosa casa remodelada  acabados lujo  calle ...
# 144635  casa coto 3 recamaras  estudio  sala comedor  ...
# 146158  zona urbanización progresiva  terreno plano es...
# ...                                                   ...
# 123855  residencia cañadas  gran oportunidad poder rem...
# 2747    www  \n3 recamaras  2 baños \n2 autos \nentreg...
# 130523  conservación  remodelar  área terreno 120 m²  ...
# 149503  últimos departamentos preventa dentro exclusiv...
# 156730  casa venta lago guadalupe  excelente ubicación...
# 258795   p desarrollo cuenta barda perimetral cerca el...
# 184779  bonita bien ubicada casa venta  3 recamaras  2...
# 214176  hermosa casa  excelente mantenimiento bien ubi...
# 235796  buen proyecto  desarrollada tres plantas  plan...
# 103355  excelente casa bien ubicada zona tranquila  pa...
# 267455  departamento venta avenida palmira   san luis ...
# 199041  vende bonita casa fracc  residencial agua cali...
# 252709  casa 2 recámaras residencial bosque  blvd 2000...
# 194027  nocnok id  mx16 bo3390  posesión física  venta...
# 262913   excelente ubicación zona mitras centro  ampli...
# 64820   casa venta fuentes satélite  atizapán  méxico ...
# 41090    p exclusiva torre departamentos venta lomas 4...
# 278167     rcv347n 287       casas nuevas estilo minim...
# 191335  ideal inversionista \nideal centro distribució...
# 175203  terreno 404m2 \nconst  347 m2 \n\npreciosa cas...
# 87498    p casa venta  magníficas condiciones  primer ...
# 137337  departamento ubicado planta baja  excelente ub...
# 54886   bonita casa remodelar calle cerrada vigilancia...
# 207892  coto privado tan solo 7 casas cada fachada dif...
# 110268   p moderna casa 3 pisos  muro llor oacute n   ...
# 119879  vendo casa bosques ica residencial 10 minutos ...
# 259178  casa jardin amplio  cuarto servicio baño compl...
# 131932  departamento excelente ubicación  cerca av  un...
# 146867  casa sola  dividida cuatro departamentos 1 rec...
# 121958  id 19816  bonito iluminado departamento  excel...
#
#                           direccion_sin_signos_puntuacion  \
# id
# 254099                    avenida division del norte 2005
# 53461                                          av  mexico
# 247984                                        urbi tonala
# 209067                      ignacio manuel altamirano 128
# 185997                                    paseos del sol
# 126147                              condominio tlalpan 2b
# 139233
# 5013                                 condominio el trebol
# 44962                      buenavista deptos con subsidio
# 134537                                        av  morelos
# 51180                                       mi 2° credito
# 103293
# 47890                            pitahayas 2   58  zibata
# 130216                   matias romero  colonia del valle
# 181436
# 201923
# 283945     cumbres del lago juriquilla  queretaro  mexico
# 73348                                   pazaje santa cruz
# 40421                                             milenio
# 87655                                  senda celestial 10
# 90071            terreno residencial en venta en cumbres
# 224513
# 129818
# 146699
# 235958                       colinas del cimatario   c721
# 97918                                       lopez velarde
# 70294                           misiones de san francisco
# 177031                              paseo de los laureles
# 144635                         coto santillana i casa g11
# 146158                            camino viejo a tesistan
# ...                                                   ...
# 123855                       paseo de los fambruesos 3150
# 2747                                                tokio
# 130523                                  albino garcia 219
# 149503                                  pérez de león  61
# 156730
# 258795
# 184779
# 214176                                    av rancho nuevo
# 235796
# 103355                                         rio parana
# 267455
# 199041                                      priv  venecia
# 252709
# 194027
# 262913                                progreso  monterrey
# 64820     fuentes de satélite  atizapán  estado de méxico
# 41090
# 278167                                  primero de mayo 5
# 191335                                       santa maria
# 175203                                             jurica
# 87498
# 137337                                         coyuya 200
# 54886                             cerrada villa picadilly
# 207892                                 paseo de la cañada
# 110268  manuel amaya entre sebastian allende y amado a...
# 119879                                            bosques
# 259178                                filiberto navas 325
# 131932                                   nicolas san juan
# 146867                              javier rojo gomez 120
# 121958                                          ave  stim
#
#                       direccion_solo_palabras_importantes
# id
# 254099                        avenida division norte 2005
# 53461                                          av  mexico
# 247984                                        urbi tonala
# 209067                      ignacio manuel altamirano 128
# 185997                                        paseos sol
# 126147                              condominio tlalpan 2b
# 139233
# 5013                                    condominio trebol
# 44962                          buenavista deptos subsidio
# 134537                                        av  morelos
# 51180                                          2° credito
# 103293
# 47890                            pitahayas 2   58  zibata
# 130216                       matias romero  colonia valle
# 181436
# 201923
# 283945         cumbres lago juriquilla  queretaro  mexico
# 73348                                   pazaje santa cruz
# 40421                                             milenio
# 87655                                  senda celestial 10
# 90071                  terreno residencial venta cumbres
# 224513
# 129818
# 146699
# 235958                           colinas cimatario   c721
# 97918                                       lopez velarde
# 70294                              misiones san francisco
# 177031                                     paseo laureles
# 144635                         coto santillana i casa g11
# 146158                              camino viejo tesistan
# ...                                                   ...
# 123855                              paseo fambruesos 3150
# 2747                                                tokio
# 130523                                  albino garcia 219
# 149503                                     pérez león  61
# 156730
# 258795
# 184779
# 214176                                    av rancho nuevo
# 235796
# 103355                                         rio parana
# 267455
# 199041                                      priv  venecia
# 252709
# 194027
# 262913                                progreso  monterrey
# 64820                  fuentes satélite  atizapán  méxico
# 41090
# 278167                                     primero mayo 5
# 191335                                       santa maria
# 175203                                             jurica
# 87498
# 137337                                         coyuya 200
# 54886                             cerrada villa picadilly
# 207892                                       paseo cañada
# 110268  manuel amaya sebastian allende amado aguirre z...
# 119879                                            bosques
# 259178                                filiberto navas 325
# 131932                                   nicolas san juan
# 146867                              javier rojo gomez 120
# 121958                                          ave  stim
#
# [240000 rows x 10 columns]

# %% [markdown]
# Features que deseamos generar para Titulo, Descripcion y Direccion:
# * F1: Cantidad de palabras importantes
# * F2: Cantidad de caracteres
# * F3: Longitud media por palabra
# * F4: Cantidad de 'Stopwords'
# * F5: Cantidad de signos de puntacion
# * F6: Cantidad de palabras en mayuscula
# * F7: Cantidad de palabras cuya primer letra es mayuscula y el resto es minuscula: 'Titulos'
# * F8: Cantidad de palabras en el top K de palabras (mas frecuentes)
# * F9: Cantidad de palabras en el bottom K de palabras (menos frecuentes)
# * F10: Cantidad de palabras que empiezan con los prefijos mas frecuentes
# * F11: Cantidad de palabras que terminan con los postfijos mas frecuentes

# %% [markdown]
# ## F1 : Cantidad de palabras importantes

# %%
t0 = time.time()
for col in cols_string:
    train_strings[col + _CANTIDAD_PALABRAS_IMPORTANTES] = train_strings[col + _SOLO_PALABRAS_IMPORTANTES].apply(lambda x: len(str(x).split()))
t1 = time.time()
print('tiempo = {0:.0f} segundos'.format((t1 - t0)))
# Out:
# tiempo = 1 segundos

# %%
plot_feature_precio_cantidad(cols_string, _CANTIDAD_PALABRAS_IMPORTANTES, [100,100,100])

# %%
plot_precio_vs_feature(cols_string, _CANTIDAD_PALABRAS_IMPORTANTES, [30, 2000,40])

# %%
plot_cantidad_vs_feature(cols_string, _CANTIDAD_PALABRAS_IMPORTANTES, [30, 2000,40])

# %% [markdown]
# ## F2: Cantidad de caracteres

# %%
t0 = time.time()
for col in cols_string:
    train_strings[col + _CANTIDAD_CARACTERES_IMPORTANTES] = train_strings[col + _SOLO_PALABRAS_IMPORTANTES].apply(lambda x: len(str(x)))
t1 = time.time()
print('tiempo = {0:.0f} segundos'.format((t1 - t0)))
# Out:
# tiempo = 0 segundos

# %%
plot_precio_vs_feature(cols_string, _CANTIDAD_CARACTERES_IMPORTANTES, [100,10000,200])

# %% [markdown]
# ## F3: Longitud media de palabras (Aprox.)

# %%
t0 = time.time()
for col in cols_string:
    train_strings[col + _LONGITUD_MEDIA_PALABRA] =\
        train_strings[col + _CANTIDAD_PALABRAS_IMPORTANTES] / train_strings[col + _CANTIDAD_CARACTERES_IMPORTANTES]
t1 = time.time()
print('tiempo = {0:.0f} segundos'.format((t1 - t0)))
# Out:
# tiempo = 0 segundos

# %%
plot_precio_vs_feature(cols_string, _LONGITUD_MEDIA_PALABRA, [0.5, 0.4, 0.6])

# %% [markdown]
# ## F4: Cantidad de 'Stopwords'

# %%
t0 = time.time()
stop_words = set(stopwords.words('spanish'))
for col in cols_string:
    train_strings[col + _CANTIDAD_STOPWORDS] =\
        train_strings[col + _SIN_SIGNOS_PUNTUACION].apply(lambda x: len([palabra for palabra in str(x).split() if palabra in stop_words]))
t1 = time.time()
print('tiempo = {0:.0f} segundos'.format((t1 - t0)))
# Out:
# tiempo = 3 segundos

# %%
plot_precio_vs_feature(cols_string, _CANTIDAD_STOPWORDS, [20, 300, 15])

# %% [markdown]
# ## F5: Cantidad de signos de puntacion

# %%
t0 = time.time()
for col in cols_string:
    train_strings[col + _CANTIDAD_SIGNOS_PUNTACION] =\
        train_strings[col].apply(lambda x: len([caracter for caracter in str(x) if caracter in string.punctuation]))
t1 = time.time()
print('tiempo = {0:.0f} segundos'.format((t1 - t0)))
# Out:
# tiempo = 6 segundos

# %%
plot_precio_vs_feature(cols_string, _CANTIDAD_SIGNOS_PUNTACION, [35, 3000, 50])

# %% [markdown]
# ## F6: Cantidad de palabras en mayuscula

# %%
t0 = time.time()
for col in cols_string:
    train_strings[col + _CANTIDAD_PALABRAS_MAYUSCULA] =\
        train_strings[col].apply(lambda x: len([palabra for palabra in str(x).split() if palabra.isupper()]))
t1 = time.time()
print('tiempo = {0:.0f} segundos'.format((t1 - t0)))
# Out:
# tiempo = 2 segundos

# %%
plot_precio_vs_feature(cols_string, _CANTIDAD_PALABRAS_MAYUSCULA)

# %% [markdown]
# En titulo y descripcion no hay palabras full-mayuscula, pero en direccion si ,y parece que la cantidad de estas influye en el precio

# %% [markdown]
# ## F7: Cantidad de palabras cuya primer letra es mayuscula y el resto es minuscula: 'Titulos'

# %%
t0 = time.time()
for col in cols_string:
    train_strings[col + _CANTIDAD_TITULOS] =\
        train_strings[col].apply(lambda x: len([palabra for palabra in str(x).split() if palabra.istitle()]))
t1 = time.time()
print('tiempo = {0:.0f} segundos'.format((t1 - t0)))
# Out:
# tiempo = 2 segundos

# %%
plot_precio_vs_feature(cols_string, _CANTIDAD_TITULOS, [10,10,20])

# %% [markdown]
# Otra vez, no hay titulos en Titulo y Descripcion, pero si en direcciones, aunque no parece muy relevante en esta ultima
