# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Imports

# %%
import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks')

# %%
import feature_string as feature_string
import feature_num as feature_num
import feature_categorica as feature_categorica
import common_machine_learning as common
import my_pipeline as my_pipe
import pandas as pd
import numpy as np
from hyperopt import fmin, tpe, hp, STATUS_OK
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline
from xgboost import XGBRegressor
import xgboost as xgb
import time

# %% [markdown]
# #### Ignore Future Warning

# %%
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## Constantes

# %%
TARGET = 'precio'
K = 3
RANDOM_SEMILLA = 3 # numero favorito (de la suerte)
XGB_RE_OBJECTIVE = 'reg:squarederror'
N_ITER = 50

# %% [markdown]
# ## Train

# %%
train = common.cargar_set_optimizado('/content/drive/My Drive/Colab Notebooks/sets_de_datos/train.csv')

# %% [markdown]
# ## Features

# %%
feature_num.agregar_feature_fecha_numerica(train)

# %% [markdown]
# Esto toma unos segundos

# %%
train = feature_num.completar_lat_lng_con_provincias_y_ciudades(train)
train = feature_num.completar_lat_lng_con_idzona_mean(train)
feature_num.completar_lat_lng_con_promedio_Mexico(train)

# %%
train = feature_categorica.agregar_tipodepropiedad_precio_mean(train)

# %%
train = feature_categorica.train_agregar_feature_provincias_ciudades_ohe_reducido_df(train)

# %%
train = feature_string.train_agregar_feature_string_todos_df(train)

# %%
drop_columns = ['titulo', 'descripcion', 'tipodepropiedad', 'direccion', 'ciudad', 'provincia', 'idzona']

# %%
train = train.drop(drop_columns, axis = 1)

# %%
train.set_index('id', inplace = True)

# %%
X = train.drop([TARGET], axis = 1).copy()
y = train[TARGET].copy()

# %%
pre_procesar_pipe = my_pipe.get_columns_pipeline()

def objective(hyper_parametros):
    
    busqueda_pipe = Pipeline(steps = [
        ('pre-procesar', pre_procesar_pipe),
        ('xgb_regressor', XGBRegressor(objective = XGB_RE_OBJECTIVE, **hyper_parametros))
    ])  
    
    score = cross_val_score(busqueda_pipe, X, y, scoring='neg_mean_absolute_error', cv=K).mean()
    
    print("SCORE: {:.3f} params {}".format(score, hyper_parametros))
    
    return {'loss': -score, 'status': STATUS_OK}

# %%
space = {
    "n_estimators": hp.randint("xgb_re__n_estimators", 1000) + 1, 
    "learning_rate": hp.uniform("xgb_re__learning_rate", 0.005, 0.03), 
    "gamma": hp.uniform("xgb_re__gamma", 0.1, 5),
    "lambda": hp.uniform("xgb_re__lambda",0.1, 5),
    "max_depth": hp.randint("xgb_re__max_depth", 11) + 1, 
    "subsample": 0.79,
    "colsample_bytree": 0.8,
    "min_child_weight": hp.randint("xgb_re__min_child_weight", 5) + 1
}

# %%
t0 = time.time()
best = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=N_ITER)
t1 = time.time()
print('Tiempo = {0:.2f} minutos'.format((t1 - t0)/60))
# Out:
# SCORE: -992003.062 params {'colsample_bytree': 0.8, 'gamma': 0.8407282068909406, 'lambda': 2.280833908213882, 'learning_rate': 0.02676243315387239, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 568, 'subsample': 0.79}
# SCORE: -1161523.500 params {'colsample_bytree': 0.8, 'gamma': 4.1163026641838005, 'lambda': 2.5361838963417966, 'learning_rate': 0.010456510993606772, 'max_depth': 1, 'min_child_weight': 2, 'n_estimators': 298, 'subsample': 0.79}
# SCORE: -985112.500 params {'colsample_bytree': 0.8, 'gamma': 4.918264252535506, 'lambda': 0.9714821559724026, 'learning_rate': 0.010934032740481384, 'max_depth': 5, 'min_child_weight': 5, 'n_estimators': 836, 'subsample': 0.79}
# SCORE: -949379.833 params {'colsample_bytree': 0.8, 'gamma': 0.41404800888010296, 'lambda': 4.076493580206379, 'learning_rate': 0.018897550901897812, 'max_depth': 8, 'min_child_weight': 4, 'n_estimators': 824, 'subsample': 0.79}
# SCORE: -939483.417 params {'colsample_bytree': 0.8, 'gamma': 1.9946751797362463, 'lambda': 0.9354015464806696, 'learning_rate': 0.024001614759811843, 'max_depth': 11, 'min_child_weight': 2, 'n_estimators': 400, 'subsample': 0.79}
# SCORE: -1366064.000 params {'colsample_bytree': 0.8, 'gamma': 2.891720129399488, 'lambda': 2.248021200546207, 'learning_rate': 0.005854378168337763, 'max_depth': 1, 'min_child_weight': 3, 'n_estimators': 140, 'subsample': 0.79}
# SCORE: -942045.979 params {'colsample_bytree': 0.8, 'gamma': 0.3848741203350111, 'lambda': 3.8630231505972996, 'learning_rate': 0.027819105398316488, 'max_depth': 9, 'min_child_weight': 1, 'n_estimators': 870, 'subsample': 0.79}
# SCORE: -980238.792 params {'colsample_bytree': 0.8, 'gamma': 2.6942082512937873, 'lambda': 2.231928452042838, 'learning_rate': 0.021291715846929817, 'max_depth': 5, 'min_child_weight': 2, 'n_estimators': 544, 'subsample': 0.79}
# SCORE: -1183849.042 params {'colsample_bytree': 0.8, 'gamma': 4.8697596080332, 'lambda': 2.5325403061955467, 'learning_rate': 0.015256003527089765, 'max_depth': 7, 'min_child_weight': 5, 'n_estimators': 59, 'subsample': 0.79}
# SCORE: -969652.917 params {'colsample_bytree': 0.8, 'gamma': 4.2651775545762645, 'lambda': 1.442133756152444, 'learning_rate': 0.007349839134666012, 'max_depth': 11, 'min_child_weight': 1, 'n_estimators': 209, 'subsample': 0.79}
# SCORE: -961526.958 params {'colsample_bytree': 0.8, 'gamma': 4.998888571220313, 'lambda': 2.51202967677337, 'learning_rate': 0.012570659380214393, 'max_depth': 7, 'min_child_weight': 1, 'n_estimators': 722, 'subsample': 0.79}
# SCORE: -953644.604 params {'colsample_bytree': 0.8, 'gamma': 0.8539678943657997, 'lambda': 1.0921622585927493, 'learning_rate': 0.026826457026650992, 'max_depth': 8, 'min_child_weight': 3, 'n_estimators': 361, 'subsample': 0.79}
# SCORE: -939840.708 params {'colsample_bytree': 0.8, 'gamma': 4.47755067145766, 'lambda': 4.566358586960752, 'learning_rate': 0.025075824862537243, 'max_depth': 11, 'min_child_weight': 5, 'n_estimators': 496, 'subsample': 0.79}
# SCORE: -948976.354 params {'colsample_bytree': 0.8, 'gamma': 4.219521244879713, 'lambda': 4.651191285002865, 'learning_rate': 0.023230811420730583, 'max_depth': 8, 'min_child_weight': 1, 'n_estimators': 719, 'subsample': 0.79}
# SCORE: -950645.875 params {'colsample_bytree': 0.8, 'gamma': 0.6704869497532839, 'lambda': 1.5281985940000327, 'learning_rate': 0.007247445999916089, 'max_depth': 9, 'min_child_weight': 5, 'n_estimators': 659, 'subsample': 0.79}
# SCORE: -1142722.417 params {'colsample_bytree': 0.8, 'gamma': 2.9486014284611977, 'lambda': 1.938412732353363, 'learning_rate': 0.015032688573609562, 'max_depth': 1, 'min_child_weight': 1, 'n_estimators': 444, 'subsample': 0.79}
# SCORE: -941307.646 params {'colsample_bytree': 0.8, 'gamma': 3.669093528867835, 'lambda': 2.48883688718222, 'learning_rate': 0.028285218881102282, 'max_depth': 11, 'min_child_weight': 4, 'n_estimators': 910, 'subsample': 0.79}
# SCORE: -950455.812 params {'colsample_bytree': 0.8, 'gamma': 2.5450683413754285, 'lambda': 1.0125249647206327, 'learning_rate': 0.02437074933996908, 'max_depth': 8, 'min_child_weight': 4, 'n_estimators': 602, 'subsample': 0.79}
# SCORE: -981493.417 params {'colsample_bytree': 0.8, 'gamma': 0.5439752504556197, 'lambda': 3.3281248393274288, 'learning_rate': 0.01641648233787064, 'max_depth': 5, 'min_child_weight': 5, 'n_estimators': 657, 'subsample': 0.79}
# SCORE: -1033864.562 params {'colsample_bytree': 0.8, 'gamma': 3.879573306111513, 'lambda': 2.726612480176155, 'learning_rate': 0.025744452128503396, 'max_depth': 3, 'min_child_weight': 4, 'n_estimators': 359, 'subsample': 0.79}
# SCORE: -967408.396 params {'colsample_bytree': 0.8, 'gamma': 1.520228731242627, 'lambda': 4.949064422218578, 'learning_rate': 0.019885363813324494, 'max_depth': 6, 'min_child_weight': 2, 'n_estimators': 620, 'subsample': 0.79}
# SCORE: -1060283.458 params {'colsample_bytree': 0.8, 'gamma': 1.8506589367110713, 'lambda': 0.20883339470482876, 'learning_rate': 0.022270303877797836, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 612, 'subsample': 0.79}
# SCORE: -939164.146 params {'colsample_bytree': 0.8, 'gamma': 1.9300884827402853, 'lambda': 0.2539167377493491, 'learning_rate': 0.029994035437933022, 'max_depth': 11, 'min_child_weight': 2, 'n_estimators': 400, 'subsample': 0.79}
# SCORE: -940554.229 params {'colsample_bytree': 0.8, 'gamma': 1.719500778355834, 'lambda': 0.11832019429127671, 'learning_rate': 0.029827969617815576, 'max_depth': 10, 'min_child_weight': 2, 'n_estimators': 561, 'subsample': 0.79}
# SCORE: -941309.646 params {'colsample_bytree': 0.8, 'gamma': 2.254441481397442, 'lambda': 0.42892288299295167, 'learning_rate': 0.029624565243915307, 'max_depth': 11, 'min_child_weight': 2, 'n_estimators': 873, 'subsample': 0.79}
# SCORE: -939319.229 params {'colsample_bytree': 0.8, 'gamma': 1.2442492148663442, 'lambda': 0.5518793061769476, 'learning_rate': 0.02975400373536882, 'max_depth': 11, 'min_child_weight': 2, 'n_estimators': 633, 'subsample': 0.79}
# SCORE: -942412.917 params {'colsample_bytree': 0.8, 'gamma': 1.1888971801047923, 'lambda': 0.525851436528861, 'learning_rate': 0.02957552565421906, 'max_depth': 11, 'min_child_weight': 2, 'n_estimators': 958, 'subsample': 0.79}
# SCORE: -1043691.500 params {'colsample_bytree': 0.8, 'gamma': 3.336829078262947, 'lambda': 0.6273974248658679, 'learning_rate': 0.021079190542286266, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 358, 'subsample': 0.79}
# SCORE: -965284.271 params {'colsample_bytree': 0.8, 'gamma': 1.2018367964324912, 'lambda': 1.6373774933701815, 'learning_rate': 0.02712709033993862, 'max_depth': 6, 'min_child_weight': 3, 'n_estimators': 563, 'subsample': 0.79}
# SCORE: -1011735.250 params {'colsample_bytree': 0.8, 'gamma': 1.212130988672731, 'lambda': 0.15761982433354474, 'learning_rate': 0.01845427177287443, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 411, 'subsample': 0.79}
# SCORE: -1056180.208 params {'colsample_bytree': 0.8, 'gamma': 2.416481356393416, 'lambda': 3.0024479192636733, 'learning_rate': 0.029590273608973656, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 503, 'subsample': 0.79}
# SCORE: -943453.479 params {'colsample_bytree': 0.8, 'gamma': 2.1354512110604578, 'lambda': 0.6954193541991996, 'learning_rate': 0.025473948479154955, 'max_depth': 10, 'min_child_weight': 2, 'n_estimators': 328, 'subsample': 0.79}
# SCORE: -941123.708 params {'colsample_bytree': 0.8, 'gamma': 0.14578017220503092, 'lambda': 1.2639343735872735, 'learning_rate': 0.013189312234289438, 'max_depth': 11, 'min_child_weight': 2, 'n_estimators': 342, 'subsample': 0.79}
# SCORE: -997164.188 params {'colsample_bytree': 0.8, 'gamma': 1.5532215449462867, 'lambda': 1.9694474620720304, 'learning_rate': 0.028332173156081327, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 431, 'subsample': 0.79}
# SCORE: -1045233.771 params {'colsample_bytree': 0.8, 'gamma': 0.9031922086310249, 'lambda': 1.8695869559477243, 'learning_rate': 0.009181710338096477, 'max_depth': 11, 'min_child_weight': 2, 'n_estimators': 129, 'subsample': 0.79}
# SCORE: -938231.083 params {'colsample_bytree': 0.8, 'gamma': 3.2491569626462806, 'lambda': 0.7758176217295185, 'learning_rate': 0.019562118856941643, 'max_depth': 11, 'min_child_weight': 2, 'n_estimators': 633, 'subsample': 0.79}
# SCORE: -945167.042 params {'colsample_bytree': 0.8, 'gamma': 3.3712230995018615, 'lambda': 0.7996437296642998, 'learning_rate': 0.01748294842923611, 'max_depth': 9, 'min_child_weight': 4, 'n_estimators': 785, 'subsample': 0.79}
# SCORE: -1307403.667 params {'colsample_bytree': 0.8, 'gamma': 3.07817747837639, 'lambda': 0.33528806683026924, 'learning_rate': 0.010540022841282738, 'max_depth': 1, 'min_child_weight': 2, 'n_estimators': 89, 'subsample': 0.79}
# SCORE: -958663.312 params {'colsample_bytree': 0.8, 'gamma': 4.59594535984843, 'lambda': 3.842989737006902, 'learning_rate': 0.012575508261177978, 'max_depth': 7, 'min_child_weight': 3, 'n_estimators': 944, 'subsample': 0.79}
# SCORE: -974191.604 params {'colsample_bytree': 0.8, 'gamma': 2.7388486509397527, 'lambda': 1.1443237003918236, 'learning_rate': 0.020414742912384272, 'max_depth': 5, 'min_child_weight': 2, 'n_estimators': 834, 'subsample': 0.79}
# SCORE: -1041188.896 params {'colsample_bytree': 0.8, 'gamma': 3.304564992933922, 'lambda': 3.2295516379808533, 'learning_rate': 0.015049235543474562, 'max_depth': 6, 'min_child_weight': 2, 'n_estimators': 86, 'subsample': 0.79}
# SCORE: -941700.271 params {'colsample_bytree': 0.8, 'gamma': 3.7267546927875084, 'lambda': 1.3299163565728942, 'learning_rate': 0.022847658602536902, 'max_depth': 11, 'min_child_weight': 1, 'n_estimators': 219, 'subsample': 0.79}
# SCORE: -1049878.417 params {'colsample_bytree': 0.8, 'gamma': 1.9880323552750987, 'lambda': 1.7663748438559115, 'learning_rate': 0.009051356423912872, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 724, 'subsample': 0.79}
# SCORE: -1454557.333 params {'colsample_bytree': 0.8, 'gamma': 3.9881160607457042, 'lambda': 0.8669181790791104, 'learning_rate': 0.005011929431976602, 'max_depth': 10, 'min_child_weight': 4, 'n_estimators': 117, 'subsample': 0.79}
# SCORE: -1113088.292 params {'colsample_bytree': 0.8, 'gamma': 2.3612236447257224, 'lambda': 2.072693055900962, 'learning_rate': 0.018903693260388856, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 240, 'subsample': 0.79}
# SCORE: -1015024.062 params {'colsample_bytree': 0.8, 'gamma': 2.7006680672976024, 'lambda': 0.2893984547809225, 'learning_rate': 0.016473879918806025, 'max_depth': 4, 'min_child_weight': 5, 'n_estimators': 412, 'subsample': 0.79}
# SCORE: -956186.938 params {'colsample_bytree': 0.8, 'gamma': 3.177866436528678, 'lambda': 2.2534032879188426, 'learning_rate': 0.02200206729497347, 'max_depth': 7, 'min_child_weight': 1, 'n_estimators': 696, 'subsample': 0.79}
# SCORE: -941037.812 params {'colsample_bytree': 0.8, 'gamma': 3.623254335416256, 'lambda': 3.668049553933692, 'learning_rate': 0.013744038425170257, 'max_depth': 11, 'min_child_weight': 2, 'n_estimators': 321, 'subsample': 0.79}
# SCORE: -1122050.042 params {'colsample_bytree': 0.8, 'gamma': 4.745086850674813, 'lambda': 4.253695826033249, 'learning_rate': 0.011916070311818194, 'max_depth': 9, 'min_child_weight': 1, 'n_estimators': 84, 'subsample': 0.79}
# SCORE: -1138678.958 params {'colsample_bytree': 0.8, 'gamma': 4.3827025596610785, 'lambda': 2.7829295490519965, 'learning_rate': 0.024275375154603058, 'max_depth': 1, 'min_child_weight': 5, 'n_estimators': 313, 'subsample': 0.79}
# 100%|██████████| 50/50 [2:53:38<00:00, 105.20s/it, best loss: 938231.0833333334]
# Tiempo = 173.64 minutos

# %%
print(best)
# Out:
# {'xgb_re__gamma': 3.2491569626462806, 'xgb_re__lambda': 0.7758176217295185, 'xgb_re__learning_rate': 0.019562118856941643, 'xgb_re__max_depth': 10, 'xgb_re__min_child_weight': 1, 'xgb_re__n_estimators': 632}

# %% [markdown]
# Solo Xgboost
# {
#   'xgb_re__gamma': 3.2491569626462806,
#   'xgb_re__lambda': 0.7758176217295185,
#   'xgb_re__learning_rate': 0.019562118856941643,
#   'xgb_re__max_depth': 10 + 1,
#   'xgb_re__min_child_weight': 1 + 1,
#   'xgb_re__n_estimators': 632
# }
# Score = 938231.0833333334
