# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks')

# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv("/content/drive/My Drive/Colab Notebooks/sets_de_datos/dima_train_with_features_9.csv",
                    dtype={ \
                            'antiguedad' : np.float32, 
                            'habitaciones' : np.float32, 
                            'garages' : np.float32, 
                            'banos' : np.float32,
                            'metroscubiertos' : np.float32, 
                            'metrostotales' : np.float32, 
                            'idzona' : np.float32, 
                            'lat' : np.float32, 
                            'lng' : np.float32, 
                            'gimnasio' : np.float32, 
                            'usosmultiples' : np.float32, 
                            'piscina' : np.float32, 
                            'escuelascercanas' : np.float32,
                            'centroscomercialescercanos' : np.float32, 
                            'precio' : np.float32, 
                            'servicios_cercanos' : np.float32,
                            'utilidades_extra' : np.float32, 
                            'tipodepropiedad_mean_antiguedad' : np.float32,
                            'tipodepropiedad_mean_habitaciones ' : np.float32, 
                            'tipodepropiedad_mean_garages' : np.float32,
                            'tipodepropiedad_mean_banos' : np.float32, 
                            'tipodepropiedad_mean_metroscubiertos' : np.float32,
                            'tipodepropiedad_mean_utilidades_extra' : np.float32,
                            'tipodepropiedad_mean_servicios_cercanos' : np.float32, 
                            'ciudad_mean_antiguedad' : np.float32,
                            'ciudad_mean_habitaciones' : np.float32, 
                            'ciudad_mean_garages' : np.float32, 
                            'ciudad_mean_banos': np.float32,
                            'ciudad_mean_metroscubiertos' : np.float32, 
                            'ciudad_mean_utilidades_extra' : np.float32,
                            'ciudad_mean_servicios_cercanos' : np.float32, 
                            'provincia_mean_antiguedad' : np.float32,
                            'provincia_mean_habitaciones' : np.float32, 
                            'provincia_mean_garages' : np.float32,
                            'provincia_mean_banos' : np.float32, 
                            'provincia_mean_metroscubiertos' : np.float32,
                            'provincia_mean_utilidades_extra' : np.float32, 
                            'provincia_mean_servicios_cercanos' : np.float32,
                            'ciudad_mean_lat' : np.float32, 
                            'ciudad_mean_lng' : np.float32, 
                            'provincia_mean_lat' : np.float32,
                            'provincia_mean_lng' : np.float32, 
                            'coseno_distancia_angular_al_centro_ciudad' : np.float32,
                            'coseno_distancia_angular_al_centro_provincia' : np.float32,
                            'coseno_distancia_angular_al_centro_pais' : np.float32, 
                            'año' : np.float32, 
                            'mes' : np.float32, 
                            'dia' : np.float32,
                            'metros_no_cubiertos' : np.float32, 
                            'cantidad_espacios' : np.float32, 
                            'metros_x_espacio' : np.float32,
                            'metros_x_habitaciones' : np.float32, 
                            'metros_x_garages' : np.float32, 
                            'metros_x_banos' : np.float32,
                            'metros_x_utilidades_extra' : np.float32, 
                            'ratio_metros_cubiertos' : np.float32, 
                            'distancia_minima_Apartamento': np.float32,
                            'distancia_minima_Bodega_comercial': np.float32,
                            'distancia_minima_Casa': np.float32,
                            'distancia_minima_Casa_en_condominio': np.float32,
                            'distancia_minima_Casa_uso_de_suelo': np.float32,
                            'distancia_minima_Departamento_Compartido': np.float32,
                            'distancia_minima_Duplex': np.float32,
                            'distancia_minima_Edificio': np.float32,
                            'distancia_minima_Garage': np.float32,
                            'distancia_minima_Hospedaje': np.float32,
                            'distancia_minima_Huerta': np.float32,
                            'distancia_minima_Inmuebles_productivos_urbanos': np.float32,
                            'distancia_minima_Local_Comercial': np.float32,
                            'distancia_minima_Local_en_centro_comercial': np.float32,
                            'distancia_minima_Lote': np.float32,
                            'distancia_minima_Nave_industrial': np.float32,
                            'distancia_minima_Oficina_comercial': np.float32,
                            'distancia_minima_Otros': np.float32,
                            'distancia_minima_Quinta_Vacacional': np.float32,
                            'distancia_minima_Rancho': np.float32,
                            'distancia_minima_Terreno': np.float32,
                            'distancia_minima_Terreno_comercial': np.float32,
                            'distancia_minima_Terreno_industrial' : np.float32,
                            'distancia_minima_promedio_ricos' : np.float32,
                            'distancia_minima_promedio_pobres' : np.float32,
                            'distancia_minima_Villa' : np.float32,
                            'banos_preciopromedio_ciudad' : np.float32,
                            'habitaciones_preciopromedio_ciudad' : np.float32, 
                            'garages_preciopromedio_ciudad' : np.float32,
                            'banos_preciopromedio_metroscubiertos' : np.float32,
                            'habitaciones_preciopromedio_metroscubiertos' : np.float32,
                            'garages_preciopromedio_metroscubiertos' : np.float32, 
                            'precio_x_m2' : np.float32,
                            'tipodepropiedad_mean_precio' : np.float32, 
                            'titulo_cantidad_palabras_importantes' : np.float32,
                            'descripcion_cantidad_palabras_importantes' : np.float32,
                            'direccion_cantidad_palabras_importantes' : np.float32,
                            'titulo_cantidad_caracteres_en_palabras_importantes' : np.float32,
                            'descripcion_cantidad_caracteres_en_palabras_importantes' : np.float32,
                            'direccion_cantidad_caracteres_en_palabras_importantes' : np.float32,
                            'titulo_longitud_media_de_palabra' : np.float32,
                            'descripcion_longitud_media_de_palabra' : np.float32,
                            'direccion_longitud_media_de_palabra' : np.float32, 
                            'titulo_cantidad_stopwords' : np.float32,
                            'descripcion_cantidad_stopwords' : np.float32, 
                            'direccion_cantidad_stopwords' : np.float32,
                            'titulo_cantidad_signos_puntacion' : np.float32,
                            'descripcion_cantidad_signos_puntacion' : np.float32,
                            'direccion_cantidad_signos_puntacion' : np.float32,
                            'direccion_cantidad_palabras_en_mayuscula' : np.float32,
                            'direccion_cantidad_titulos' : np.float32, 
                            'titulo_cantidad_palabras_top_k' : np.float32,
                            'descripcion_cantidad_palabras_top_k' : np.float32,
                            'direccion_cantidad_palabras_top_k' : np.float32,
                            'titulo_cantidad_palabras_bottom_k' : np.float32,
                            'descripcion_cantidad_palabras_bottom_k' : np.float32,
                            'direccion_cantidad_palabras_bottom_k' : np.float32,
                            'titulo_cantidad_prefijos_top_k' : np.float32, 
                            'descripcion_cantidad_prefijos_top_k' : np.float32,
                            'direccion_cantidad_prefijos_top_k' : np.float32, 
                            'titulo_cantidad_postfijos_top_k' : np.float32,
                            'descripcion_cantidad_postfijos_top_k' : np.float32,
                            'direccion_cantidad_postfijos_top_k' : np.float32, 
                            '0' : np.float32, 
                            '1' : np.float32, 
                            '2' : np.float32, 
                            '3' : np.float32, 
                            '4' : np.float32, 
                            '5' : np.float32, 
                            '6' : np.float32,
                            '7' : np.float32,
                            'distancia_euclideana_al_origen' : np.float32, 
                            'distancia_minima_comercial' : np.float32,
                            'coseno_maximo_ciudad_pais' : np.float32,
                            'ciudad_mean_antiguedad_sobre_provincia_mean_antiguedad' : np.float32,
                            'tipodepropiead_mean_utilidades_extra_sobre_ciudad_mean_utilidades_extra' : np.float32,
                            'antiguedad_sobre_tipodepropiedad_mean_antiguedad' : np.float32,
                            'direccion_cantidad_al_menos_una_mayuscula' : np.float32,
                            'direccion_cantidad_fijos_top_k' : np.float32, 
                            'titulo_cantidad_fijos_top_k' : np.float32,
                            'titulo_palabras_top_k_sobre_total_palabras' : np.float32,
                            'ciudad_distancia_al_origen':  np.float32, 
                            'ciudad_mean_mean_todas' : np.float32,
                            'ciudad_mean_antiguedad_sobre_mean_metrocubiertos' : np.float32
                            }
                    )

# %%
train.set_index('id', inplace = True)

# %%
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def evaluar_modelo(modelo, XX_test, y_test):
    y_pred = modelo.predict(XX_test)
    errors = abs(y_pred - y_test)
    mape = 100 * np.mean(errors / y_test)
    accuracy = 100 - mape
    print('Performance del modelo:')
    print('Average Error: {:0.4f} degrees.'.format(np.mean(errors)))
    print('Accuracy = {:0.2f}%.'.format(accuracy))
    return accuracy

# %%
def plot_importance(modelo):
  feat_imp_1 = pd.Series(modelo.get_booster().get_fscore()).sort_values(ascending=False)
  feat_imp_1.plot(kind='barh', title='Feature Importances', figsize=(15, 15))
  plt.ylabel('Feature Importance Score')
  plt.show()
  return feat_imp_1

# %%
TARGET = 'precio'
FEATURES_1 = ['descripcion_longitud_media_de_palabra', 'metrostotales',
            'metros_x_espacio', 'idzona', 'lat', 'titulo_longitud_media_de_palabra',
            'metros_x_garages','metroscubiertos', 'metros_x_habitaciones', 'metros_x_banos',
            'titulo_cantidad_caracteres_en_palabras_importantes',
            'descripcion_cantidad_palabras_top_k',
            'descripcion_cantidad_caracteres_en_palabras_importantes',
            'coseno_distancia_angular_al_centro_provincia',
            'descripcion_cantidad_stopwords',
            'descripcion_cantidad_signos_puntacion',
            'direccion_longitud_media_de_palabra',
            'titulo_palabras_top_k_sobre_total_palabras',
            'habitaciones_preciopromedio_ciudad', 'antiguedad', 'lng',
            'garages_preciopromedio_ciudad',
            'direccion_cantidad_caracteres_en_palabras_importantes',
            'coseno_distancia_angular_al_centro_ciudad',
            'banos_preciopromedio_ciudad', 'descripcion_cantidad_prefijos_top_k',
            'precio_x_m2', 'año', 'titulo_cantidad_fijos_top_k',
            'descripcion_cantidad_palabras_importantes',
            'descripcion_cantidad_postfijos_top_k', 'ciudad_mean_mean_todas',
            'ciudad_mean_antiguedad_sobre_mean_metrocubiertos',
            'habitaciones_preciopromedio_metroscubiertos', 'cantidad_espacios',
            'direccion_cantidad_al_menos_una_mayuscula',
            'direccion_cantidad_fijos_top_k', 'ciudad_distancia_al_origen',
            'distancia_minima_Apartamento',
            'distancia_minima_Bodega_comercial',
            'distancia_minima_Casa',
            'distancia_minima_Casa_en_condominio',
            'distancia_minima_Casa_uso_de_suelo',
            'distancia_minima_Departamento_Compartido',
            'distancia_minima_Duplex',
            'distancia_minima_Edificio',
            'distancia_minima_Garage',
            'distancia_minima_Hospedaje',
            'distancia_minima_Huerta',
            'distancia_minima_Inmuebles_productivos_urbanos',
            'distancia_minima_Local_Comercial',
            'distancia_minima_Local_en_centro_comercial',
            'distancia_minima_Lote',
            'distancia_minima_Nave_industrial',
            'distancia_minima_Oficina_comercial',
            'distancia_minima_Otros',
            'distancia_minima_Quinta_Vacacional',
            'distancia_minima_Rancho',
            'distancia_minima_Terreno',
            'distancia_minima_Terreno_comercial',
            'distancia_minima_Terreno_industrial',
            'distancia_minima_Villa',
            'distancia_minima_promedio_ricos',
            'distancia_minima_promedio_pobres']

# %%
params = {
    'colsample_bytree': 0.8,
    'gamma': 4.7506160486034,
    'lambda': 1.1183589932730134,
    'learning_rate': 0.02611652524078614,
    'max_depth': 18,
    'min_child_weight': 9,
    'n_estimators': 604,
    'subsample': 0.8
    }
xgb_regressor = XGBRegressor(objective = 'reg:squarederror', **params)

# %%
X_train_1, XX_test_1, y_train_1, y_test_1 = train_test_split(train[FEATURES_1], train[TARGET], test_size=0.2, random_state=50)

# %%
xgb_regressor.fit(X_train_1, y_train_1)
# Out:
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.8, gamma=4.7506160486034,
#              importance_type='gain', lambda=1.1183589932730134,
#              learning_rate=0.02611652524078614, max_delta_step=0, max_depth=18,
#              min_child_weight=9, missing=None, n_estimators=604, n_jobs=1,
#              nthread=None, objective='reg:squarederror', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=0.8, verbosity=1)

# %%
evaluar_modelo(xgb_regressor, XX_test_1, y_test_1)
# Out:
# Performance del modelo:
# Average Error: 529633.0000 degrees.
# Accuracy = 74.34%.
# 74.3382066488266

# %%
nombres_importancia_1 = plot_importance(xgb_regressor)

# %%
train = pd.read_csv("/content/drive/My Drive/Colab Notebooks/sets_de_datos/dima_train_with_features_10.csv",
                    dtype={ \
                            'antiguedad' : np.float32, 
                            'habitaciones' : np.float32, 
                            'garages' : np.float32, 
                            'banos' : np.float32,
                            'metroscubiertos' : np.float32, 
                            'metrostotales' : np.float32, 
                            'idzona' : np.float32, 
                            'lat' : np.float32, 
                            'lng' : np.float32, 
                            'gimnasio' : np.float32, 
                            'usosmultiples' : np.float32, 
                            'piscina' : np.float32, 
                            'escuelascercanas' : np.float32,
                            'centroscomercialescercanos' : np.float32, 
                            'precio' : np.float32, 
                            'servicios_cercanos' : np.float32,
                            'utilidades_extra' : np.float32, 
                            'tipodepropiedad_mean_antiguedad' : np.float32,
                            'tipodepropiedad_mean_habitaciones ' : np.float32, 
                            'tipodepropiedad_mean_garages' : np.float32,
                            'tipodepropiedad_mean_banos' : np.float32, 
                            'tipodepropiedad_mean_metroscubiertos' : np.float32,
                            'tipodepropiedad_mean_utilidades_extra' : np.float32,
                            'tipodepropiedad_mean_servicios_cercanos' : np.float32, 
                            'ciudad_mean_antiguedad' : np.float32,
                            'ciudad_mean_habitaciones' : np.float32, 
                            'ciudad_mean_garages' : np.float32, 
                            'ciudad_mean_banos': np.float32,
                            'ciudad_mean_metroscubiertos' : np.float32, 
                            'ciudad_mean_utilidades_extra' : np.float32,
                            'ciudad_mean_servicios_cercanos' : np.float32, 
                            'provincia_mean_antiguedad' : np.float32,
                            'provincia_mean_habitaciones' : np.float32, 
                            'provincia_mean_garages' : np.float32,
                            'provincia_mean_banos' : np.float32, 
                            'provincia_mean_metroscubiertos' : np.float32,
                            'provincia_mean_utilidades_extra' : np.float32, 
                            'provincia_mean_servicios_cercanos' : np.float32,
                            'ciudad_mean_lat' : np.float32, 
                            'ciudad_mean_lng' : np.float32, 
                            'provincia_mean_lat' : np.float32,
                            'provincia_mean_lng' : np.float32, 
                            'producto_interno_centro_ciudad' : np.float32,
                            'producto_interno_centro_provincia' : np.float32,
                            'producto_interno_centro_pais' : np.float32, 
                            'año' : np.float32, 
                            'mes' : np.float32, 
                            'dia' : np.float32,
                            'metros_no_cubiertos' : np.float32, 
                            'cantidad_espacios' : np.float32, 
                            'metros_x_espacio' : np.float32,
                            'metros_x_habitaciones' : np.float32, 
                            'metros_x_garages' : np.float32, 
                            'metros_x_banos' : np.float32,
                            'metros_x_utilidades_extra' : np.float32, 
                            'ratio_metros_cubiertos' : np.float32, 
                            'distancia_minima_Apartamento': np.float32,
                            'distancia_minima_Bodega_comercial': np.float32,
                            'distancia_minima_Casa': np.float32,
                            'distancia_minima_Casa_en_condominio': np.float32,
                            'distancia_minima_Casa_uso_de_suelo': np.float32,
                            'distancia_minima_Departamento_Compartido': np.float32,
                            'distancia_minima_Duplex': np.float32,
                            'distancia_minima_Edificio': np.float32,
                            'distancia_minima_Garage': np.float32,
                            'distancia_minima_Hospedaje': np.float32,
                            'distancia_minima_Huerta': np.float32,
                            'distancia_minima_Inmuebles_productivos_urbanos': np.float32,
                            'distancia_minima_Local_Comercial': np.float32,
                            'distancia_minima_Local_en_centro_comercial': np.float32,
                            'distancia_minima_Lote': np.float32,
                            'distancia_minima_Nave_industrial': np.float32,
                            'distancia_minima_Oficina_comercial': np.float32,
                            'distancia_minima_Otros': np.float32,
                            'distancia_minima_Quinta_Vacacional': np.float32,
                            'distancia_minima_Rancho': np.float32,
                            'distancia_minima_Terreno': np.float32,
                            'distancia_minima_Terreno_comercial': np.float32,
                            'distancia_minima_Terreno_industrial' : np.float32,
                            'distancia_minima_promedio_ricos' : np.float32,
                            'distancia_minima_promedio_pobres' : np.float32,
                            'distancia_minima_Villa' : np.float32,
                            'distancia_centro_ciudad' : np.float32,
                            'distancia_centro_provincia' : np.float32,
                            'distancia_centro_pais' : np.float32,
                            'banos_preciopromedio_ciudad' : np.float32,
                            'habitaciones_preciopromedio_ciudad' : np.float32, 
                            'garages_preciopromedio_ciudad' : np.float32,
                            'banos_preciopromedio_metroscubiertos' : np.float32,
                            'habitaciones_preciopromedio_metroscubiertos' : np.float32,
                            'garages_preciopromedio_metroscubiertos' : np.float32, 
                            'precio_x_m2' : np.float32,
                            'tipodepropiedad_mean_precio' : np.float32, 
                            'titulo_cantidad_palabras_importantes' : np.float32,
                            'descripcion_cantidad_palabras_importantes' : np.float32,
                            'direccion_cantidad_palabras_importantes' : np.float32,
                            'titulo_cantidad_caracteres_en_palabras_importantes' : np.float32,
                            'descripcion_cantidad_caracteres_en_palabras_importantes' : np.float32,
                            'direccion_cantidad_caracteres_en_palabras_importantes' : np.float32,
                            'titulo_longitud_media_de_palabra' : np.float32,
                            'descripcion_longitud_media_de_palabra' : np.float32,
                            'direccion_longitud_media_de_palabra' : np.float32, 
                            'titulo_cantidad_stopwords' : np.float32,
                            'descripcion_cantidad_stopwords' : np.float32, 
                            'direccion_cantidad_stopwords' : np.float32,
                            'titulo_cantidad_signos_puntacion' : np.float32,
                            'descripcion_cantidad_signos_puntacion' : np.float32,
                            'direccion_cantidad_signos_puntacion' : np.float32,
                            'direccion_cantidad_palabras_en_mayuscula' : np.float32,
                            'direccion_cantidad_titulos' : np.float32, 
                            'titulo_cantidad_palabras_top_k' : np.float32,
                            'descripcion_cantidad_palabras_top_k' : np.float32,
                            'direccion_cantidad_palabras_top_k' : np.float32,
                            'titulo_cantidad_palabras_bottom_k' : np.float32,
                            'descripcion_cantidad_palabras_bottom_k' : np.float32,
                            'direccion_cantidad_palabras_bottom_k' : np.float32,
                            'titulo_cantidad_prefijos_top_k' : np.float32, 
                            'descripcion_cantidad_prefijos_top_k' : np.float32,
                            'direccion_cantidad_prefijos_top_k' : np.float32, 
                            'titulo_cantidad_postfijos_top_k' : np.float32,
                            'descripcion_cantidad_postfijos_top_k' : np.float32,
                            'direccion_cantidad_postfijos_top_k' : np.float32, 
                            'categoria_descripcion_0' : np.float32, 
                            'categoria_descripcion_1' : np.float32, 
                            'categoria_descripcion_2' : np.float32, 
                            'categoria_descripcion_3' : np.float32, 
                            'categoria_descripcion_4' : np.float32, 
                            'categoria_descripcion_5' : np.float32, 
                            'categoria_descripcion_6' : np.float32,
                            'categoria_descripcion_7' : np.float32,
                            'distancia_euclideana_al_origen' : np.float32, 
                            'distancia_minima_comercial' : np.float32,
                            'producto_interno_maximo_ciudad_pais' : np.float32,
                            'ciudad_mean_antiguedad_sobre_provincia_mean_antiguedad' : np.float32,
                            'tipodepropiead_mean_utilidades_extra_sobre_ciudad_mean_utilidades_extra' : np.float32,
                            'antiguedad_sobre_tipodepropiedad_mean_antiguedad' : np.float32,
                            'direccion_cantidad_al_menos_una_mayuscula' : np.float32,
                            'direccion_cantidad_fijos_top_k' : np.float32, 
                            'titulo_cantidad_fijos_top_k' : np.float32,
                            'titulo_palabras_top_k_sobre_total_palabras' : np.float32,
                            'ciudad_distancia_al_origen':  np.float32, 
                            'ciudad_mean_mean_todas' : np.float32,
                            'ciudad_mean_antiguedad_sobre_mean_metrocubiertos' : np.float32
                            }
                    )

# %%
add_columns_2 = ['distancia_centro_ciudad','distancia_centro_provincia','distancia_centro_pais', 
                 'producto_interno_centro_provincia', 'producto_interno_centro_ciudad']
drop_columns_2 = ['direccion_cantidad_fijos_top_k', 'distancia_minima_Huerta',
                  'distancia_minima_Garage',
                  'ciudad_mean_antiguedad_sobre_mean_metrocubiertos',
                  'direccion_cantidad_al_menos_una_mayuscula',
                  'distancia_minima_Nave_industrial',
                  'distancia_minima_Terreno_industrial', 'distancia_minima_Hospedaje',
                  'ciudad_distancia_al_origen',
                  'coseno_distancia_angular_al_centro_provincia', 
                  'coseno_distancia_angular_al_centro_ciudad']
FEATURES_2 = list(set(FEATURES_1) - set(drop_columns_2)) + add_columns_2

# %%
X_train_2, XX_test_2, y_train_2, y_test_2 = train_test_split(train[FEATURES_2], train[TARGET], test_size=0.2, random_state=51)

# %%
xgb_regressor.fit(X_train_2, y_train_2)
# Out:
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.8, gamma=4.7506160486034,
#              importance_type='gain', lambda=1.1183589932730134,
#              learning_rate=0.02611652524078614, max_delta_step=0, max_depth=18,
#              min_child_weight=9, missing=None, n_estimators=604, n_jobs=1,
#              nthread=None, objective='reg:squarederror', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=0.8, verbosity=1)

# %%
evaluar_modelo(xgb_regressor, XX_test_2, y_test_2)
# Out:
# Performance del modelo:
# Average Error: 525345.1250 degrees.
# Accuracy = 74.37%.
# 74.37475919723511

# %%
nombres_importancia_2 = plot_importance(xgb_regressor)

# %%
nombres_importancia_2.index
# Out:
# Index(['metrostotales', 'descripcion_longitud_media_de_palabra',
#        'metros_x_habitaciones', 'metros_x_banos', 'metros_x_garages',
#        'metroscubiertos', 'metros_x_espacio',
#        'titulo_longitud_media_de_palabra',
#        'descripcion_cantidad_palabras_top_k',
#        'titulo_cantidad_caracteres_en_palabras_importantes',
#        'distancia_minima_Casa', 'idzona',
#        'descripcion_cantidad_signos_puntacion',
#        'distancia_minima_promedio_ricos', 'distancia_minima_promedio_pobres',
#        'descripcion_cantidad_stopwords',
#        'descripcion_cantidad_caracteres_en_palabras_importantes',
#        'direccion_longitud_media_de_palabra',
#        'titulo_palabras_top_k_sobre_total_palabras',
#        'direccion_cantidad_caracteres_en_palabras_importantes',
#        'habitaciones_preciopromedio_ciudad', 'antiguedad',
#        'distancia_centro_ciudad', 'distancia_minima_Terreno',
#        'distancia_minima_Apartamento', 'distancia_minima_Casa_en_condominio',
#        'garages_preciopromedio_ciudad', 'lat', 'banos_preciopromedio_ciudad',
#        'distancia_minima_Oficina_comercial', 'distancia_centro_provincia',
#        'año', 'distancia_minima_Local_Comercial',
#        'distancia_minima_Departamento_Compartido', 'distancia_minima_Villa',
#        'distancia_minima_Bodega_comercial',
#        'descripcion_cantidad_prefijos_top_k',
#        'descripcion_cantidad_postfijos_top_k', 'titulo_cantidad_fijos_top_k',
#        'distancia_minima_Otros', 'distancia_minima_Edificio',
#        'distancia_minima_Terreno_comercial',
#        'descripcion_cantidad_palabras_importantes', 'distancia_minima_Duplex',
#        'distancia_minima_Quinta_Vacacional', 'distancia_minima_Lote',
#        'distancia_minima_Rancho', 'precio_x_m2',
#        'habitaciones_preciopromedio_metroscubiertos',
#        'distancia_minima_Casa_uso_de_suelo', 'cantidad_espacios',
#        'producto_interno_centro_ciudad', 'lng', 'ciudad_mean_mean_todas',
#        'distancia_minima_Local_en_centro_comercial',
#        'distancia_minima_Inmuebles_productivos_urbanos',
#        'distancia_centro_pais', 'producto_interno_centro_provincia'],
#       dtype='object')

# %%
solo_distrito_federal = train[train['provincia'] == 'Distrito Federal']

# %%
solo_distrito_federal['lat'].mean()
# Out:
# 19.373363494873047

# %%
solo_distrito_federal['lng'].mean()
# Out:
# -98.84355926513672

# %%
train['distancia_Distrito_Federal'] = train.apply(lambda x:
                                                  np.sqrt(np.square(x['lat'] - (19.373363494873047)) + np.square(x['lng'] - (-98.84355926513672))), 
                                                  axis = 1)

# %%
drop_columns_3 = ['distancia_centro_pais', 'producto_interno_centro_provincia']
add_columns_3 = ['distancia_Distrito_Federal']
FEATURES_3 = list(set(FEATURES_2) - set(drop_columns_3)) + add_columns_3

# %%
X_train_3, XX_test_3, y_train_3, y_test_3 = train_test_split(train[FEATURES_3], train[TARGET], test_size=0.2, random_state=52)

# %%
xgb_regressor.fit(X_train_3, y_train_3)
# Out:
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.8, gamma=4.7506160486034,
#              importance_type='gain', lambda=1.1183589932730134,
#              learning_rate=0.02611652524078614, max_delta_step=0, max_depth=18,
#              min_child_weight=9, missing=None, n_estimators=604, n_jobs=1,
#              nthread=None, objective='reg:squarederror', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=0.8, verbosity=1)

# %%
evaluar_modelo(xgb_regressor, XX_test_3, y_test_3)
# Out:
# Performance del modelo:
# Average Error: 531098.9375 degrees.
# Accuracy = 74.34%.
# 74.34449791908264

# %%
nombres_importancia_3 = plot_importance(xgb_regressor)

# %%
nombres_importancia_3
# Out:
# metrostotales                                              58531
# descripcion_longitud_media_de_palabra                      50743
# metros_x_habitaciones                                      45384
# metros_x_garages                                           44172
# metros_x_banos                                             42743
# metroscubiertos                                            42191
# titulo_longitud_media_de_palabra                           40743
# metros_x_espacio                                           37928
# titulo_cantidad_caracteres_en_palabras_importantes         36160
# descripcion_cantidad_palabras_top_k                        35391
# distancia_minima_Casa                                      35216
# distancia_minima_promedio_ricos                            33348
# idzona                                                     31714
# descripcion_cantidad_stopwords                             30905
# descripcion_cantidad_caracteres_en_palabras_importantes    30638
# descripcion_cantidad_signos_puntacion                      30622
# direccion_cantidad_caracteres_en_palabras_importantes      30348
# titulo_palabras_top_k_sobre_total_palabras                 30309
# distancia_minima_promedio_pobres                           30270
# antiguedad                                                 30097
# direccion_longitud_media_de_palabra                        29432
# habitaciones_preciopromedio_ciudad                         28021
# distancia_minima_Apartamento                               27214
# distancia_minima_Casa_en_condominio                        26801
# distancia_centro_ciudad                                    26304
# lat                                                        25800
# banos_preciopromedio_ciudad                                25539
# distancia_minima_Terreno                                   24965
# garages_preciopromedio_ciudad                              24452
# distancia_minima_Oficina_comercial                         23197
# producto_interno_centro_ciudad                             23031
# año                                                        22767
# distancia_centro_provincia                                 22248
# distancia_minima_Local_Comercial                           21002
# descripcion_cantidad_prefijos_top_k                        19819
# distancia_minima_Rancho                                    19271
# distancia_minima_Bodega_comercial                          19268
# distancia_minima_Terreno_comercial                         18989
# distancia_minima_Departamento_Compartido                   18940
# descripcion_cantidad_palabras_importantes                  18938
# distancia_minima_Villa                                     18617
# titulo_cantidad_fijos_top_k                                18500
# descripcion_cantidad_postfijos_top_k                       18467
# distancia_minima_Quinta_Vacacional                         17492
# distancia_minima_Otros                                     17471
# distancia_minima_Duplex                                    17377
# distancia_minima_Lote                                      17194
# distancia_minima_Casa_uso_de_suelo                         17145
# distancia_minima_Edificio                                  16953
# habitaciones_preciopromedio_metroscubiertos                16404
# lng                                                        16127
# precio_x_m2                                                16121
# cantidad_espacios                                          15696
# ciudad_mean_mean_todas                                     14961
# distancia_minima_Local_en_centro_comercial                 14186
# distancia_Distrito_Federal                                 13547
# distancia_minima_Inmuebles_productivos_urbanos             12895
# dtype: int64
