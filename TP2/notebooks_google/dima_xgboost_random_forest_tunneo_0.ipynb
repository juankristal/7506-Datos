# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Imports

# %%
import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks')

# %%
import feature_string as feature_string
import feature_num as feature_num
import feature_categorica as feature_categorica
import common_machine_learning as common
import my_pipeline as my_pipe
import pandas as pd
import numpy as np
from hyperopt import fmin, tpe, hp, STATUS_OK
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline
from xgboost import XGBRFRegressor
import xgboost as xgb
import time

# %% [markdown]
# #### Ignore Future Warning

# %%
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## Constantes

# %%
TARGET = 'precio'
K = 3
RANDOM_SEMILLA = 3 # numero favorito (de la suerte)
XGB_RE_OBJECTIVE = 'reg:squarederror'
N_ITER = 50

# %% [markdown]
# ## Train

# %%
train = common.cargar_set_optimizado('/content/drive/My Drive/Colab Notebooks/sets_de_datos/train.csv')

# %% [markdown]
# ## Features

# %%
feature_num.agregar_feature_fecha_numerica(train)

# %% [markdown]
# Esto toma unos segundos

# %%
train = feature_num.completar_lat_lng_con_provincias_y_ciudades(train)
train = feature_num.completar_lat_lng_con_idzona_mean(train)
feature_num.completar_lat_lng_con_promedio_Mexico(train)

# %%
train = feature_categorica.agregar_tipodepropiedad_precio_mean(train)

# %%
train = feature_categorica.train_agregar_feature_provincias_ciudades_ohe_reducido_df(train)

# %%
train = feature_string.train_agregar_feature_string_todos_df(train)

# %%
train.columns
# Out:
# Index(['id', 'titulo', 'descripcion', 'tipodepropiedad', 'direccion', 'ciudad',
#        'provincia', 'antiguedad', 'habitaciones', 'garages', 'banos',
#        'metroscubiertos', 'metrostotales', 'idzona', 'lat', 'lng', 'fecha',
#        'gimnasio', 'usosmultiples', 'piscina', 'escuelascercanas',
#        'centroscomercialescercanos', 'precio', 'fecha_numerica',
#        'tipodepropiedad_precio_mean', 'ciudad_San_Luis_Potosí',
#        'ciudad_Querétaro', 'ciudad_Zapopan', 'ciudad_Huixquilucan',
#        'ciudad_Mérida', 'provincia_Distrito_Federal',
#        'provincia_Edo._de_México', 'provincia_San_luis_Potosí',
#        'provincia_Yucatán', 'provincia_Querétaro',
#        'titulo_cantidad_palabras_importantes',
#        'descripcion_cantidad_palabras_importantes',
#        'direccion_cantidad_palabras_importantes',
#        'titulo_cantidad_caracteres_en_palabras_importantes',
#        'descripcion_cantidad_caracteres_en_palabras_importantes',
#        'direccion_cantidad_caracteres_en_palabras_importantes',
#        'titulo_longitud_media_de_palabra',
#        'descripcion_longitud_media_de_palabra',
#        'direccion_longitud_media_de_palabra', 'titulo_cantidad_stopwords',
#        'descripcion_cantidad_stopwords', 'direccion_cantidad_stopwords',
#        'titulo_cantidad_signos_puntacion',
#        'descripcion_cantidad_signos_puntacion',
#        'direccion_cantidad_signos_puntacion',
#        'direccion_cantidad_palabras_en_mayuscula',
#        'direccion_cantidad_titulos', 'titulo_cantidad_palabras_top_k',
#        'descripcion_cantidad_palabras_top_k',
#        'direccion_cantidad_palabras_top_k',
#        'titulo_cantidad_palabras_bottom_k',
#        'descripcion_cantidad_palabras_bottom_k',
#        'direccion_cantidad_palabras_bottom_k',
#        'titulo_cantidad_prefijos_top_k', 'descripcion_cantidad_prefijos_top_k',
#        'direccion_cantidad_prefijos_top_k', 'titulo_cantidad_postfijos_top_k',
#        'descripcion_cantidad_postfijos_top_k',
#        'direccion_cantidad_postfijos_top_k'],
#       dtype='object')

# %%
drop_columns = ['titulo', 'descripcion', 'tipodepropiedad', 'direccion', 'ciudad', 'provincia', 'idzona']

# %%
train = train.drop(drop_columns, axis = 1)

# %%
train.shape
# Out:
# (240000, 57)

# %%
train.isnull().sum()
# Out:
# id                                                             0
# antiguedad                                                 43555
# habitaciones                                               22471
# garages                                                    37765
# banos                                                      26221
# metroscubiertos                                            17400
# metrostotales                                              51467
# lat                                                            0
# lng                                                            0
# fecha                                                          0
# gimnasio                                                       0
# usosmultiples                                                  0
# piscina                                                        0
# escuelascercanas                                               0
# centroscomercialescercanos                                     0
# precio                                                         0
# fecha_numerica                                                 0
# tipodepropiedad_precio_mean                                    0
# ciudad_San_Luis_Potosí                                         0
# ciudad_Querétaro                                               0
# ciudad_Zapopan                                                 0
# ciudad_Huixquilucan                                            0
# ciudad_Mérida                                                  0
# provincia_Distrito_Federal                                     0
# provincia_Edo._de_México                                       0
# provincia_San_luis_Potosí                                      0
# provincia_Yucatán                                              0
# provincia_Querétaro                                            0
# titulo_cantidad_palabras_importantes                           0
# descripcion_cantidad_palabras_importantes                      0
# direccion_cantidad_palabras_importantes                        0
# titulo_cantidad_caracteres_en_palabras_importantes             0
# descripcion_cantidad_caracteres_en_palabras_importantes        0
# direccion_cantidad_caracteres_en_palabras_importantes          0
# titulo_longitud_media_de_palabra                               0
# descripcion_longitud_media_de_palabra                          0
# direccion_longitud_media_de_palabra                            0
# titulo_cantidad_stopwords                                      0
# descripcion_cantidad_stopwords                                 0
# direccion_cantidad_stopwords                                   0
# titulo_cantidad_signos_puntacion                               0
# descripcion_cantidad_signos_puntacion                          0
# direccion_cantidad_signos_puntacion                            0
# direccion_cantidad_palabras_en_mayuscula                       0
# direccion_cantidad_titulos                                     0
# titulo_cantidad_palabras_top_k                                 0
# descripcion_cantidad_palabras_top_k                            0
# direccion_cantidad_palabras_top_k                              0
# titulo_cantidad_palabras_bottom_k                              0
# descripcion_cantidad_palabras_bottom_k                         0
# direccion_cantidad_palabras_bottom_k                           0
# titulo_cantidad_prefijos_top_k                                 0
# descripcion_cantidad_prefijos_top_k                            0
# direccion_cantidad_prefijos_top_k                              0
# titulo_cantidad_postfijos_top_k                                0
# descripcion_cantidad_postfijos_top_k                           0
# direccion_cantidad_postfijos_top_k                             0
# dtype: int64

# %%
train.set_index('id', inplace = True)

# %%
X = train.drop([TARGET], axis = 1).copy()
y = train[TARGET].copy()

# %%
pre_procesar_pipe = my_pipe.get_columns_pipeline()

def objective(hyper_parametros):
    
    busqueda_pipe = Pipeline(steps = [
        ('pre-procesar', pre_procesar_pipe),
        ('xgb_regressor', XGBRFRegressor(objective = XGB_RE_OBJECTIVE, **hyper_parametros))
    ])  
    
    score = cross_val_score(busqueda_pipe, X, y, scoring='neg_mean_absolute_error', cv=K).mean()
    
    print("SCORE: {:.3f} params {}".format(score, hyper_parametros))
    
    return {'loss': -score, 'status': STATUS_OK}

# %%
space = {
    "n_estimators": hp.randint("xgb_re__n_estimators", 1000), 
    "learning_rate": hp.uniform("xgb_re__learning_rate", 0.005, 0.03), 
    "gamma": hp.uniform("xgb_re__gamma", 0.1, 5),
    "lambda": hp.uniform("xgb_re__lambda",0.1, 5),
    "max_depth": hp.randint("xgb_re__max_depth", 11) + 1, 
    "subsample": 0.79,
    "colsample_bytree": 0.8,
    "min_child_weight": hp.randint("xgb_re__min_child_weight", 5) + 1
}

# %%
t0 = time.time()
best = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=N_ITER)
t1 = time.time()
print('Tiempo = {0:.2f} minutos'.format((t1 - t0)/60))
# Out:
# SCORE: -2509840.500 params {'colsample_bytree': 0.8, 'gamma': 2.428368405243723, 'lambda': 3.8646906351852572, 'learning_rate': 0.008340336571426752, 'max_depth': 11, 'min_child_weight': 5, 'n_estimators': 164, 'subsample': 0.79}
# SCORE: -2483126.000 params {'colsample_bytree': 0.8, 'gamma': 1.350766692360818, 'lambda': 1.5796173193623455, 'learning_rate': 0.018858712297080263, 'max_depth': 5, 'min_child_weight': 4, 'n_estimators': 497, 'subsample': 0.79}
# SCORE: -2510424.750 params {'colsample_bytree': 0.8, 'gamma': 3.488423567701276, 'lambda': 0.6661071931191829, 'learning_rate': 0.008066170422133824, 'max_depth': 1, 'min_child_weight': 5, 'n_estimators': 194, 'subsample': 0.79}
# SCORE: -2481739.167 params {'colsample_bytree': 0.8, 'gamma': 4.49164987933878, 'lambda': 1.5977612192284554, 'learning_rate': 0.019412670805599202, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 876, 'subsample': 0.79}
# SCORE: -2515718.583 params {'colsample_bytree': 0.8, 'gamma': 0.484344728851656, 'lambda': 2.072663692903453, 'learning_rate': 0.005974265278079522, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 213, 'subsample': 0.79}
# SCORE: -2480591.833 params {'colsample_bytree': 0.8, 'gamma': 1.4387781602435328, 'lambda': 0.8828486911179444, 'learning_rate': 0.019854334149447053, 'max_depth': 3, 'min_child_weight': 4, 'n_estimators': 68, 'subsample': 0.79}
# SCORE: -2470940.167 params {'colsample_bytree': 0.8, 'gamma': 4.689784538500247, 'lambda': 1.0719539461913246, 'learning_rate': 0.02367541444605664, 'max_depth': 5, 'min_child_weight': 1, 'n_estimators': 520, 'subsample': 0.79}
# SCORE: -2492818.833 params {'colsample_bytree': 0.8, 'gamma': 0.28111858682050017, 'lambda': 3.3906117720622477, 'learning_rate': 0.01502269649429491, 'max_depth': 2, 'min_child_weight': 4, 'n_estimators': 866, 'subsample': 0.79}
# SCORE: -2515649.083 params {'colsample_bytree': 0.8, 'gamma': 0.3262359946126803, 'lambda': 0.9904549884655319, 'learning_rate': 0.006001843536788591, 'max_depth': 1, 'min_child_weight': 2, 'n_estimators': 56, 'subsample': 0.79}
# SCORE: -2471365.500 params {'colsample_bytree': 0.8, 'gamma': 3.483317751832571, 'lambda': 3.475625754788399, 'learning_rate': 0.02350022823328392, 'max_depth': 1, 'min_child_weight': 4, 'n_estimators': 762, 'subsample': 0.79}
# SCORE: -2506226.500 params {'colsample_bytree': 0.8, 'gamma': 4.915866241572315, 'lambda': 2.876760011654788, 'learning_rate': 0.009728018826910191, 'max_depth': 5, 'min_child_weight': 4, 'n_estimators': 295, 'subsample': 0.79}
# SCORE: -2478423.500 params {'colsample_bytree': 0.8, 'gamma': 3.224511263863309, 'lambda': 1.206098487302354, 'learning_rate': 0.02075087414329858, 'max_depth': 8, 'min_child_weight': 2, 'n_estimators': 567, 'subsample': 0.79}
# SCORE: -2458781.750 params {'colsample_bytree': 0.8, 'gamma': 0.5463608282650539, 'lambda': 1.09298215460265, 'learning_rate': 0.028471882617482895, 'max_depth': 2, 'min_child_weight': 2, 'n_estimators': 747, 'subsample': 0.79}
# SCORE: -2499981.667 params {'colsample_bytree': 0.8, 'gamma': 3.5857639334643983, 'lambda': 3.104659897347046, 'learning_rate': 0.012196354528319617, 'max_depth': 5, 'min_child_weight': 4, 'n_estimators': 202, 'subsample': 0.79}
# SCORE: -2460698.167 params {'colsample_bytree': 0.8, 'gamma': 3.8380529750201844, 'lambda': 4.487952047830307, 'learning_rate': 0.02771485532050067, 'max_depth': 1, 'min_child_weight': 2, 'n_estimators': 321, 'subsample': 0.79}
# SCORE: -2488714.417 params {'colsample_bytree': 0.8, 'gamma': 4.448169918814811, 'lambda': 4.869092815831057, 'learning_rate': 0.016654475118751635, 'max_depth': 6, 'min_child_weight': 3, 'n_estimators': 484, 'subsample': 0.79}
# SCORE: -2494942.333 params {'colsample_bytree': 0.8, 'gamma': 1.834445750609352, 'lambda': 4.320158031116795, 'learning_rate': 0.014210816644848044, 'max_depth': 8, 'min_child_weight': 3, 'n_estimators': 987, 'subsample': 0.79}
# SCORE: -2468884.917 params {'colsample_bytree': 0.8, 'gamma': 0.21679980183434944, 'lambda': 4.353582025651794, 'learning_rate': 0.024478956869249027, 'max_depth': 2, 'min_child_weight': 4, 'n_estimators': 407, 'subsample': 0.79}
# SCORE: -2494775.500 params {'colsample_bytree': 0.8, 'gamma': 0.11635757473437412, 'lambda': 1.3068177768344444, 'learning_rate': 0.014250127051754928, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 512, 'subsample': 0.79}
# SCORE: -2455850.167 params {'colsample_bytree': 0.8, 'gamma': 4.414203746185139, 'lambda': 0.6198359829397568, 'learning_rate': 0.02964867613389512, 'max_depth': 6, 'min_child_weight': 1, 'n_estimators': 659, 'subsample': 0.79}
# SCORE: -2455808.917 params {'colsample_bytree': 0.8, 'gamma': 2.691532655232031, 'lambda': 0.44841566345233363, 'learning_rate': 0.029650363573613926, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 41, 'subsample': 0.79}
# SCORE: -2455297.667 params {'colsample_bytree': 0.8, 'gamma': 2.7005006309523525, 'lambda': 0.33586758049950977, 'learning_rate': 0.029853274470336866, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 188, 'subsample': 0.79}
# SCORE: -2465276.833 params {'colsample_bytree': 0.8, 'gamma': 2.742548152840313, 'lambda': 0.34610187855365976, 'learning_rate': 0.025908970882827426, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 996, 'subsample': 0.79}
# SCORE: -2454966.583 params {'colsample_bytree': 0.8, 'gamma': 2.404847311811813, 'lambda': 0.22037929992167735, 'learning_rate': 0.02998472878410937, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 144, 'subsample': 0.79}
# SCORE: -2463959.833 params {'colsample_bytree': 0.8, 'gamma': 2.2361264478069134, 'lambda': 0.15734238888642893, 'learning_rate': 0.026425751050101615, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 30, 'subsample': 0.79}
# SCORE: -2474742.583 params {'colsample_bytree': 0.8, 'gamma': 3.01490133039746, 'lambda': 2.1790772116741155, 'learning_rate': 0.022190150096127778, 'max_depth': 7, 'min_child_weight': 1, 'n_estimators': 844, 'subsample': 0.79}
# SCORE: -2462876.833 params {'colsample_bytree': 0.8, 'gamma': 1.891296745780584, 'lambda': 2.330652738331197, 'learning_rate': 0.026972973301659736, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 311, 'subsample': 0.79}
# SCORE: -2455690.833 params {'colsample_bytree': 0.8, 'gamma': 1.301795330995216, 'lambda': 0.12960501665697455, 'learning_rate': 0.029784729016193293, 'max_depth': 9, 'min_child_weight': 1, 'n_estimators': 146, 'subsample': 0.79}
# SCORE: -2467841.083 params {'colsample_bytree': 0.8, 'gamma': 2.246364589809691, 'lambda': 1.932533143182975, 'learning_rate': 0.02504180567525107, 'max_depth': 11, 'min_child_weight': 1, 'n_estimators': 144, 'subsample': 0.79}
# SCORE: -2475342.750 params {'colsample_bytree': 0.8, 'gamma': 1.771638165295487, 'lambda': 1.71603922217352, 'learning_rate': 0.02193158560266123, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 149, 'subsample': 0.79}
# SCORE: -2458328.167 params {'colsample_bytree': 0.8, 'gamma': 4.029268491438024, 'lambda': 2.4641571984095787, 'learning_rate': 0.028654483991822386, 'max_depth': 4, 'min_child_weight': 5, 'n_estimators': 118, 'subsample': 0.79}
# SCORE: -2486655.333 params {'colsample_bytree': 0.8, 'gamma': 2.411476467299773, 'lambda': 0.17191764016707717, 'learning_rate': 0.01747768908014077, 'max_depth': 7, 'min_child_weight': 1, 'n_estimators': 852, 'subsample': 0.79}
# SCORE: -2473950.000 params {'colsample_bytree': 0.8, 'gamma': 3.1679468650440956, 'lambda': 0.7179974692822292, 'learning_rate': 0.022482127109694845, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 130, 'subsample': 0.79}
# SCORE: -2455149.333 params {'colsample_bytree': 0.8, 'gamma': 1.018128099408279, 'lambda': 2.8071472709875183, 'learning_rate': 0.029994359110802987, 'max_depth': 9, 'min_child_weight': 5, 'n_estimators': 880, 'subsample': 0.79}
# SCORE: -2503388.667 params {'colsample_bytree': 0.8, 'gamma': 0.840681751952421, 'lambda': 2.7763951969923593, 'learning_rate': 0.010877666233067525, 'max_depth': 9, 'min_child_weight': 5, 'n_estimators': 492, 'subsample': 0.79}
# SCORE: -2483844.083 params {'colsample_bytree': 0.8, 'gamma': 1.0091840551464397, 'lambda': 3.2372822395087337, 'learning_rate': 0.01864433872195409, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 251, 'subsample': 0.79}
# SCORE: -2466281.333 params {'colsample_bytree': 0.8, 'gamma': 1.4621929318706766, 'lambda': 3.6306662199385196, 'learning_rate': 0.025582185716604918, 'max_depth': 9, 'min_child_weight': 5, 'n_estimators': 265, 'subsample': 0.79}
# SCORE: -2511342.917 params {'colsample_bytree': 0.8, 'gamma': 0.8299830690606789, 'lambda': 3.986218769640071, 'learning_rate': 0.007725633182281489, 'max_depth': 9, 'min_child_weight': 5, 'n_estimators': 545, 'subsample': 0.79}
# SCORE: -2460718.083 params {'colsample_bytree': 0.8, 'gamma': 1.1436183556313728, 'lambda': 2.7236019498656936, 'learning_rate': 0.027852262925665165, 'max_depth': 11, 'min_child_weight': 5, 'n_estimators': 724, 'subsample': 0.79}
# SCORE: -2518219.417 params {'colsample_bytree': 0.8, 'gamma': 1.6848010960591013, 'lambda': 3.861338214998875, 'learning_rate': 0.00500055202712928, 'max_depth': 9, 'min_child_weight': 5, 'n_estimators': 87, 'subsample': 0.79}
# SCORE: -2478492.083 params {'colsample_bytree': 0.8, 'gamma': 2.0339403498607638, 'lambda': 1.477429596478791, 'learning_rate': 0.02068426895584561, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 438, 'subsample': 0.79}
# SCORE: -2470390.500 params {'colsample_bytree': 0.8, 'gamma': 0.6725048108675026, 'lambda': 1.7157202448472781, 'learning_rate': 0.02392992010084959, 'max_depth': 8, 'min_child_weight': 5, 'n_estimators': 901, 'subsample': 0.79}
# SCORE: -2462323.667 params {'colsample_bytree': 0.8, 'gamma': 1.5015496564209008, 'lambda': 2.950075660610019, 'learning_rate': 0.027185515465542806, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 57, 'subsample': 0.79}
# SCORE: -2458791.917 params {'colsample_bytree': 0.8, 'gamma': 2.9142229812704685, 'lambda': 1.9951016852959467, 'learning_rate': 0.028553105679789834, 'max_depth': 9, 'min_child_weight': 3, 'n_estimators': 768, 'subsample': 0.79}
# SCORE: -2481965.667 params {'colsample_bytree': 0.8, 'gamma': 2.4737843879900465, 'lambda': 2.5353253422332376, 'learning_rate': 0.01931724049232014, 'max_depth': 5, 'min_child_weight': 4, 'n_estimators': 765, 'subsample': 0.79}
# SCORE: -2491242.333 params {'colsample_bytree': 0.8, 'gamma': 2.108882720202077, 'lambda': 4.051411302556968, 'learning_rate': 0.01564625319098957, 'max_depth': 1, 'min_child_weight': 2, 'n_estimators': 178, 'subsample': 0.79}
# SCORE: -2473532.167 params {'colsample_bytree': 0.8, 'gamma': 3.7909583632462067, 'lambda': 3.581777260547743, 'learning_rate': 0.02276284669076382, 'max_depth': 11, 'min_child_weight': 5, 'n_estimators': 636, 'subsample': 0.79}
# SCORE: -2478413.000 params {'colsample_bytree': 0.8, 'gamma': 3.42366522044441, 'lambda': 4.6909990026931, 'learning_rate': 0.02071476047342048, 'max_depth': 2, 'min_child_weight': 4, 'n_estimators': 205, 'subsample': 0.79}
# SCORE: -2484509.417 params {'colsample_bytree': 0.8, 'gamma': 0.42620971380181216, 'lambda': 3.035871417540278, 'learning_rate': 0.018317139430457045, 'max_depth': 6, 'min_child_weight': 2, 'n_estimators': 447, 'subsample': 0.79}
# SCORE: -2497327.917 params {'colsample_bytree': 0.8, 'gamma': 1.1865421338275075, 'lambda': 3.333032522119869, 'learning_rate': 0.013255673281922325, 'max_depth': 7, 'min_child_weight': 3, 'n_estimators': 631, 'subsample': 0.79}
# 100%|██████████| 50/50 [1:42:24<00:00, 158.51s/it, best loss: 2454966.5833333335]
# Tiempo = 102.40 minutos

# %%
print(best)
# Out:
# {'xgb_re__gamma': 2.404847311811813, 'xgb_re__lambda': 0.22037929992167735, 'xgb_re__learning_rate': 0.02998472878410937, 'xgb_re__max_depth': 3, 'xgb_re__min_child_weight': 0, 'xgb_re__n_estimators': 144}

# %% [markdown]
# Xgboost + Random Forest
#
# {
#     'xgb_re__gamma': 2.404847311811813,
#     'xgb_re__lambda': 0.22037929992167735,
#     'xgb_re__learning_rate': 0.02998472878410937,
#     'xgb_re__max_depth': 3,
#     'xgb_re__min_child_weight': 0,
#     'xgb_re__n_estimators': 144
# }
# Score = 2454966.5833333335
