# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks')

# %%
import pandas as pd
import numpy as np

# %%
train_10 = pd.read_csv("/content/drive/My Drive/Colab Notebooks/sets_de_datos/dima_train_with_features_10.csv")

# %%
X_test_10 = pd.read_csv("/content/drive/My Drive/Colab Notebooks/sets_de_datos/dima_test_with_features_10.csv")

# %%
train_6 = pd.read_csv("/content/drive/My Drive/Colab Notebooks/sets_de_datos/dima_train_with_features_6.csv")

# %%
X_test_6 = pd.read_csv("/content/drive/My Drive/Colab Notebooks/sets_de_datos/dima_test_with_features_6.csv")

# %%
train_10.columns[:70]
# Out:
# Index(['id', 'titulo', 'descripcion', 'tipodepropiedad', 'direccion', 'ciudad',
#        'provincia', 'antiguedad', 'habitaciones', 'garages', 'banos',
#        'metroscubiertos', 'metrostotales', 'idzona', 'lat', 'lng', 'fecha',
#        'gimnasio', 'usosmultiples', 'piscina', 'escuelascercanas',
#        'centroscomercialescercanos', 'precio', 'servicios_cercanos',
#        'utilidades_extra', 'tipodepropiedad_mean_antiguedad',
#        'tipodepropiedad_mean_habitaciones', 'tipodepropiedad_mean_garages',
#        'tipodepropiedad_mean_banos', 'tipodepropiedad_mean_metroscubiertos',
#        'tipodepropiedad_mean_utilidades_extra',
#        'tipodepropiedad_mean_servicios_cercanos', 'ciudad_mean_antiguedad',
#        'ciudad_mean_habitaciones', 'ciudad_mean_garages', 'ciudad_mean_banos',
#        'ciudad_mean_metroscubiertos', 'ciudad_mean_utilidades_extra',
#        'ciudad_mean_servicios_cercanos', 'provincia_mean_antiguedad',
# ...

# %% [markdown]
# 'distancia_minima_Apartamento' : 'distancia_promedio_Apartamento_10_mas_cercanos',
# 'distancia_minima_Casa_en_condominio' : 'distancia_promedio_Casa_en_condominio_10_mas_cercanos',
# 'distancia_minima_Casa' : 'distancia_promedio_Casa_10_mas_cercanos',
# 'distancia_minima_Terreno' : 'distancia_promedio_Terreno_10_mas_cercanos',
# 'distancia_minima_Quinta_Vacacional' : 'distancia_promedio_Quinta_Vacacional_10_mas_cercanos',
# 'distancia_minima_Edificio'  : 'distancia_promedio_Edificio_10_mas_cercanos',
# 'distancia_minima_Casa_uso_de_suelo' : 'distancia_promedio_Casa_uso_de_suelo_10_mas_cercanos',
# 'distancia_minima_Otros' : 'distancia_promedio_Otros_10_mas_cercanos',
# 'distancia_minima_Villa' : 'distancia_promedio_Villa_10_mas_cercanos',
# 'distancia_minima_Duplex' : 'distancia_promedio_Duplex_10_mas_cercanos',
# 'distancia_minima_Inmuebles_productivos_urbanos' : 'distancia_promedio_Inmuebles_productivos_urbanos_10_mas_cercanos',
# 'distancia_minima_Departamento_Compartido' : 'distancia_promedio_Departamento_Compartido_10_mas_cercanos',
# 'distancia_minima_Nave_industrial' : 'distancia_promedio_Nave_industrial_10_mas_cercanos',
# 'distancia_minima_Rancho' : 'distancia_promedio_Rancho_10_mas_cercanos',
# 'distancia_minima_Terreno_industrial' : 'distancia_promedio_Terreno_industrial_10_mas_cercanos',
# 'distancia_minima_Terreno_comercial' : 'distancia_promedio_Terreno_comercial_10_mas_cercanos',
# 'distancia_minima_Local_Comercial' : 'distancia_promedio_Local_Comercial_10_mas_cercanos',
# 'distancia_minima_Oficina_comercial' : 'distancia_promedio_Oficina_comercial_10_mas_cercanos',
# 'distancia_minima_Local_en_centro_comercial' : 'distancia_promedio_Local_en_centro_comercial_10_mas_cercanos',
# 'distancia_minima_Bodega_comercial' : 'distancia_promedio_Bodega_comercial_10_mas_cercanos'

# %%
train_10.rename(columns = {'distancia_minima_Apartamento' : 'distancia_promedio_Apartamento_10_mas_cercanos',  
'distancia_minima_Casa_en_condominio' : 'distancia_promedio_Casa_en_condominio_10_mas_cercanos',   
'distancia_minima_Casa' : 'distancia_promedio_Casa_10_mas_cercanos',  
'distancia_minima_Terreno' : 'distancia_promedio_Terreno_10_mas_cercanos',  
'distancia_minima_Quinta_Vacacional' : 'distancia_promedio_Quinta_Vacacional_10_mas_cercanos',  
'distancia_minima_Edificio'  : 'distancia_promedio_Edificio_10_mas_cercanos',  
'distancia_minima_Casa_uso_de_suelo' : 'distancia_promedio_Casa_uso_de_suelo_10_mas_cercanos',  
'distancia_minima_Otros' : 'distancia_promedio_Otros_10_mas_cercanos',  
'distancia_minima_Villa' : 'distancia_promedio_Villa_10_mas_cercanos',  
'distancia_minima_Duplex' : 'distancia_promedio_Duplex_10_mas_cercanos',   
'distancia_minima_Inmuebles_productivos_urbanos' : 'distancia_promedio_Inmuebles_productivos_urbanos_10_mas_cercanos',  
'distancia_minima_Departamento_Compartido' : 'distancia_promedio_Departamento_Compartido_10_mas_cercanos',  
'distancia_minima_Nave_industrial' : 'distancia_promedio_Nave_industrial_10_mas_cercanos',  
'distancia_minima_Rancho' : 'distancia_promedio_Rancho_10_mas_cercanos',  
'distancia_minima_Terreno_industrial' : 'distancia_promedio_Terreno_industrial_10_mas_cercanos',  
'distancia_minima_Terreno_comercial' : 'distancia_promedio_Terreno_comercial_10_mas_cercanos',  
'distancia_minima_Local_Comercial' : 'distancia_promedio_Local_Comercial_10_mas_cercanos',  
'distancia_minima_Oficina_comercial' : 'distancia_promedio_Oficina_comercial_10_mas_cercanos',  
'distancia_minima_Local_en_centro_comercial' : 'distancia_promedio_Local_en_centro_comercial_10_mas_cercanos',  
'distancia_minima_Bodega_comercial' : 'distancia_promedio_Bodega_comercial_10_mas_cercanos' }, inplace = True)

# %%
X_test_10.rename(columns = {'distancia_minima_Apartamento' : 'distancia_promedio_Apartamento_10_mas_cercanos',  
'distancia_minima_Casa_en_condominio' : 'distancia_promedio_Casa_en_condominio_10_mas_cercanos',   
'distancia_minima_Casa' : 'distancia_promedio_Casa_10_mas_cercanos',  
'distancia_minima_Terreno' : 'distancia_promedio_Terreno_10_mas_cercanos',  
'distancia_minima_Quinta_Vacacional' : 'distancia_promedio_Quinta_Vacacional_10_mas_cercanos',  
'distancia_minima_Edificio'  : 'distancia_promedio_Edificio_10_mas_cercanos',  
'distancia_minima_Casa_uso_de_suelo' : 'distancia_promedio_Casa_uso_de_suelo_10_mas_cercanos',  
'distancia_minima_Otros' : 'distancia_promedio_Otros_10_mas_cercanos',  
'distancia_minima_Villa' : 'distancia_promedio_Villa_10_mas_cercanos',  
'distancia_minima_Duplex' : 'distancia_promedio_Duplex_10_mas_cercanos',   
'distancia_minima_Inmuebles_productivos_urbanos' : 'distancia_promedio_Inmuebles_productivos_urbanos_10_mas_cercanos',  
'distancia_minima_Departamento_Compartido' : 'distancia_promedio_Departamento_Compartido_10_mas_cercanos',  
'distancia_minima_Nave_industrial' : 'distancia_promedio_Nave_industrial_10_mas_cercanos',  
'distancia_minima_Rancho' : 'distancia_promedio_Rancho_10_mas_cercanos',  
'distancia_minima_Terreno_industrial' : 'distancia_promedio_Terreno_industrial_10_mas_cercanos',  
'distancia_minima_Terreno_comercial' : 'distancia_promedio_Terreno_comercial_10_mas_cercanos',  
'distancia_minima_Local_Comercial' : 'distancia_promedio_Local_Comercial_10_mas_cercanos',  
'distancia_minima_Oficina_comercial' : 'distancia_promedio_Oficina_comercial_10_mas_cercanos',  
'distancia_minima_Local_en_centro_comercial' : 'distancia_promedio_Local_en_centro_comercial_10_mas_cercanos',  
'distancia_minima_Bodega_comercial' : 'distancia_promedio_Bodega_comercial_10_mas_cercanos' }, inplace = True)

# %%
train_10.shape
# Out:
# (240000, 152)

# %%
X_test_10.shape
# Out:
# (60000, 151)

# %%
train_6.columns[60:]
# Out:
# Index(['id', 'titulo', 'descripcion', 'tipodepropiedad', 'direccion', 'ciudad',
#        'provincia', 'antiguedad', 'habitaciones', 'garages', 'banos',
#        'metroscubiertos', 'metrostotales', 'idzona', 'lat', 'lng', 'fecha',
#        'gimnasio', 'usosmultiples', 'piscina', 'escuelascercanas',
#        'centroscomercialescercanos', 'precio', 'servicios_cercanos',
#        'utilidades_extra', 'tipodepropiedad_mean_antiguedad',
#        'tipodepropiedad_mean_habitaciones', 'tipodepropiedad_mean_garages',
#        'tipodepropiedad_mean_banos', 'tipodepropiedad_mean_metroscubiertos',
#        'tipodepropiedad_mean_utilidades_extra',
#        'tipodepropiedad_mean_servicios_cercanos', 'ciudad_mean_antiguedad',
#        'ciudad_mean_habitaciones', 'ciudad_mean_garages', 'ciudad_mean_banos',
#        'ciudad_mean_metroscubiertos', 'ciudad_mean_utilidades_extra',
#        'ciudad_mean_servicios_cercanos', 'provincia_mean_antiguedad',
# ...

# %%
train_6_distancia  = train_6[['id',  
       'distancia_minima_Terreno_comercial',
       'distancia_minima_Local_Comercial',
       'distancia_minima_Oficina_comercial',
       'distancia_minima_Local_en_centro_comercial',
       'distancia_minima_Bodega_comercial']]

# %%
X_test_6_distancias =  X_test_6[['id',  
                                  'distancia_minima_Terreno_comercial',
                                  'distancia_minima_Local_Comercial',
                                  'distancia_minima_Oficina_comercial',
                                  'distancia_minima_Local_en_centro_comercial',
                                  'distancia_minima_Bodega_comercial']]

# %%
train_6_distancia.shape
# Out:
# (240000, 6)

# %%
X_test_6_distancias.shape
# Out:
# (60000, 6)

# %%
train_11 = train_10.merge(train_6_distancia, on = 'id')

# %%
train_11.shape
# Out:
# (240000, 157)

# %%
X_test_11 = X_test_10.merge(X_test_6_distancias, on = 'id')

# %%
X_test_11.shape
# Out:
# (60000, 156)

# %%
train_11.to_csv("/content/drive/My Drive/Colab Notebooks/sets_de_datos/train_with_features_11.csv", index = False)

# %%
X_test_11.to_csv("/content/drive/My Drive/Colab Notebooks/sets_de_datos/test_with_features_11.csv", index = False)

# %%
prueba = pd.read_csv("/content/drive/My Drive/Colab Notebooks/sets_de_datos/test_with_features_11.csv")

# %%
prueba.columns[:70]
# Out:
# Index(['id', 'titulo', 'descripcion', 'tipodepropiedad', 'direccion', 'ciudad',
#        'provincia', 'antiguedad', 'habitaciones', 'garages', 'banos',
#        'metroscubiertos', 'metrostotales', 'idzona', 'lat', 'lng', 'fecha',
#        'gimnasio', 'usosmultiples', 'piscina', 'escuelascercanas',
#        'centroscomercialescercanos', 'servicios_cercanos', 'utilidades_extra',
#        'tipodepropiedad_mean_antiguedad', 'tipodepropiedad_mean_habitaciones',
#        'tipodepropiedad_mean_garages', 'tipodepropiedad_mean_banos',
#        'tipodepropiedad_mean_metroscubiertos',
#        'tipodepropiedad_mean_utilidades_extra',
#        'tipodepropiedad_mean_servicios_cercanos', 'ciudad_mean_antiguedad',
#        'ciudad_mean_habitaciones', 'ciudad_mean_garages', 'ciudad_mean_banos',
#        'ciudad_mean_metroscubiertos', 'ciudad_mean_utilidades_extra',
#        'ciudad_mean_servicios_cercanos', 'provincia_mean_antiguedad',
# ...
