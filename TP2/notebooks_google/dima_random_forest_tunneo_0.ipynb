# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Imports

# %%
import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks')

# %%
import feature_string as feature_string
import feature_num as feature_num
import feature_categorica as feature_categorica
import common_machine_learning as common
import my_pipeline as my_pipe
import pandas as pd
import numpy as np
from hyperopt import fmin, tpe, hp, STATUS_OK
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
import time

# %% [markdown]
# #### Ignore Future Warning

# %%
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## Constantes

# %%
TARGET = 'precio'
K = 3
RANDOM_SEMILLA = 3 # numero favorito (de la suerte)
XGB_RE_OBJECTIVE = 'reg:squarederror'
N_ITER = 50

# %% [markdown]
# ## Train

# %%
train = common.cargar_set_optimizado('/content/drive/My Drive/Colab Notebooks/sets_de_datos/train.csv')

# %% [markdown]
# ## Features

# %%
feature_num.agregar_feature_fecha_numerica(train)

# %% [markdown]
# Esto toma unos segundos

# %%
train = feature_num.completar_lat_lng_con_provincias_y_ciudades(train)
train = feature_num.completar_lat_lng_con_idzona_mean(train)
feature_num.completar_lat_lng_con_promedio_Mexico(train)

# %%
train = feature_categorica.agregar_tipodepropiedad_precio_mean(train)

# %%
train = feature_categorica.train_agregar_feature_provincias_ciudades_ohe_reducido_df(train)

# %%
train = feature_string.train_agregar_feature_string_todos_df(train)

# %%
train.columns
# Out:
# Index(['id', 'titulo', 'descripcion', 'tipodepropiedad', 'direccion', 'ciudad',
#        'provincia', 'antiguedad', 'habitaciones', 'garages', 'banos',
#        'metroscubiertos', 'metrostotales', 'idzona', 'lat', 'lng', 'fecha',
#        'gimnasio', 'usosmultiples', 'piscina', 'escuelascercanas',
#        'centroscomercialescercanos', 'precio', 'fecha_numerica',
#        'tipodepropiedad_precio_mean', 'ciudad_San_Luis_Potosí',
#        'ciudad_Querétaro', 'ciudad_Zapopan', 'ciudad_Huixquilucan',
#        'ciudad_Mérida', 'provincia_Distrito_Federal',
#        'provincia_Edo._de_México', 'provincia_San_luis_Potosí',
#        'provincia_Yucatán', 'provincia_Querétaro',
#        'titulo_cantidad_palabras_importantes',
#        'descripcion_cantidad_palabras_importantes',
#        'direccion_cantidad_palabras_importantes',
#        'titulo_cantidad_caracteres_en_palabras_importantes',
#        'descripcion_cantidad_caracteres_en_palabras_importantes',
#        'direccion_cantidad_caracteres_en_palabras_importantes',
#        'titulo_longitud_media_de_palabra',
#        'descripcion_longitud_media_de_palabra',
#        'direccion_longitud_media_de_palabra', 'titulo_cantidad_stopwords',
#        'descripcion_cantidad_stopwords', 'direccion_cantidad_stopwords',
#        'titulo_cantidad_signos_puntacion',
#        'descripcion_cantidad_signos_puntacion',
#        'direccion_cantidad_signos_puntacion',
#        'direccion_cantidad_palabras_en_mayuscula',
#        'direccion_cantidad_titulos', 'titulo_cantidad_palabras_top_k',
#        'descripcion_cantidad_palabras_top_k',
#        'direccion_cantidad_palabras_top_k',
#        'titulo_cantidad_palabras_bottom_k',
#        'descripcion_cantidad_palabras_bottom_k',
#        'direccion_cantidad_palabras_bottom_k',
#        'titulo_cantidad_prefijos_top_k', 'descripcion_cantidad_prefijos_top_k',
#        'direccion_cantidad_prefijos_top_k', 'titulo_cantidad_postfijos_top_k',
#        'descripcion_cantidad_postfijos_top_k',
#        'direccion_cantidad_postfijos_top_k'],
#       dtype='object')

# %%
drop_columns = ['titulo', 'descripcion', 'tipodepropiedad', 'direccion', 'ciudad', 'provincia', 'idzona']

# %%
train = train.drop(drop_columns, axis = 1)

# %%
train.shape
# Out:
# (240000, 57)

# %%
train.isnull().sum()
# Out:
# id                                                             0
# antiguedad                                                 43555
# habitaciones                                               22471
# garages                                                    37765
# banos                                                      26221
# metroscubiertos                                            17400
# metrostotales                                              51467
# lat                                                            0
# lng                                                            0
# fecha                                                          0
# gimnasio                                                       0
# usosmultiples                                                  0
# piscina                                                        0
# escuelascercanas                                               0
# centroscomercialescercanos                                     0
# precio                                                         0
# fecha_numerica                                                 0
# tipodepropiedad_precio_mean                                    0
# ciudad_San_Luis_Potosí                                         0
# ciudad_Querétaro                                               0
# ciudad_Zapopan                                                 0
# ciudad_Huixquilucan                                            0
# ciudad_Mérida                                                  0
# provincia_Distrito_Federal                                     0
# provincia_Edo._de_México                                       0
# provincia_San_luis_Potosí                                      0
# provincia_Yucatán                                              0
# provincia_Querétaro                                            0
# titulo_cantidad_palabras_importantes                           0
# descripcion_cantidad_palabras_importantes                      0
# direccion_cantidad_palabras_importantes                        0
# titulo_cantidad_caracteres_en_palabras_importantes             0
# descripcion_cantidad_caracteres_en_palabras_importantes        0
# direccion_cantidad_caracteres_en_palabras_importantes          0
# titulo_longitud_media_de_palabra                               0
# descripcion_longitud_media_de_palabra                          0
# direccion_longitud_media_de_palabra                            0
# titulo_cantidad_stopwords                                      0
# descripcion_cantidad_stopwords                                 0
# direccion_cantidad_stopwords                                   0
# titulo_cantidad_signos_puntacion                               0
# descripcion_cantidad_signos_puntacion                          0
# direccion_cantidad_signos_puntacion                            0
# direccion_cantidad_palabras_en_mayuscula                       0
# direccion_cantidad_titulos                                     0
# titulo_cantidad_palabras_top_k                                 0
# descripcion_cantidad_palabras_top_k                            0
# direccion_cantidad_palabras_top_k                              0
# titulo_cantidad_palabras_bottom_k                              0
# descripcion_cantidad_palabras_bottom_k                         0
# direccion_cantidad_palabras_bottom_k                           0
# titulo_cantidad_prefijos_top_k                                 0
# descripcion_cantidad_prefijos_top_k                            0
# direccion_cantidad_prefijos_top_k                              0
# titulo_cantidad_postfijos_top_k                                0
# descripcion_cantidad_postfijos_top_k                           0
# direccion_cantidad_postfijos_top_k                             0
# dtype: int64

# %%
train.set_index('id', inplace = True)

# %%
X = train.drop([TARGET], axis = 1).copy()
y = train[TARGET].copy()

# %%
pre_procesar_pipe = my_pipe.get_columns_pipeline()

def objective(hyper_parametros):
    
    busqueda_pipe = Pipeline(steps = [
        ('pre-procesar', pre_procesar_pipe),
        ('xgb_regressor', RandomForestRegressor(**hyper_parametros))
    ])  
    
    score = cross_val_score(busqueda_pipe, X, y, scoring='neg_mean_absolute_error', cv=K).mean()
    
    print("SCORE: {:.3f} params {}".format(score, hyper_parametros))
    
    return {'loss': -score, 'status': STATUS_OK}

# %%
train.shape[1]
# Out:
# 56

# %%
space = {
    "n_estimators": hp.randint("n_estimators", 1000),
    "max_depth": hp.randint("max_depth", 15) + 2,
    "min_samples_split": hp.randint("min_samples_split", 10) + 2,
    "min_samples_leaf": hp.choice("min_samples_leaf", [2, 3, 4, 5, 6, 7, 8, 9, 10]),
    "max_features": hp.uniform("max_features", 0.6, 0.8)
}

# %%
t0 = time.time()
best = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=N_ITER)
t1 = time.time()
print('Tiempo = {0:.2f} minutos'.format((t1 - t0)/60))
# Out:
# SCORE: -1195823.793 params {'max_depth': 2, 'max_features': 0.7320420643915713, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 380}
# SCORE: -986937.124 params {'max_depth': 9, 'max_features': 0.6696957828982146, 'min_samples_leaf': 9, 'min_samples_split': 8, 'n_estimators': 122}
# SCORE: -976050.769 params {'max_depth': 10, 'max_features': 0.7701903251461797, 'min_samples_leaf': 10, 'min_samples_split': 9, 'n_estimators': 94}
# SCORE: -976510.703 params {'max_depth': 10, 'max_features': 0.7177776573992107, 'min_samples_leaf': 2, 'min_samples_split': 11, 'n_estimators': 62}
# SCORE: -1001378.127 params {'max_depth': 8, 'max_features': 0.7405097915539923, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 999}
# SCORE: -1001236.585 params {'max_depth': 8, 'max_features': 0.6844298444352478, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 704}
# SCORE: -1117264.564 params {'max_depth': 4, 'max_features': 0.6047681352516926, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 632}
# SCORE: -951056.225 params {'max_depth': 14, 'max_features': 0.6783298063525202, 'min_samples_leaf': 10, 'min_samples_split': 2, 'n_estimators': 359}
# SCORE: -945749.928 params {'max_depth': 15, 'max_features': 0.7658998914973174, 'min_samples_leaf': 3, 'min_samples_split': 6, 'n_estimators': 894}
# SCORE: -947703.747 params {'max_depth': 15, 'max_features': 0.6887389238467215, 'min_samples_leaf': 8, 'min_samples_split': 4, 'n_estimators': 640}
# SCORE: -1052414.052 params {'max_depth': 6, 'max_features': 0.6391367680481234, 'min_samples_leaf': 8, 'min_samples_split': 10, 'n_estimators': 81}
# SCORE: -1117018.812 params {'max_depth': 4, 'max_features': 0.6413836120521837, 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 550}
# SCORE: -980552.850 params {'max_depth': 10, 'max_features': 0.6131431947196617, 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 185}
# SCORE: -975384.870 params {'max_depth': 10, 'max_features': 0.7257486178684558, 'min_samples_leaf': 6, 'min_samples_split': 6, 'n_estimators': 406}
# SCORE: -1020456.156 params {'max_depth': 7, 'max_features': 0.6670119730298538, 'min_samples_leaf': 9, 'min_samples_split': 10, 'n_estimators': 211}
# SCORE: -1044655.733 params {'max_depth': 6, 'max_features': 0.78482508795263, 'min_samples_leaf': 2, 'min_samples_split': 11, 'n_estimators': 634}
# SCORE: -949644.645 params {'max_depth': 15, 'max_features': 0.6485702967241695, 'min_samples_leaf': 8, 'min_samples_split': 8, 'n_estimators': 293}
# SCORE: -950989.822 params {'max_depth': 15, 'max_features': 0.7406973244548374, 'min_samples_leaf': 8, 'min_samples_split': 10, 'n_estimators': 19}
# SCORE: -1147776.321 params {'max_depth': 3, 'max_features': 0.7493392724903961, 'min_samples_leaf': 5, 'min_samples_split': 9, 'n_estimators': 896}
# SCORE: -980152.194 params {'max_depth': 10, 'max_features': 0.6632847077123009, 'min_samples_leaf': 6, 'min_samples_split': 11, 'n_estimators': 724}
# SCORE: -945998.219 params {'max_depth': 15, 'max_features': 0.7018631631134992, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 952}
# SCORE: -944220.585 params {'max_depth': 16, 'max_features': 0.7105264652323079, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 684}
# SCORE: -944356.057 params {'max_depth': 16, 'max_features': 0.7665282351744811, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 336}
# SCORE: -944170.475 params {'max_depth': 16, 'max_features': 0.7097479532655517, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 636}
# SCORE: -944143.902 params {'max_depth': 16, 'max_features': 0.7093997095411249, 'min_samples_leaf': 4, 'min_samples_split': 7, 'n_estimators': 778}
# SCORE: -944950.249 params {'max_depth': 16, 'max_features': 0.7042925413247143, 'min_samples_leaf': 4, 'min_samples_split': 7, 'n_estimators': 129}
# SCORE: -954133.748 params {'max_depth': 13, 'max_features': 0.6898935485592518, 'min_samples_leaf': 7, 'min_samples_split': 7, 'n_estimators': 191}
# SCORE: -1077184.663 params {'max_depth': 5, 'max_features': 0.7938062653147343, 'min_samples_leaf': 4, 'min_samples_split': 7, 'n_estimators': 84}
# SCORE: -959070.704 params {'max_depth': 12, 'max_features': 0.7249396076923346, 'min_samples_leaf': 4, 'min_samples_split': 7, 'n_estimators': 855}
# SCORE: -966759.433 params {'max_depth': 11, 'max_features': 0.7492088072410024, 'min_samples_leaf': 7, 'min_samples_split': 2, 'n_estimators': 108}
# SCORE: -1206833.418 params {'max_depth': 2, 'max_features': 0.6237085005270606, 'min_samples_leaf': 4, 'min_samples_split': 7, 'n_estimators': 982}
# SCORE: -944220.645 params {'max_depth': 16, 'max_features': 0.7159689705158958, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 893}
# SCORE: -948051.012 params {'max_depth': 16, 'max_features': 0.6598081662839781, 'min_samples_leaf': 9, 'min_samples_split': 4, 'n_estimators': 429}
# SCORE: -986708.693 params {'max_depth': 9, 'max_features': 0.7321122267591682, 'min_samples_leaf': 4, 'min_samples_split': 9, 'n_estimators': 492}
# SCORE: -1076633.313 params {'max_depth': 5, 'max_features': 0.6979496978335135, 'min_samples_leaf': 4, 'min_samples_split': 3, 'n_estimators': 67}
# SCORE: -944921.974 params {'max_depth': 16, 'max_features': 0.6752943796276274, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 383}
# SCORE: -951101.711 params {'max_depth': 14, 'max_features': 0.7362273999599894, 'min_samples_leaf': 10, 'min_samples_split': 7, 'n_estimators': 827}
# SCORE: -1020271.228 params {'max_depth': 7, 'max_features': 0.7467151173219283, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 928}
# SCORE: -1001127.713 params {'max_depth': 8, 'max_features': 0.760363794886186, 'min_samples_leaf': 7, 'min_samples_split': 4, 'n_estimators': 637}
# SCORE: -957399.102 params {'max_depth': 13, 'max_features': 0.6534520212092054, 'min_samples_leaf': 9, 'min_samples_split': 5, 'n_estimators': 955}
# SCORE: -1148003.939 params {'max_depth': 3, 'max_features': 0.7803393632624962, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 778}
# SCORE: -966736.966 params {'max_depth': 11, 'max_features': 0.6813690702676755, 'min_samples_leaf': 10, 'min_samples_split': 9, 'n_estimators': 152}
# SCORE: -962157.128 params {'max_depth': 12, 'max_features': 0.6282962465725325, 'min_samples_leaf': 4, 'min_samples_split': 3, 'n_estimators': 779}
# SCORE: -1196403.104 params {'max_depth': 2, 'max_features': 0.6930303145559162, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 307}
# SCORE: -1113157.114 params {'max_depth': 4, 'max_features': 0.7230709571450696, 'min_samples_leaf': 5, 'min_samples_split': 11, 'n_estimators': 787}
# SCORE: -986676.432 params {'max_depth': 9, 'max_features': 0.7101787465934054, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 919}
# SCORE: -944856.308 params {'max_depth': 16, 'max_features': 0.755190678776657, 'min_samples_leaf': 6, 'min_samples_split': 10, 'n_estimators': 421}
# SCORE: -1044781.166 params {'max_depth': 6, 'max_features': 0.671819093181928, 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 950}
# SCORE: -950509.745 params {'max_depth': 14, 'max_features': 0.6855349810920212, 'min_samples_leaf': 3, 'min_samples_split': 7, 'n_estimators': 56}
# SCORE: -946541.905 params {'max_depth': 16, 'max_features': 0.777715745143796, 'min_samples_leaf': 9, 'min_samples_split': 6, 'n_estimators': 237}
# 100%|██████████| 50/50 [2:51:23<00:00, 166.61s/it, best loss: 944143.9023536701]
# Tiempo = 171.39 minutos

# %%
print(best)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3acd3477e223> in <module>()
# ----> 1 print(best)
#
# NameError: name 'best' is not defined

# %% [markdown]
# Random Forest
# {
#      'max_depth': 16,
#      'max_features': 0.7093997095411249,
#      'min_samples_leaf': 4,
#      'min_samples_split': 7,
#      'n_estimators': 778
# }
# SCORE = -944143.902
